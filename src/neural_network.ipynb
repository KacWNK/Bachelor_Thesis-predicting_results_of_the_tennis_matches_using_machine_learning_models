# %%
import pandas as pd
import os

# %%
matches = pd.read_csv('../data/everything_before_models/matches2.csv')

# %%
# Check for missing values in the DataFrame
missing_values = matches.isnull().sum()

# Filter columns with missing values
columns_with_nan = missing_values[missing_values > 0]

# Display the columns and their corresponding NaN counts
print("Columns with NaN values and their counts:")
print(columns_with_nan)
# Out:
# Columns with NaN values and their counts:
# player1_bet_odds    12
# player2_bet_odds    12
# dtype: int64

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
list(matches.columns)
# Out:
# ['outdoor',
#  'player1_bet_odds',
#  'player2_bet_odds',
#  'player1_Sets_Before',
#  'player1_Gems_Before',
#  'player2_Sets_Before',
#  'player2_Gems_Before',
#  'tournament_level',
#  'player1_right_handed',
#  'player1_age',
#  'player2_right_handed',
#  'player2_age',
#  'best_of',
#  'player1_rank',
#  'player2_rank',
#  'player1_entry_LL',
#  'player1_entry_Q',
#  'player1_entry_WC',
#  'player2_entry_LL',
#  'player2_entry_Q',
#  'player2_entry_WC',
#  'player1_is_seeded',
#  'player2_is_seeded',
#  'player1_h2h_wins',
#  'player2_h2h_wins',
#  'player1_home',
#  'player2_home',
#  'Round_Num',
#  'player1_win_pct_last_10',
#  'player2_win_pct_last_10',
#  'player1_win_pct_last_10_surface',
#  'player2_win_pct_last_10_surface',
#  'player1_elo',
#  'player2_elo',
#  'player1_surface_elo',
#  'player2_surface_elo',
#  'player1_blended_elo',
#  'player2_blended_elo',
#  'num_CO_matches',
#  'player1_CO_1st_serve_in_pct_avg',
#  'player2_CO_1st_serve_in_pct_avg',
#  'player1_1st_serve_in_pct_avg',
#  'player2_1st_serve_in_pct_avg',
#  'player1_CO_1st_serve_win_pct_avg',
#  'player2_CO_1st_serve_win_pct_avg',
#  'player1_1st_serve_win_pct_avg',
#  'player2_1st_serve_win_pct_avg',
#  'player1_CO_2nd_serve_win_pct_avg',
#  'player2_CO_2nd_serve_win_pct_avg',
#  'player1_2nd_serve_win_pct_avg',
#  'player2_2nd_serve_win_pct_avg',
#  'player1_CO_serve_games_win_pct_avg',
#  'player2_CO_serve_games_win_pct_avg',
#  'player1_serve_games_win_pct_avg',
#  'player2_serve_games_win_pct_avg',
#  'player1_CO_ace_avg',
#  'player2_CO_ace_avg',
#  'player1_ace_avg',
#  'player2_ace_avg',
#  'player1_CO_df_avg',
#  'player2_CO_df_avg',
#  'player1_df_avg',
#  'player2_df_avg',
#  'player1_CO_1st_serve_return_win_pct_avg',
#  'player2_CO_1st_serve_return_win_pct_avg',
#  'player1_1st_serve_return_win_pct_avg',
#  'player2_1st_serve_return_win_pct_avg',
#  'player1_fatigue_score',
#  'player2_fatigue_score',
#  'player1_tournament_wins_before',
#  'player1_tournament_losses_before',
#  'player2_tournament_wins_before',
#  'player2_tournament_losses_before',
#  'Surface_Clay',
#  'Surface_Grass',
#  'Surface_Hard',
#  'target']

# %%
player1_cols = [col for col in matches.columns if col.startswith('player1_') and "bet" not in col]
player2_cols = [col for col in matches.columns if col.startswith('player2_') and "bet" not in col]
env_cols = [col for col in matches.columns if col not in player1_cols and col not in player2_cols and "diff" not in col and "CO" not in col and "target" not in col and "bet" not in col]
target_col = 'target'
player1_bet = 'player1_bet_odds'
player2_bet = 'player2_bet_odds'
player1_cols
# Out:
# ['player1_Sets_Before',
#  'player1_Gems_Before',
#  'player1_right_handed',
#  'player1_age',
#  'player1_rank',
#  'player1_entry_LL',
#  'player1_entry_Q',
#  'player1_entry_WC',
#  'player1_is_seeded',
#  'player1_h2h_wins',
#  'player1_home',
#  'player1_win_pct_last_10',
#  'player1_win_pct_last_10_surface',
#  'player1_elo',
#  'player1_surface_elo',
#  'player1_blended_elo',
#  'player1_CO_1st_serve_in_pct_avg',
#  'player1_1st_serve_in_pct_avg',
#  'player1_CO_1st_serve_win_pct_avg',
#  'player1_1st_serve_win_pct_avg',
#  'player1_CO_2nd_serve_win_pct_avg',
#  'player1_2nd_serve_win_pct_avg',
#  'player1_CO_serve_games_win_pct_avg',
#  'player1_serve_games_win_pct_avg',
#  'player1_CO_ace_avg',
#  'player1_ace_avg',
#  'player1_CO_df_avg',
#  'player1_df_avg',
#  'player1_CO_1st_serve_return_win_pct_avg',
#  'player1_1st_serve_return_win_pct_avg',
#  'player1_fatigue_score',
#  'player1_tournament_wins_before',
#  'player1_tournament_losses_before']

# %%
player1_features = matches[player1_cols].values  # Convert to numpy array
player2_features = matches[player2_cols].values
env_features = matches[env_cols].values
match_outcomes = matches[target_col].values  # Target (1 for player1 win, 0 for player2 win)
player1_bet_odds = matches[player1_bet].values
player2_bet_odds = matches[player2_bet].values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
player1_features = scaler.fit_transform(player1_features)
player2_features = scaler.transform(player2_features)  
env_features = scaler.fit_transform(env_features)

# %%
player1_features
# Out:
# array([[0.10526316, 0.08571429, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.10526316, 0.08571429, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.10526316, 0.08571429, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.42105263, 0.38571429, 0.        , ..., 0.34354583, 0.08823529,
#         0.        ],
#        [0.47368421, 0.28571429, 1.        , ..., 0.40908869, 0.11764706,
#         0.        ],
#        [0.52631579, 0.45714286, 0.        , ..., 0.4261071 , 0.11764706,
#         0.        ]])

# %%
import torch

player1_features = torch.tensor(player1_features, dtype=torch.float32)
player2_features = torch.tensor(player2_features, dtype=torch.float32)
env_features = torch.tensor(env_features, dtype=torch.float32)
match_outcomes = torch.tensor(match_outcomes, dtype=torch.float32).unsqueeze(1)  # Add dimension for compatibility
player1_bet_odds = torch.tensor(player1_bet_odds, dtype=torch.float32).unsqueeze(1)
player2_bet_odds = torch.tensor(player2_bet_odds, dtype=torch.float32).unsqueeze(1)

# %%
from sklearn.model_selection import train_test_split

player1_train, player1_test, player2_train, player2_test, env_train, env_test, y_train, y_test, player1_bet_odds_train, player1_bet_odds_test, player2_bet_odds_train, player2_bet_odds_test = train_test_split(
    player1_features, player2_features, env_features, match_outcomes, player1_bet_odds, player2_bet_odds, test_size=0.2, random_state=42, stratify=match_outcomes
)
player1_train, player1_val, player2_train, player2_val, env_train, env_val, y_train, y_val, player1_bet_odds_train, player1_bet_odds_val, player2_bet_odds_train, player2_bet_odds_val = train_test_split(
    player1_train, player2_train, env_train, y_train, player1_bet_odds_train, player2_bet_odds_train, test_size=0.2, random_state=42, stratify=y_train
)
y_val.unique(return_counts=True)
# Out:
# (tensor([0., 1.]), tensor([1129, 1129]))

# %%
class PlayerEmbeddingNet(nn.Module):
    def __init__(self, player_feature_size, embedding_size, dropout, hidden_sizes):
        super(PlayerEmbeddingNet, self).__init__()
        
        # Dynamically build the layers
        layers = []
        input_size = player_feature_size
        
        for hidden_size in hidden_sizes:
            layers.append(nn.Linear(input_size, hidden_size))
            layers.append(nn.BatchNorm1d(hidden_size))  # Batch normalization
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout))  # Regularization
            input_size = hidden_size
        
        # Add the final layer to project to the embedding size
        layers.append(nn.Linear(input_size, embedding_size))
        layers.append(nn.BatchNorm1d(embedding_size))  # Normalize embeddings
        
        # Define the network
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)  # Output: player embedding

# %%
class SymmetricNNWithEnvInteraction(nn.Module):
    def __init__(self, player_feature_size, env_feature_size, embedding_size, hidden_sizes, dropout, embedding_hidden_sizes=[32]):
        """
        Args:
            player_feature_size (int): Number of features for each player.
            env_feature_size (int): Number of environmental features.
            embedding_size (int): Size of the player embedding.
            hidden_sizes (list[int]): List of hidden layer sizes. Each entry adds one hidden layer.
        """
        super(SymmetricNNWithEnvInteraction, self).__init__()
        
        # Shared subnetwork for player stats
        self.shared_player_net = PlayerEmbeddingNet(player_feature_size, embedding_size, dropout, embedding_hidden_sizes)
        
        # Dynamically build the final network
        layers = []
        input_size = embedding_size * 2 + env_feature_size
        for hidden_size in hidden_sizes:
            layers.append(nn.Linear(input_size, hidden_size))  # Hidden layer
            layers.append(nn.ReLU())                          # Activation
            layers.append(nn.Dropout(dropout))                    # Dropout
            input_size = hidden_size  # Update input size for the next layer
        
        # Output layer
        layers.append(nn.Linear(input_size, 1))  # Final layer
        layers.append(nn.Sigmoid())             # Output probability
        
        self.final_net = nn.Sequential(*layers)

    def forward(self, player1_features, player2_features, env_features):
        # Generate embeddings for both players
        player1_emb = self.shared_player_net(player1_features)
        player2_emb = self.shared_player_net(player2_features)
        
        # Combine embeddings symmetrically
        combined_embedding = torch.cat([
            player1_emb - player2_emb,
            torch.abs(player1_emb - player2_emb)
        ], dim=1)
        
        # Concatenate with environmental features
        final_input = torch.cat([combined_embedding, env_features], dim=1)
        
        # Pass through the dynamically built final network
        return self.final_net(final_input)

# %%
def calculate_kelly_fraction(p, odds):
    b = odds - 1  # Adjust odds to represent decimal profit
    f = (p * b - (1 - p)) / b
    return max(f, 0)  # Only bet if f > 0

# %%
def calculate_roi(predictions, avgW, avgL, y_true, max_bet=1.0):
    total_bet = 0
    net_profit = 0

    flat_predictions = [item[0] for item in predictions]  # Flatten predictions
    flat_avgW = [item[0] for item in avgW]               # Flatten avgW
    flat_avgL = [item[0] for item in avgL]               # Flatten avgL
    flat_y_true = [item[0] for item in y_true]           # Flatten y_true
    
    for prob, odds_w, odds_l, actual in zip(flat_predictions, flat_avgW, flat_avgL, flat_y_true):
        # Your logic here
        if odds_w is None or odds_l is None:
            continue
        # Decide the bet
        if prob >= 0.5:  # Predicted winner
            odds = odds_w
            kelly_fraction = calculate_kelly_fraction(prob, odds)
            outcome = 1 if actual == 1 else -1
        else:  # Predicted loser
            odds = odds_l
            kelly_fraction = calculate_kelly_fraction(1 - prob, odds)
            outcome = 1 if actual == 0 else -1

        # Fixed max bet
        bet_amount = kelly_fraction * max_bet
        if bet_amount > 0:
            total_bet += bet_amount
            if outcome == 1:  # Bet won
                net_profit += bet_amount * (odds - 1)
            else:  # Bet lost
                net_profit -= bet_amount
    roi = net_profit / total_bet if total_bet > 0 else 0
    print(net_profit, total_bet)
    return roi

# %%
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch
import random
import numpy as np
# Set random seed for reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(42)

# Best Configuration: {'batch_size': 64, 'dropout': np.float64(0.25476497662909336), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.008841074088520707), 'optimizer': 'Adam', 'weight_decay': np.float64(5.315656057158321e-06)}
# Best Validation Accuracy: 0.6678
# Create DataLoader for training

train_dataset = TensorDataset(player1_train, player2_train, env_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# Validation DataLoader
val_dataset = TensorDataset(player1_val, player2_val, env_val, y_val, player1_bet_odds_val, player2_bet_odds_val)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# Initialize the model
model = SymmetricNNWithEnvInteraction(
    player_feature_size=player1_train.shape[1],
    env_feature_size=env_train.shape[1],
    embedding_size=8,   
    hidden_sizes=[64, 32, 16],
    dropout=np.float64(0.25476497662909336)
)

# Define weight initialization
def initialize_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        nn.init.zeros_(m.bias)

model.apply(initialize_weights)

# Define optimizer and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=np.float64(0.008841074088520707),  weight_decay=np.float64(5.315656057158321e-06))
criterion = nn.BCELoss()  # Binary Cross-Entropy Loss

    
    
 # Training loop
best_val_accuracy = 0.0
for epoch in range(20):
    model.train()
    epoch_loss = 0.0
    for p1, p2, env, labels in train_loader:
        optimizer.zero_grad()
        predictions = model(p1, p2, env)
        loss = criterion(predictions, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        epoch_loss += loss.item()
    epoch_loss /= len(train_loader)

    # Validation loop
    model.eval()
    val_loss = 0.0
    val_predictions = []
    val_y_true = []
    val_avgW = []
    val_avgL = []

    with torch.no_grad():
        for p1, p2, env, labels, avgW, avgL in val_loader:  # Add avgW, avgL in validation data
            predictions = model(p1, p2, env)
            loss = criterion(predictions, labels)
            val_loss += loss.item()
            # Collect predictions and true labels for ROI calculation
            val_predictions.extend(predictions.tolist())
            val_y_true.extend(labels.tolist())
            val_avgW.extend(avgW.tolist())
            val_avgL.extend(avgL.tolist())
    val_loss /= len(val_loader)
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for p1, p2, env, labels, a, b in val_loader:
            predictions = model(p1, p2, env)
            predicted = (predictions > 0.5).float()
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
    val_accuracy = correct / total
    print("val accuracy: ", val_accuracy)
    # Calculate validation ROI
    roi = calculate_roi(val_predictions, val_avgW, val_avgL, val_y_true, max_bet=1.0)

    print(f"Epoch {epoch + 1}: Training Loss: {epoch_loss:.4f}, Validation Loss: {val_loss:.4f}, ROI: {roi:.4%}")
# Out:
# val accuracy:  0.6470327723649247
# -15.990513424085915 178.95545921770204
# Epoch 1: Training Loss: 0.6589, Validation Loss: 0.6321, ROI: -8.9355%
# val accuracy:  0.6488042515500443
# -11.343732324939086 115.41389698220877
# Epoch 2: Training Loss: 0.6425, Validation Loss: 0.6332, ROI: -9.8287%
# val accuracy:  0.6545615589016829
# -4.010992377984639 106.67111915191396
# Epoch 3: Training Loss: 0.6389, Validation Loss: 0.6273, ROI: -3.7601%
# val accuracy:  0.6594331266607617
# -2.1696839248699744 105.42496531911702
# Epoch 4: Training Loss: 0.6357, Validation Loss: 0.6290, ROI: -2.0580%
# val accuracy:  0.6567759078830824
# -10.278599192652774 150.7125120725469
# Epoch 5: Training Loss: 0.6351, Validation Loss: 0.6237, ROI: -6.8200%
# val accuracy:  0.6479185119574845
# -16.001095485373718 195.46743102368825
# Epoch 6: Training Loss: 0.6343, Validation Loss: 0.6277, ROI: -8.1861%
# val accuracy:  0.6545615589016829
# -5.343244164740524 141.72135955186198
# Epoch 7: Training Loss: 0.6318, Validation Loss: 0.6259, ROI: -3.7702%
# val accuracy:  0.6563330380868024
# -4.795256362264188 135.85489487823207
# Epoch 8: Training Loss: 0.6290, Validation Loss: 0.6292, ROI: -3.5297%
# val accuracy:  0.6439326837909655
# -0.889342288157446 126.82358621514678
# Epoch 9: Training Loss: 0.6290, Validation Loss: 0.6299, ROI: -0.7012%
# val accuracy:  0.6558901682905226
# -6.834318903636635 114.49208614314907
# Epoch 10: Training Loss: 0.6284, Validation Loss: 0.6282, ROI: -5.9693%
# val accuracy:  0.6505757307351638
# 1.80264044323524 113.4935386563914
# Epoch 11: Training Loss: 0.6317, Validation Loss: 0.6294, ROI: 1.5883%
# val accuracy:  0.6545615589016829
# -12.868012630616573 203.16705910382007
# Epoch 12: Training Loss: 0.6352, Validation Loss: 0.6269, ROI: -6.3337%
# val accuracy:  0.6496899911426041
# -2.4942019469676953 90.89006089781977
# Epoch 13: Training Loss: 0.6288, Validation Loss: 0.6303, ROI: -2.7442%
# val accuracy:  0.6510186005314438
# -3.7255742310045115 126.79248559794966
# Epoch 14: Training Loss: 0.6281, Validation Loss: 0.6279, ROI: -2.9383%
# val accuracy:  0.6567759078830824
# -12.223756687435088 190.09940830716786
# Epoch 15: Training Loss: 0.6302, Validation Loss: 0.6232, ROI: -6.4302%
# val accuracy:  0.6532329495128433
# -11.729202492736764 181.3699955043194
# Epoch 16: Training Loss: 0.6264, Validation Loss: 0.6236, ROI: -6.4670%
# val accuracy:  0.6536758193091231
# -4.731027748939883 108.53521460306723
# Epoch 17: Training Loss: 0.6270, Validation Loss: 0.6254, ROI: -4.3590%
# val accuracy:  0.6545615589016829
# -7.482446452944438 109.07585961034133
# Epoch 18: Training Loss: 0.6288, Validation Loss: 0.6270, ROI: -6.8599%
# val accuracy:  0.6558901682905226
# -4.005946654464524 139.1543045000264
# Epoch 19: Training Loss: 0.6283, Validation Loss: 0.6260, ROI: -2.8788%
# val accuracy:  0.6563330380868024
# -4.299913488203119 97.74308635282455
# Epoch 20: Training Loss: 0.6284, Validation Loss: 0.6304, ROI: -4.3992%

# %%
from sklearn.model_selection import ParameterSampler
import scipy.stats as stats
set_seed(42)

# Parameter grid for random search
param_grid = {
    'learning_rate': stats.loguniform(1e-5, 1e-2),
    'dropout': stats.uniform(0.1, 0.6),
    'hidden_layer_sizes': [
        [128], [256, 128], [256, 128, 64], [512, 256, 128], [64], [32], [16, 8], [64, 32], [64, 64], [64, 32, 16], [64, 32, 32, 16], [256, 128, 64, 32], [512, 256, 128, 64]
    ],
    'batch_size': [32, 64, 128],
    'weight_decay': stats.loguniform(1e-6, 1e-3),
    'optimizer': ['Adam', 'SGD', 'RMSprop']
}

# Generate random hyperparameter samples
n_samples = 200
random_params = list(ParameterSampler(param_grid, n_iter=n_samples, random_state=42))

# Training and evaluation function
def train_and_evaluate(params):
    print(f"Testing configuration: {params}")
    
    # Extract parameters
    learning_rate = params['learning_rate']
    dropout = params['dropout']
    hidden_layer_sizes = params['hidden_layer_sizes']
    batch_size = params['batch_size']
    weight_decay = params['weight_decay']
    optimizer_choice = params['optimizer']
    
    # DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Model
    model = SymmetricNNWithEnvInteraction(
        player_feature_size=player1_train.shape[1],
        env_feature_size=env_train.shape[1],
        embedding_size=8,
        hidden_sizes=hidden_layer_sizes,
        dropout=dropout
    )
    
    # Initialize weights
    def initialize_weights(m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            nn.init.zeros_(m.bias)
    model.apply(initialize_weights)

    # Optimizer
    if optimizer_choice == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    elif optimizer_choice == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=weight_decay, momentum=0.9)
    elif optimizer_choice == 'RMSprop':
        optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate, weight_decay=weight_decay)


    # Loss function
    criterion = nn.BCELoss()

     # Training loop
    for epoch in range(20):
        model.train()
        for p1, p2, env, labels in train_loader:
            optimizer.zero_grad()
            predictions = model(p1, p2, env)
            loss = criterion(predictions, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
    
    # Validation loop to calculate ROI
    model.eval()
    val_predictions = []
    val_y_true = []
    val_avgW = []
    val_avgL = []

    with torch.no_grad():
        for p1, p2, env, labels, avgW, avgL in val_loader:
            predictions = model(p1, p2, env)
            val_predictions.extend(predictions.tolist())
            val_y_true.extend(labels.tolist())
            val_avgW.extend(avgW.tolist())
            val_avgL.extend(avgL.tolist())

    # Calculate ROI
    roi = calculate_roi(val_predictions, val_avgW, val_avgL, val_y_true, max_bet=1.0)
    print(f"Validation ROI for this configuration: {roi:.4%}")
    return roi, model

# Run random search
best_params = None
best_val_roi = float('-inf')  # Start with negative infinity for maximization
best_model = None

for params in random_params:
    val_roi, model = train_and_evaluate(params)
    if val_roi > best_val_roi:
        best_val_roi = val_roi
        best_params = params
        best_model = model

# Save the best model weights and configuration
if best_model is not None:
    torch.save(best_model.state_dict(), os.path.join("best_models", "best_model_weights.pth"))
    with open(os.path.join("best_models", "best_config.txt"), "w") as f:
        f.write(f"Best Configuration:\n{best_params}\n")
        f.write(f"Best Validation ROI: {best_val_roi:.4%}\n")

print(f"Best Configuration: {best_params}")
print(f"Best Validation ROI: {best_val_roi:.4%}")
# Out:
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5779257921161397), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.0021830968390524606), 'optimizer': 'Adam', 'weight_decay': np.float64(2.9380279387035354e-06)}
# -0.3563399057850133 71.57519205714021
# Validation ROI for this configuration: -0.4979%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.15998494949080172), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.003967605077052989), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.1527987128232402e-06)}
# -10.762784995292835 117.74114308648157
# Validation ROI for this configuration: -9.1411%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5331992633600948), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(1.0053940194693018e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(7.119418600172983e-05)}
# -29.669320264701142 401.01249282786273
# Validation ROI for this configuration: -7.3986%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4148538589793427), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(1.1727009450102244e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(6.847920095574779e-05)}
# -6.574360591412016 109.37163528644393
# Validation ROI for this configuration: -6.0110%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.12799939792816925), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.00012562773503807024), 'optimizer': 'SGD', 'weight_decay': np.float64(1.8699039697141515e-06)}
# -15.625456793656253 174.42914619537274
# Validation ROI for this configuration: -8.9581%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21980426929501584), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00890620438616168), 'optimizer': 'Adam', 'weight_decay': np.float64(1.3783237455007196e-06)}
# 2.861683790994597 113.54184292956047
# Validation ROI for this configuration: 2.5204%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5081845231526678), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(1.5673095467235405e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0007886714129990489)}
# -19.028735535826637 147.0741390684159
# Validation ROI for this configuration: -12.9382%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3312499015239496), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(1.9634341572933304e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.0001121477478415947)}
# -19.357393191709875 139.83849837631027
# Validation ROI for this configuration: -13.8427%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5999169470416986), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.00534516611064682), 'optimizer': 'SGD', 'weight_decay': np.float64(9.717775305059631e-05)}
# -6.84131096899324 71.30932502334268
# Validation ROI for this configuration: -9.5939%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.35509352469474686), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00043664735929796326), 'optimizer': 'SGD', 'weight_decay': np.float64(1.241480428274396e-06)}
# -12.5933916554919 138.86740644014563
# Validation ROI for this configuration: -9.0686%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5650796940166687), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00015326772391384085), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00015199034037054093)}
# -28.08417139764117 174.87292988141988
# Validation ROI for this configuration: -16.0598%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.1530955012311517), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00036517646487517567), 'optimizer': 'SGD', 'weight_decay': np.float64(9.462175356461487e-06)}
# -20.50778064258308 156.1336114568775
# Validation ROI for this configuration: -13.1348%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2628094190643375), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0005757759187507043), 'optimizer': 'Adam', 'weight_decay': np.float64(6.963114377829292e-06)}
# -5.715867771944536 115.50779451783156
# Validation ROI for this configuration: -4.9485%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.18455453498485758), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(1.6736010167825783e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.8629639119246215e-05)}
# -13.34772167421895 118.61683253598038
# Validation ROI for this configuration: -11.2528%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.21922940892050344), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(1.1021468611551662e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.00013199942261535007)}
# -16.80114892788406 186.43906144276713
# Validation ROI for this configuration: -9.0116%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5741053243187234), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(1.667761543019792e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(8.979064194712974e-05)}
# -24.014523936464887 262.06583101950247
# Validation ROI for this configuration: -9.1635%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6100231466738796), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(9.833181933644887e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(8.569331925053988e-06)}
# -8.772370722123243 248.12347163609195
# Validation ROI for this configuration: -3.5355%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5377637070028385), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(6.670607370178194e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(2.6100256506134754e-05)}
# 1.3010869632951254 86.91222984865668
# Validation ROI for this configuration: 1.4970%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6830272572334622), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.0019158219548093154), 'optimizer': 'SGD', 'weight_decay': np.float64(5.104518230902804e-06)}
# -11.993223775677492 90.82729590082322
# Validation ROI for this configuration: -13.2044%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3962773578186345), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0013551540552976555), 'optimizer': 'SGD', 'weight_decay': np.float64(1.1919481947918734e-06)}
# -12.049927451265068 91.14801150121744
# Validation ROI for this configuration: -13.2202%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.22103152140123772), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0002667538336169917), 'optimizer': 'Adam', 'weight_decay': np.float64(3.35515102272148e-05)}
# -10.400970032698794 102.22606289583662
# Validation ROI for this configuration: -10.1745%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.18359887264352542), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0001702741688676439), 'optimizer': 'RMSprop', 'weight_decay': np.float64(4.066152607618113e-06)}
# -13.827816622028573 97.80725113392809
# Validation ROI for this configuration: -14.1378%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.1461879458972758), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.001214380539778398), 'optimizer': 'SGD', 'weight_decay': np.float64(7.465555774745703e-05)}
# -7.802190085533046 94.56659516679058
# Validation ROI for this configuration: -8.2505%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4800422539062541), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0002342090710043416), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00044651985676577956)}
# -20.697063399906668 131.73344043787867
# Validation ROI for this configuration: -15.7113%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.17325277282040402), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(8.995191735587162e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(6.552344878295667e-06)}
# -5.235917608258118 111.34875600675866
# Validation ROI for this configuration: -4.7023%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.35626467317575383), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.00011421064100297755), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.0491954332267908e-06)}
# -8.888764452137272 100.4333149174154
# Validation ROI for this configuration: -8.8504%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.35044660188926735), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0011948354480999254), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0300196600986763e-05)}
# -3.1986589539333212 113.56388002649574
# Validation ROI for this configuration: -2.8166%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.20097462530375834), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0012854549964879019), 'optimizer': 'Adam', 'weight_decay': np.float64(1.5655853232456835e-06)}
# -9.894910519250274 132.526458065165
# Validation ROI for this configuration: -7.4664%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6774683769652667), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0003102740950912838), 'optimizer': 'Adam', 'weight_decay': np.float64(2.7813829613946124e-06)}
# -17.440575300434883 250.70656635078583
# Validation ROI for this configuration: -6.9566%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.260068608565171), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0003221343740912344), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2564702171144143e-06)}
# -12.869916797874325 120.5949229758528
# Validation ROI for this configuration: -10.6720%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.48061080682081825), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0003915648958243002), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0009056311714376344)}
# -10.747852855455633 99.00340342370747
# Validation ROI for this configuration: -10.8560%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5032813284435271), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.0001285178253319705), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00015298506868937454)}
# -9.5951293439988 262.76819944584844
# Validation ROI for this configuration: -3.6516%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4793834983561477), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00015720752387932209), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.8658181360124843e-06)}
# -6.007165693394853 76.2657869156823
# Validation ROI for this configuration: -7.8766%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.19043052637925767), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(3.627066608804409e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00037590353898082695)}
# -8.365626362061272 109.44964856785931
# Validation ROI for this configuration: -7.6434%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.232144628539329), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0003437788661779579), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.1117265099859662e-05)}
# -10.555364382055886 85.76444695149961
# Validation ROI for this configuration: -12.3074%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.20461985740299488), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.000155853321857154), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.0006459367085984855)}
# -16.670403124383572 124.44930339695333
# Validation ROI for this configuration: -13.3953%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5054140702235684), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(2.1898812429056927e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(4.2105993732656564e-05)}
# -29.551654688287037 145.93294866736386
# Validation ROI for this configuration: -20.2502%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.25476497662909336), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(3.348611630346182e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(3.547379678619787e-05)}
# -11.493075757638122 113.10449718272379
# Validation ROI for this configuration: -10.1615%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24511137454027102), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.00047302093349336854), 'optimizer': 'RMSprop', 'weight_decay': np.float64(3.682318289576365e-06)}
# -2.8021770473189305 76.17724703076492
# Validation ROI for this configuration: -3.6785%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.30952574476759653), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.00370657571211), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00021858816162324157)}
# -6.058186528495986 85.39832300327667
# Validation ROI for this configuration: -7.0940%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6613809965325684), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.004962066332418387), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0655924993232579e-06)}
# -17.991239510155843 78.00866212503543
# Validation ROI for this configuration: -23.0631%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.664080065474667), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(1.0355826161899173e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(4.4279363365000904e-05)}
# -27.50316168339162 411.3540283326038
# Validation ROI for this configuration: -6.6860%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3690544857917484), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(4.70769077431769e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1329900368822802e-06)}
# -5.200465517889895 99.20365110901744
# Validation ROI for this configuration: -5.2422%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2952398188955606), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.00012572057357983696), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.0001454855207016414)}
# -11.695270076350283 101.75706900669005
# Validation ROI for this configuration: -11.4933%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.42552413833293956), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.00012680822080429405), 'optimizer': 'RMSprop', 'weight_decay': np.float64(5.641381315708957e-06)}
# 1.1839072229434755 69.87312435703775
# Validation ROI for this configuration: 1.6944%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6838063328514673), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(0.0002885535747082005), 'optimizer': 'RMSprop', 'weight_decay': np.float64(2.0099400153590393e-05)}
# -5.627392233274396 54.40096604760424
# Validation ROI for this configuration: -10.3443%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.40158225586311525), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.0010157157317146237), 'optimizer': 'Adam', 'weight_decay': np.float64(3.852378615162034e-06)}
# -5.849436554094715 109.44497428328872
# Validation ROI for this configuration: -5.3446%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3995160279308514), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(1.1828996391101272e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.3514852657379037e-06)}
# -12.934508307401849 125.78057424222787
# Validation ROI for this configuration: -10.2834%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6723571462015524), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.004471796861411278), 'optimizer': 'Adam', 'weight_decay': np.float64(0.000723128604484139)}
# -9.454054359159192 109.94377908590957
# Validation ROI for this configuration: -8.5990%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3569104889903886), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0005210476092155952), 'optimizer': 'Adam', 'weight_decay': np.float64(1.682824274470241e-06)}
# -8.092282815508991 95.08887624489599
# Validation ROI for this configuration: -8.5102%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.33105863716115513), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(6.388877641195179e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(3.2246177486423724e-06)}
# -17.09945790481959 123.85141210332692
# Validation ROI for this configuration: -13.8064%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3368148800856833), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.001224868285680487), 'optimizer': 'SGD', 'weight_decay': np.float64(1.9567235921447345e-06)}
# -12.529190159328651 95.63104198250976
# Validation ROI for this configuration: -13.1016%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6940323100625579), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(5.787499242847461e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0004286661750367161)}
# -3.150649347564198 305.26171580056905
# Validation ROI for this configuration: -1.0321%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6092018769548047), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0012807142800445779), 'optimizer': 'RMSprop', 'weight_decay': np.float64(7.599334001601099e-06)}
# -4.182945115443947 99.993824066321
# Validation ROI for this configuration: -4.1832%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.35186851386776585), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.003992242886631504), 'optimizer': 'Adam', 'weight_decay': np.float64(1.7570436113703507e-06)}
# -11.94582969352146 144.58108062163137
# Validation ROI for this configuration: -8.2624%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.40090977681231976), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(3.826677479763703e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0002439933603572919)}
# -39.23502135188178 278.9529741520049
# Validation ROI for this configuration: -14.0651%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3027970941109215), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.000545248759924117), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.00010377157441891256)}
# -7.046035070935453 69.38091024661625
# Validation ROI for this configuration: -10.1556%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3793588108794761), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(0.0032870060709777288), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2345274466024463e-06)}
# -9.250740274727008 93.84738655062533
# Validation ROI for this configuration: -9.8572%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.593560336395795), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0004085519442448727), 'optimizer': 'Adam', 'weight_decay': np.float64(3.687480905792534e-05)}
# -7.171761314631062 87.93886597548492
# Validation ROI for this configuration: -8.1554%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2629257494918451), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.0007390459262954655), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4290425609432093e-06)}
# -8.910897620746564 108.48118264226771
# Validation ROI for this configuration: -8.2142%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.42438107296606387), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(2.6005144855575935e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0008102342569581549)}
# -14.440887407259956 189.6617120126641
# Validation ROI for this configuration: -7.6140%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.29377388376474756), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0001572036785737579), 'optimizer': 'RMSprop', 'weight_decay': np.float64(2.0745039310086577e-05)}
# -13.174811234906805 118.76634421758871
# Validation ROI for this configuration: -11.0931%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2505163164079967), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.007725831714587859), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.927273832483683e-05)}
# -10.043897786240969 155.25943023245728
# Validation ROI for this configuration: -6.4691%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.13491615730506618), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(2.946531769463084e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(5.240371517221391e-06)}
# -14.937377288862416 196.22113656318118
# Validation ROI for this configuration: -7.6125%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5287575536200374), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0063656387975889565), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0007321428778380783)}
# -6.034631952275948 103.23426207107508
# Validation ROI for this configuration: -5.8456%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.49426679710010013), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0006841671828013816), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.3904276100386608e-06)}
# -3.7686822603641104 82.3230866588223
# Validation ROI for this configuration: -4.5779%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.31358360719075695), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(2.2934746458906674e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(2.2295536203910113e-06)}
# -9.589415412608437 150.7838400779258
# Validation ROI for this configuration: -6.3597%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.15649419296113606), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(3.357305095994099e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0001950263393033)}
# -14.234323813279264 115.72779952472885
# Validation ROI for this configuration: -12.2998%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.38408306246833945), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0002477544357860111), 'optimizer': 'Adam', 'weight_decay': np.float64(1.5686071966628896e-05)}
# -10.439522948478892 90.24420543013002
# Validation ROI for this configuration: -11.5681%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6694874389548315), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(1.3674518065224915e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.1115106310605993e-06)}
# -5.26313544164717 121.45660068444334
# Validation ROI for this configuration: -4.3333%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4018817551480526), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0004150805133739244), 'optimizer': 'Adam', 'weight_decay': np.float64(3.0817917005205634e-06)}
# -12.758909095094513 115.06699110440994
# Validation ROI for this configuration: -11.0882%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6665509582751004), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.000571908753518847), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.0002528412239850358)}
# -0.3750789877889189 74.90604965913876
# Validation ROI for this configuration: -0.5007%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.44402022500315996), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00023700563480372539), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.00028967994358600045)}
# -4.94177013852954 94.38894044105224
# Validation ROI for this configuration: -5.2355%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5922561062627608), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.005200581729114121), 'optimizer': 'Adam', 'weight_decay': np.float64(1.6146704696224922e-06)}
# 0.25412809570586936 137.12986765524118
# Validation ROI for this configuration: 0.1853%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3263554499367855), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(1.9201222592871423e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.0224984178178779e-05)}
# -12.40094930849981 123.54262576585802
# Validation ROI for this configuration: -10.0378%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.29138537817625676), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0011087688261177291), 'optimizer': 'SGD', 'weight_decay': np.float64(0.000277591042418819)}
# -10.563765982555323 105.44131052508168
# Validation ROI for this configuration: -10.0186%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.39762247257604366), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0012308680425397655), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0006455716578617576)}
# -11.404162827299182 127.64579433559751
# Validation ROI for this configuration: -8.9342%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5820885582309091), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0004404693056456518), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00017858470261618843)}
# -6.3896412451805125 68.23374031717489
# Validation ROI for this configuration: -9.3643%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.694303085200404), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.00013063340811682268), 'optimizer': 'RMSprop', 'weight_decay': np.float64(5.5160988091309545e-05)}
# -0.1697413160244932 85.84356326664582
# Validation ROI for this configuration: -0.1977%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6584543953621388), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(5.1974531032483503e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.00017890117928710345)}
# -3.0674240696509742 125.94945961661547
# Validation ROI for this configuration: -2.4354%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24294169144238767), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00040085049163922815), 'optimizer': 'Adam', 'weight_decay': np.float64(9.123233767937076e-06)}
# -3.0472250498675257 126.76110198258985
# Validation ROI for this configuration: -2.4039%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.15999093229711803), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(1.0777374007231586e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0003478799766775243)}
# -5.325839334486268 160.92484112321642
# Validation ROI for this configuration: -3.3095%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2915881825542489), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.0005251866335241127), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.777678555991064e-06)}
# -13.322104312613174 134.4841924373197
# Validation ROI for this configuration: -9.9061%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2759264630188387), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00045825705211138113), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0001807688471444607)}
# -11.498461433280077 100.51745098206933
# Validation ROI for this configuration: -11.4393%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5687776302827215), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(1.877665856576684e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0008370369418545595)}
# -62.41871478169276 397.5449522684836
# Validation ROI for this configuration: -15.7010%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.42971732939424134), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0016259480681891795), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1291328372260006e-05)}
# -6.250359727823838 141.99914628570647
# Validation ROI for this configuration: -4.4017%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6811911663844809), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0019254484473270926), 'optimizer': 'Adam', 'weight_decay': np.float64(2.0107960728626184e-06)}
# -2.18587480999845 70.68320414512239
# Validation ROI for this configuration: -3.0925%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.35565488502816467), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(1.653061529917773e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00047390438403936333)}
# -31.23614381437616 283.65836500941253
# Validation ROI for this configuration: -11.0119%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.14880926838513986), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(5.0082294452713506e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2939766550813196e-05)}
# -11.803905754026077 142.67058820465078
# Validation ROI for this configuration: -8.2735%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6683491464303152), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0005965766024488798), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00013321207301714318)}
# -9.220573617656285 80.49654964199999
# Validation ROI for this configuration: -11.4546%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.566288149556462), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0013039264435721995), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0005236765843156189)}
# -13.401575918196597 114.47097921347213
# Validation ROI for this configuration: -11.7074%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.36067110669296276), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(1.0815856940648098e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4754001628061713e-06)}
# -47.860720730360114 249.0224702656079
# Validation ROI for this configuration: -19.2194%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5936742111260158), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0017303527113379845), 'optimizer': 'Adam', 'weight_decay': np.float64(5.158452239241319e-06)}
# -6.155213948783025 58.76672789538113
# Validation ROI for this configuration: -10.4740%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.32492234771422246), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(1.7728580556091035e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(4.6858406496824244e-06)}
# -17.419436604257378 154.43918655493943
# Validation ROI for this configuration: -11.2792%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5812655494160405), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(0.00812150432873865), 'optimizer': 'Adam', 'weight_decay': np.float64(9.290929504070812e-06)}
# 0.9449960894376161 58.982360577931345
# Validation ROI for this configuration: 1.6022%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6547859981341576), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(1.664905907163967e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.00012196448023200595)}
# -7.430202264693887 255.0613214623823
# Validation ROI for this configuration: -2.9131%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.41385870650208934), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(4.471233183495585e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(2.310059649904301e-05)}
# -10.29267710887236 94.05344674193836
# Validation ROI for this configuration: -10.9434%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5181550335182888), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.005052124349891388), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0005568818006274345)}
# 3.496437392048883 76.29882181271249
# Validation ROI for this configuration: 4.5826%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6702468904459352), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00015260381674960595), 'optimizer': 'Adam', 'weight_decay': np.float64(6.7942816938428095e-06)}
# -18.34090385862917 94.5817399168594
# Validation ROI for this configuration: -19.3916%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.33296103039392333), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.0005635965624549062), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0008378850141664129)}
# -5.028712089130896 119.89531634609676
# Validation ROI for this configuration: -4.1943%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.518897028411847), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(6.907016945696069e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0002763026556593476)}
# -9.904966383519055 104.37274912499696
# Validation ROI for this configuration: -9.4900%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.1799110751342498), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.0029350244859083895), 'optimizer': 'SGD', 'weight_decay': np.float64(1.777940296540047e-05)}
# -12.345092240446585 127.11653252348465
# Validation ROI for this configuration: -9.7116%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.46804911756147394), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(1.7711088782735673e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0003964529634406677)}
# -13.708373054672812 158.57704836365207
# Validation ROI for this configuration: -8.6446%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.19890055668220058), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0001347069802638634), 'optimizer': 'Adam', 'weight_decay': np.float64(2.7612787175114943e-05)}
# -8.325880336687769 92.79775252606015
# Validation ROI for this configuration: -8.9721%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.19025013466211693), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0017731068186487243), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0008123500161567048)}
# -5.112462325731506 137.85638758356902
# Validation ROI for this configuration: -3.7085%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4414488814994486), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0002547296385667093), 'optimizer': 'RMSprop', 'weight_decay': np.float64(2.5209042845955456e-06)}
# -6.532837047557374 93.5164271548435
# Validation ROI for this configuration: -6.9858%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.13382529799055626), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0011888941538614243), 'optimizer': 'Adam', 'weight_decay': np.float64(0.000998051656641731)}
# -11.250713040134855 145.98366086553395
# Validation ROI for this configuration: -7.7068%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6478994513545857), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0020275064549386645), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00018674268813625796)}
# -5.513515048479633 53.58408143668879
# Validation ROI for this configuration: -10.2895%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.24840886104591858), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(2.4404968163647497e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(6.6710683613066355e-06)}
# -19.85321364443391 137.03422782531382
# Validation ROI for this configuration: -14.4878%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6269324004875153), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0007151295457181831), 'optimizer': 'RMSprop', 'weight_decay': np.float64(2.1911533674189203e-06)}
# -4.9553209687993744 73.99707909125601
# Validation ROI for this configuration: -6.6966%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3988991119875358), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00207469937066435), 'optimizer': 'RMSprop', 'weight_decay': np.float64(8.381692413704328e-06)}
# -8.244278088017627 123.57869307022897
# Validation ROI for this configuration: -6.6713%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4311441032646913), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(1.841724519709937e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.6234861897604046e-05)}
# -21.63126768843464 140.18853397112954
# Validation ROI for this configuration: -15.4301%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.11726960578800338), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0007259866824755671), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00026009619721459966)}
# -20.947739902786257 150.4836857492052
# Validation ROI for this configuration: -13.9203%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.18182288535206187), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.008737519847726189), 'optimizer': 'SGD', 'weight_decay': np.float64(5.885089345740327e-05)}
# -5.218822336844884 109.44726794958014
# Validation ROI for this configuration: -4.7683%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4328893651253354), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.005157937596208984), 'optimizer': 'Adam', 'weight_decay': np.float64(3.4831202446644246e-05)}
# -2.4138242487291186 137.7234844448665
# Validation ROI for this configuration: -1.7527%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3379256693927621), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00037222610516825764), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0007056053596739238)}
# -10.928349934662817 89.63539013770422
# Validation ROI for this configuration: -12.1920%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6559525750968966), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.002026530871125825), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0008711595980645578)}
# -4.3792478373194035 73.28358448342875
# Validation ROI for this configuration: -5.9758%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3084480449352485), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.0005482135976853446), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.688845746279721e-06)}
# -3.147360106268742 101.18270294750276
# Validation ROI for this configuration: -3.1106%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3760714953901432), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(2.6090446888493444e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0004901908831315694)}
# -30.81114893572613 203.52053011189201
# Validation ROI for this configuration: -15.1391%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.40914163291852657), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.000639449403565431), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.3261903052572606e-06)}
# -2.912530355727254 115.29387446531443
# Validation ROI for this configuration: -2.5262%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.307049576693432), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(3.396498701004281e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(4.427371118089804e-05)}
# -18.018170803280892 100.41327752545966
# Validation ROI for this configuration: -17.9440%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.37646726081963544), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.004815615334144284), 'optimizer': 'Adam', 'weight_decay': np.float64(3.237813373628106e-05)}
# 3.7155129833190625 117.48972376959303
# Validation ROI for this configuration: 3.1624%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2929496588080174), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0025016767752510135), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00011570553940015657)}
# -8.917141607535385 102.80989435534744
# Validation ROI for this configuration: -8.6734%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.19418660962971623), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(1.0180874247652735e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.79287917621631e-06)}
# -10.83562100402153 162.96180309188412
# Validation ROI for this configuration: -6.6492%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2107126116138264), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0002841639333505349), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00019048738804360626)}
# -3.871648586684076 170.5318862993062
# Validation ROI for this configuration: -2.2703%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.37752082967988876), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(1.5382399542566003e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(5.718878014855691e-06)}
# -18.473004805699443 134.55867311375923
# Validation ROI for this configuration: -13.7286%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5122993032419987), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0003427933011298978), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.2342878621258998e-06)}
# 4.639202267115822 100.24576609755772
# Validation ROI for this configuration: 4.6278%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.36844742009407283), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.00015541448638894275), 'optimizer': 'Adam', 'weight_decay': np.float64(0.000163010514546)}
# -9.209959127473352 71.42924561920209
# Validation ROI for this configuration: -12.8938%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4383790552113018), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(4.308677819182366e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(4.036516127900801e-05)}
# -31.92992468742743 173.97424726038983
# Validation ROI for this configuration: -18.3532%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6343163684439369), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.0002641860151813428), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00023308467265656605)}
# -10.263952503973469 184.5511586986561
# Validation ROI for this configuration: -5.5616%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.38774926105255014), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.00040862000564111903), 'optimizer': 'SGD', 'weight_decay': np.float64(4.712233450454001e-05)}
# -12.383222147492713 117.76040183216388
# Validation ROI for this configuration: -10.5156%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4386751255135848), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(7.101134154276113e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.000499967980239712)}
# -1.7316083742905244 257.7845597332845
# Validation ROI for this configuration: -0.6717%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2466118932787927), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.009110574133808462), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0006325217608524989)}
# -4.083497751944532 147.82010668332381
# Validation ROI for this configuration: -2.7625%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.16106948357224224), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0001247585903534619), 'optimizer': 'SGD', 'weight_decay': np.float64(3.6282823166258323e-06)}
# -26.515967107290574 153.53285240460318
# Validation ROI for this configuration: -17.2705%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5835189320446861), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.004901130584259784), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.4285861442639356e-06)}
# -18.10788818738441 222.25247225382685
# Validation ROI for this configuration: -8.1474%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.34623809619379686), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.009812204802186949), 'optimizer': 'SGD', 'weight_decay': np.float64(1.561589201432928e-05)}
# -8.598459463649313 83.72334248568168
# Validation ROI for this configuration: -10.2701%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6193042755363881), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.008417855934402044), 'optimizer': 'SGD', 'weight_decay': np.float64(3.255837808893694e-06)}
# -12.674782890094994 79.90549324552998
# Validation ROI for this configuration: -15.8622%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5925168838920115), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0004680461519589531), 'optimizer': 'SGD', 'weight_decay': np.float64(6.917310667555201e-06)}
# -21.956921854530815 111.67715638424819
# Validation ROI for this configuration: -19.6611%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.21222624913451404), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.001357867633588999), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00016171174037105194)}
# -9.916608948056103 139.50670522021716
# Validation ROI for this configuration: -7.1083%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5243380573866667), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0005542614381064704), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.0006252346334537663)}
# -4.439938373649256 83.39362296723216
# Validation ROI for this configuration: -5.3241%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4195536595309515), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00012814198421127212), 'optimizer': 'SGD', 'weight_decay': np.float64(4.423941279705387e-05)}
# -14.712100694362263 135.0402678638609
# Validation ROI for this configuration: -10.8946%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6939761394339671), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(0.0011316565556970905), 'optimizer': 'Adam', 'weight_decay': np.float64(2.6090014491512547e-06)}
# -5.678784464380131 59.40696633035178
# Validation ROI for this configuration: -9.5591%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5561367159338119), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.00026272330763465047), 'optimizer': 'SGD', 'weight_decay': np.float64(1.719977407917786e-05)}
# -8.833699744417327 254.4099814320738
# Validation ROI for this configuration: -3.4722%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.16401955006806163), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.003103546261460404), 'optimizer': 'SGD', 'weight_decay': np.float64(2.3598895136582365e-06)}
# -10.012265544535788 127.59114476321403
# Validation ROI for this configuration: -7.8471%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6630042740926226), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.00013730481106870182), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0001672483908098155)}
# ...
# -3.607540288801753 62.562417177725585
# Validation ROI for this configuration: -5.7663%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5241882767460754), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.0017054495536480705), 'optimizer': 'SGD', 'weight_decay': np.float64(4.108031636599255e-06)}
# -28.833281888067496 194.11333168372434
# Validation ROI for this configuration: -14.8538%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5574752114444143), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.0018361403544674786), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0002909188847499605)}
# -17.148391593924554 239.026295835447
# Validation ROI for this configuration: -7.1743%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3272929393341494), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(2.4124925839939234e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.00024653926524984893)}
# -12.351667142154051 113.19217900637513
# Validation ROI for this configuration: -10.9121%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3918144891973647), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.0014681069857124401), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0879507025215043e-06)}
# -5.11798330844857 78.50865081346002
# Validation ROI for this configuration: -6.5190%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5163690666802601), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.0014077878873452836), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.089150713985329e-05)}
# -7.538704890280983 112.62738859576426
# Validation ROI for this configuration: -6.6935%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6754448767384166), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0005625684654372195), 'optimizer': 'RMSprop', 'weight_decay': np.float64(2.4323015184601963e-05)}
# -13.86654023863628 65.58356279832952
# Validation ROI for this configuration: -21.1433%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4689701578915927), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0005737061375884857), 'optimizer': 'SGD', 'weight_decay': np.float64(2.006244268512482e-06)}
# -25.93723082634087 208.0946551123083
# Validation ROI for this configuration: -12.4642%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.11086611029250432), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.000601019711621374), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0005854612336582596)}
# -8.935455022206494 114.07110029009002
# Validation ROI for this configuration: -7.8332%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.1915234257485568), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.00013283303914179908), 'optimizer': 'Adam', 'weight_decay': np.float64(1.872371465271093e-05)}
# -12.406698463372289 112.22965437627676
# Validation ROI for this configuration: -11.0547%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.1625481796310857), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.005980059962602604), 'optimizer': 'RMSprop', 'weight_decay': np.float64(2.3357822053558448e-06)}
# -5.215408672103636 103.65846259892113
# Validation ROI for this configuration: -5.0313%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6909047193774007), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(2.3658545631797183e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(9.91834562199159e-06)}
# -7.010254447068718 137.0002398827379
# Validation ROI for this configuration: -5.1170%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4113028342756433), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0006663205098435372), 'optimizer': 'RMSprop', 'weight_decay': np.float64(1.459771621213804e-06)}
# -4.626940842795573 80.92188623169467
# Validation ROI for this configuration: -5.7178%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2233478850253825), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(1.0325142852622369e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(2.2019218455240237e-06)}
# -14.882484702913139 145.5787471557714
# Validation ROI for this configuration: -10.2230%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6181108843677742), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00010940520471305277), 'optimizer': 'SGD', 'weight_decay': np.float64(2.7701987838040972e-05)}
# -14.082531811612196 148.99586802729502
# Validation ROI for this configuration: -9.4516%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.37133076453388425), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(1.2547003257045794e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(2.6458855905382128e-06)}
# -12.784279349453412 219.6704621850685
# Validation ROI for this configuration: -5.8198%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3990206636436878), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(1.2636810727696833e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.222310935843224e-05)}
# -17.534492227666977 172.6027058316166
# Validation ROI for this configuration: -10.1589%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.26655230357765086), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(1.0946703871181126e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(3.5117294300386954e-05)}
# -41.93286122792877 245.98791690427552
# Validation ROI for this configuration: -17.0467%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6766421904816731), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00046980334720751683), 'optimizer': 'SGD', 'weight_decay': np.float64(1.8032211984108182e-06)}
# -7.066527125303152 94.62522258009648
# Validation ROI for this configuration: -7.4679%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.21067772285131364), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0006111601825712035), 'optimizer': 'Adam', 'weight_decay': np.float64(1.555802074976316e-05)}
# -4.107896548095876 90.05357727922146
# Validation ROI for this configuration: -4.5616%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.22594335585735145), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.00011172773564975564), 'optimizer': 'SGD', 'weight_decay': np.float64(3.733044457006201e-06)}
# -12.486071592209386 152.82446799098918
# Validation ROI for this configuration: -8.1702%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3266355684641016), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0005785765302943251), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0002121206015630903)}
# -4.193652814929059 84.1449071239262
# Validation ROI for this configuration: -4.9838%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4165886380868715), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00021003334103218075), 'optimizer': 'SGD', 'weight_decay': np.float64(3.0976749693105294e-05)}
# 7.609129559405744 141.52103164161073
# Validation ROI for this configuration: 5.3767%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.19314414755842751), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00010071367278536203), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.0006892017736077922)}
# -12.491823831496543 127.10598596808703
# Validation ROI for this configuration: -9.8279%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2624468038861323), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0001683458881839942), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.0008645583444926513)}
# -4.9270502610686 119.46405927297957
# Validation ROI for this configuration: -4.1243%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6201962560069141), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(1.2058352559152984e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(5.776512163025031e-06)}
# -50.90198796583534 230.55418733097042
# Validation ROI for this configuration: -22.0781%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.503135646159237), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(0.0006097431627143494), 'optimizer': 'Adam', 'weight_decay': np.float64(0.000251043080905963)}
# -2.5351584545711927 75.86990492464012
# Validation ROI for this configuration: -3.3415%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6324762895081018), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(5.182607785773114e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0002605822934359379)}
# -3.387247665243385 263.53057788244814
# Validation ROI for this configuration: -1.2853%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.46191844130618775), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(0.007725879952983427), 'optimizer': 'Adam', 'weight_decay': np.float64(2.649998001012157e-06)}
# 4.319078424513185 118.69223083214258
# Validation ROI for this configuration: 3.6389%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.27588863815660797), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(1.093970901921631e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.00016132951922988547)}
# -22.965878255424855 149.9394258673676
# Validation ROI for this configuration: -15.3168%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.11591932232429183), 'hidden_layer_sizes': [512, 256, 128, 64], 'learning_rate': np.float64(0.0042592411298169), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8376959227633293e-05)}
# -12.306589486088066 149.81493300093499
# Validation ROI for this configuration: -8.2145%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6463744021241823), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00010603568714526016), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0002987596859654259)}
# -18.243513703112527 130.59957127115794
# Validation ROI for this configuration: -13.9690%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.45417696550888464), 'hidden_layer_sizes': [256, 128, 64, 32], 'learning_rate': np.float64(0.0031042988191650705), 'optimizer': 'Adam', 'weight_decay': np.float64(1.6913557203040614e-05)}
# -7.1124698698809175 112.72579231315142
# Validation ROI for this configuration: -6.3095%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.31765473679956724), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(7.645348356750789e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00019535178436774233)}
# -15.835469417917036 171.69809184890755
# Validation ROI for this configuration: -9.2229%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6210807855387477), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.009038616013990274), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.00025093761607131664)}
# -3.9966814795510057 65.91222616179091
# Validation ROI for this configuration: -6.0636%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3908670202902077), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(6.397820897579585e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(7.951236285054585e-05)}
# -18.977268952102115 141.22773851702834
# Validation ROI for this configuration: -13.4374%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2308138644964519), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.003197353910755753), 'optimizer': 'SGD', 'weight_decay': np.float64(3.7763352883158246e-05)}
# -12.950260200758388 110.39793168639275
# Validation ROI for this configuration: -11.7305%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5147331145657926), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(1.1354604971432884e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(3.881369921262648e-05)}
# -26.29502422174173 345.7030448650926
# Validation ROI for this configuration: -7.6062%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.44590988530855213), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(1.5904726296047852e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(9.000386613598925e-05)}
# -26.671694726982047 222.26870655262982
# Validation ROI for this configuration: -11.9998%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5321215489793775), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(1.078915633252609e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(6.180895597327765e-06)}
# -35.44706856755679 221.30658521653518
# Validation ROI for this configuration: -16.0172%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6243340465375091), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(5.6518676276111605e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(9.888035652279e-05)}
# -14.613197281609853 198.60872574174385
# Validation ROI for this configuration: -7.3578%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4439766269076404), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00018043117389568452), 'optimizer': 'SGD', 'weight_decay': np.float64(3.603737224946194e-05)}
# -12.715376704315165 128.00296398633435
# Validation ROI for this configuration: -9.9337%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.19977002125364765), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(3.57365614010719e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(6.4484647240886e-05)}
# -8.916993724718804 117.84022793199087
# Validation ROI for this configuration: -7.5670%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.14094982321245494), 'hidden_layer_sizes': [64, 32, 32, 16], 'learning_rate': np.float64(7.346512304317996e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00014608263143976426)}
# -11.619057761105285 107.20900127085285
# Validation ROI for this configuration: -10.8378%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6695840782346594), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0009795204244055947), 'optimizer': 'SGD', 'weight_decay': np.float64(2.5409951274787355e-06)}
# -14.109379908038276 142.0756322038891
# Validation ROI for this configuration: -9.9309%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.26194673343531694), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(3.062256983127042e-05), 'optimizer': 'RMSprop', 'weight_decay': np.float64(0.00034611749186297207)}
# -12.384587402531032 119.13372953859808
# Validation ROI for this configuration: -10.3955%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4581057093501335), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0007413062346607221), 'optimizer': 'SGD', 'weight_decay': np.float64(2.088308996320748e-06)}
# -15.043286873012857 95.41841797526413
# Validation ROI for this configuration: -15.7656%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3109240966805313), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0003065306799880855), 'optimizer': 'RMSprop', 'weight_decay': np.float64(6.235311790324838e-05)}
# -6.770966084420398 91.83747008288061
# Validation ROI for this configuration: -7.3728%
# Best Configuration: {'batch_size': 128, 'dropout': np.float64(0.4165886380868715), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00021003334103218075), 'optimizer': 'SGD', 'weight_decay': np.float64(3.0976749693105294e-05)}
# Best Validation ROI: 5.3767%

# %%
from sklearn.model_selection import ParameterSampler
import scipy.stats as stats
set_seed(42)

# Parameter grid for random search
param_grid = {
    'learning_rate': stats.loguniform(1e-4, 1e-2),
    'dropout': stats.uniform(0.2, 0.4),
    'hidden_layer_sizes': [
        [128], [256, 128], [64], [32], [16, 8], [64, 32], [64, 64], [64, 32, 16], [32,32], [128,128], [64,16]
    ],
    'batch_size': [32, 64, 128],
    'weight_decay': stats.loguniform(1e-6, 1e-5),
    'optimizer': ['Adam', 'SGD'],
    'embedding_size': [4,8,16],
    'embedding_hidden_layer_sizes': [[128], [256, 128], [64], [32], [16, 8], [64, 32], [16]]
}

# Generate random hyperparameter samples
n_samples = 200
random_params = list(ParameterSampler(param_grid, n_iter=n_samples, random_state=42))

# Training and evaluation function
def train_and_evaluate(params):
    print(f"Testing configuration: {params}")
    
    # Extract parameters
    learning_rate = params['learning_rate']
    dropout = params['dropout']
    hidden_layer_sizes = params['hidden_layer_sizes']
    batch_size = params['batch_size']
    weight_decay = params['weight_decay']
    optimizer_choice = params['optimizer']
    
    # DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Model
    model = SymmetricNNWithEnvInteraction(
        player_feature_size=player1_train.shape[1],
        env_feature_size=env_train.shape[1],
        embedding_size=8,
        hidden_sizes=hidden_layer_sizes,
        dropout=dropout
    )
    
    # Initialize weights
    def initialize_weights(m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            nn.init.zeros_(m.bias)
    model.apply(initialize_weights)

    # Optimizer
    if optimizer_choice == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    elif optimizer_choice == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=weight_decay, momentum=0.9)
    elif optimizer_choice == 'RMSprop':
        optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate, weight_decay=weight_decay)


    # Loss function
    criterion = nn.BCELoss()

     # Training loop
    for epoch in range(20):
        model.train()
        for p1, p2, env, labels in train_loader:
            optimizer.zero_grad()
            predictions = model(p1, p2, env)
            loss = criterion(predictions, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
    
    # Validation loop to calculate ROI
    model.eval()
    val_predictions = []
    val_y_true = []
    val_avgW = []
    val_avgL = []

    with torch.no_grad():
        for p1, p2, env, labels, avgW, avgL in val_loader:
            predictions = model(p1, p2, env)
            val_predictions.extend(predictions.tolist())
            val_y_true.extend(labels.tolist())
            val_avgW.extend(avgW.tolist())
            val_avgL.extend(avgL.tolist())

    # Calculate ROI
    roi = calculate_roi(val_predictions, val_avgW, val_avgL, val_y_true, max_bet=1.0)
    print(f"Validation ROI for this configuration: {roi:.4%}")
    return roi, model

# Run random search
best_params = None
best_val_roi = float('-inf')  # Start with negative infinity for maximization
best_model = None

for params in random_params:
    val_roi, model = train_and_evaluate(params)
    if val_roi > best_val_roi:
        best_val_roi = val_roi
        best_params = params
        best_model = model

# Save the best model weights and configuration
if best_model is not None:
    torch.save(best_model.state_dict(), os.path.join("best_models", "best_model_weights2.pth"))
    with open(os.path.join("best_models", "best_config.txt"), "w") as f:
        f.write(f"Best Configuration:\n{best_params}\n")
        f.write(f"Best Validation ROI: {best_val_roi:.4%}\n")

print(f"Best Configuration: {best_params}")
print(f"Best Validation ROI: {best_val_roi:.4%}")
# Out:
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5186171947440932), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0015751320499779737), 'optimizer': 'Adam', 'weight_decay': np.float64(2.7914686374528733e-06)}
# -3.968212789604882 83.94855100316518
# Validation ROI for this configuration: -4.7270%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2232334448672798), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00012966511753760416), 'optimizer': 'SGD', 'weight_decay': np.float64(6.798962421591126e-06)}
# -12.335295358804888 141.32701607779916
# Validation ROI for this configuration: -8.7282%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.20031150633640574), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0004059611610484307), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0164038588691218e-06)}
# -14.129066265143905 136.7309293135699
# Validation ROI for this configuration: -10.3335%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3164916560792168), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.00012397420340784152), 'optimizer': 'SGD', 'weight_decay': np.float64(2.3246728489504338e-06)}
# -17.95191642923036 156.62761886456116
# Validation ROI for this configuration: -11.4615%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23624257381312833), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.009256818992066877), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1128853174905741e-06)}
# -3.7415124032288154 132.06904001548722
# Validation ROI for this configuration: -2.8330%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4721230154351119), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 16, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.007902619549708232), 'optimizer': 'SGD', 'weight_decay': np.float64(3.658374977026925e-06)}
# -11.377566921173884 91.21088216928608
# Validation ROI for this configuration: -12.4739%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3218455076693483), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0003034247005811288), 'optimizer': 'SGD', 'weight_decay': np.float64(1.3244581340099348e-06)}
# -18.650863974082416 128.1894468286175
# Validation ROI for this configuration: -14.5495%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5332779646944658), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 8, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00032927591344236165), 'optimizer': 'SGD', 'weight_decay': np.float64(5.693265147694793e-06)}
# -10.054080251605592 121.37401992641801
# Validation ROI for this configuration: -8.2836%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.40802720847112434), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 8, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0035503048581283078), 'optimizer': 'SGD', 'weight_decay': np.float64(2.4839922470497287e-06)}
# -9.125448152973842 88.46225750978196
# Validation ROI for this configuration: -10.3156%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4909087983425684), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0011006988685589537), 'optimizer': 'SGD', 'weight_decay': np.float64(2.115097202168558e-06)}
# -13.28335833155688 87.35863645914938
# Validation ROI for this configuration: -15.2055%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3085396127095584), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0003646439558980723), 'optimizer': 'SGD', 'weight_decay': np.float64(1.887987793138363e-06)}
# -12.15416553885756 111.11142616303081
# Validation ROI for this configuration: -10.9387%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5208787923016158), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0007027534096484147), 'optimizer': 'Adam', 'weight_decay': np.float64(1.5802131864103876e-06)}
# -5.2454133563964 64.1534908457379
# Validation ROI for this configuration: -8.1763%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5261845713819338), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0034877126245459306), 'optimizer': 'Adam', 'weight_decay': np.float64(8.439192211522155e-06)}
# -3.2691649553639843 101.65563547513719
# Validation ROI for this configuration: -3.2159%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2463476238100519), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0007923213310872082), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1575995526672769e-06)}
# -4.141739913857075 112.85573965667304
# Validation ROI for this configuration: -3.6699%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4675365010654429), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0003543590967245047), 'optimizer': 'Adam', 'weight_decay': np.float64(2.966298998700069e-06)}
# -6.1005223686328165 70.69083761312748
# Validation ROI for this configuration: -8.6299%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5886848381556415), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0013260331922696556), 'optimizer': 'Adam', 'weight_decay': np.float64(1.80330141206943e-06)}
# -7.0734508660803295 61.89299511693461
# Validation ROI for this configuration: -11.4285%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.40909313175279766), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0007562632622090496), 'optimizer': 'Adam', 'weight_decay': np.float64(1.0750512925563067e-06)}
# -4.537530554311064 84.16628745794146
# Validation ROI for this configuration: -5.3911%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3901480892728447), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00031519872951938895), 'optimizer': 'Adam', 'weight_decay': np.float64(3.4661000236991392e-06)}
# -8.435535481635318 86.83917105278663
# Validation ROI for this configuration: -9.7140%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.29151926619664903), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00021010799310103572), 'optimizer': 'SGD', 'weight_decay': np.float64(4.2106975549595465e-06)}
# -9.54523510312778 134.88348696209025
# Validation ROI for this configuration: -7.0767%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4533615026041694), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0004453382949384449), 'optimizer': 'Adam', 'weight_decay': np.float64(7.87211264452507e-06)}
# -5.727915752863264 59.74476010887427
# Validation ROI for this configuration: -9.5873%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5627313766183016), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0007148510793512986), 'optimizer': 'SGD', 'weight_decay': np.float64(2.252002437952502e-06)}
# -37.60181141615516 185.4883063847751
# Validation ROI for this configuration: -20.2718%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2027808522124763), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0024258953709486815), 'optimizer': 'SGD', 'weight_decay': np.float64(2.17578095712877e-06)}
# -12.812233321769167 97.27089211639918
# Validation ROI for this configuration: -13.1717%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.26731641686917224), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0003219814322305041), 'optimizer': 'SGD', 'weight_decay': np.float64(1.7855922645162278e-06)}
# -8.316026541602692 160.3011376453903
# Validation ROI for this configuration: -5.1878%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.48490823596977684), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00011851515660043118), 'optimizer': 'Adam', 'weight_decay': np.float64(9.475779710186507e-06)}
# -1.8966987302575253 175.43759762704303
# Validation ROI for this configuration: -1.0811%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21322029316021937), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0022983221528155035), 'optimizer': 'Adam', 'weight_decay': np.float64(3.0864039085286244e-06)}
# -19.15242630274248 185.65827907808722
# Validation ROI for this configuration: -10.3160%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2968221086046002), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0005486670911103226), 'optimizer': 'Adam', 'weight_decay': np.float64(5.348307249011089e-06)}
# -6.058862654545298 106.04735433811047
# Validation ROI for this configuration: -5.7134%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.45292233223743184), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.004294016871114837), 'optimizer': 'SGD', 'weight_decay': np.float64(6.843881726124964e-06)}
# -4.766777512766192 80.05131588298248
# Validation ROI for this configuration: -5.9547%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2746074041599417), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00044866047355907247), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0389336884578954e-06)}
# -19.487006835700356 138.6677814664002
# Validation ROI for this configuration: -14.0530%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5238004184558862), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.007604077403300607), 'optimizer': 'SGD', 'weight_decay': np.float64(2.436325699083497e-06)}
# -6.810812105893906 96.09719351344765
# Validation ROI for this configuration: -7.0874%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5350840423629313), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.00026190466946509494), 'optimizer': 'Adam', 'weight_decay': np.float64(7.539444583132283e-06)}
# -7.140391498892211 67.09097650674715
# Validation ROI for this configuration: -10.6428%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2914200087189199), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0011463075602214), 'optimizer': 'SGD', 'weight_decay': np.float64(9.914109236071422e-06)}
# -12.694816717446699 132.6515171351937
# Validation ROI for this configuration: -9.5701%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5588863031813307), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0004764963542138519), 'optimizer': 'Adam', 'weight_decay': np.float64(5.016003489764549e-06)}
# -7.398770054447092 61.14036054549068
# Validation ROI for this configuration: -12.1013%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5425297167512371), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.005033347298469074), 'optimizer': 'Adam', 'weight_decay': np.float64(1.450870712623418e-06)}
# -1.6426080103426657 81.9838411883186
# Validation ROI for this configuration: -2.0036%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4675953018856915), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.002123261760236048), 'optimizer': 'Adam', 'weight_decay': np.float64(1.922741830375281e-06)}
# -5.319241985252795 95.69713004557877
# Validation ROI for this configuration: -5.5584%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.41949351574663446), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.00022482805601745356), 'optimizer': 'SGD', 'weight_decay': np.float64(1.7268280218698493e-06)}
# -6.130697948086994 123.4796401756013
# Validation ROI for this configuration: -4.9649%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.27152908368853157), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00041316315364585784), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2407228136107147e-06)}
# -10.627788300730181 123.92162443846942
# Validation ROI for this configuration: -8.5762%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.45453304727435817), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.009073727166787787), 'optimizer': 'Adam', 'weight_decay': np.float64(7.799137106526667e-06)}
# -2.507743277840085 138.1952876878641
# Validation ROI for this configuration: -1.8146%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.37375774620417146), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.001424976719890157), 'optimizer': 'SGD', 'weight_decay': np.float64(7.314212353782314e-06)}
# -10.44286937875075 124.21305434335812
# Validation ROI for this configuration: -8.4072%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.399677351953901), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0001222383681374562), 'optimizer': 'SGD', 'weight_decay': np.float64(8.71883751827232e-06)}
# -11.987328931760006 142.1101874238574
# Validation ROI for this configuration: -8.4352%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.31182413671870346), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0080564495905871), 'optimizer': 'Adam', 'weight_decay': np.float64(2.6803045790696394e-06)}
# -2.8392722764497416 119.52568438399332
# Validation ROI for this configuration: -2.3754%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.42891698766833536), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0003880590213919323), 'optimizer': 'Adam', 'weight_decay': np.float64(1.552069023093634e-06)}
# -10.39428076292838 95.82905333060427
# Validation ROI for this configuration: -10.8467%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3267688020625111), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0074526297929126415), 'optimizer': 'SGD', 'weight_decay': np.float64(8.51171032003087e-06)}
# -9.80863232288209 92.64286356976632
# Validation ROI for this configuration: -10.5876%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23887059750830741), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00019061980918553997), 'optimizer': 'Adam', 'weight_decay': np.float64(1.9737429347913066e-06)}
# -14.031206003033018 98.92668790799725
# Validation ROI for this configuration: -14.1834%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4963074471016818), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0026171101019856905), 'optimizer': 'Adam', 'weight_decay': np.float64(1.9660377127695594e-06)}
# -8.584847392933748 137.85933927159806
# Validation ROI for this configuration: -6.2273%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.36791234257851063), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.006706271090367465), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0120101371205066e-06)}
# -4.695000169327276 74.7209593945688
# Validation ROI for this configuration: -6.2834%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.27770958140481694), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0004742314081112146), 'optimizer': 'SGD', 'weight_decay': np.float64(3.7919700238294456e-06)}
# -6.704452981502072 103.08762541202492
# Validation ROI for this configuration: -6.5036%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.46881045411807976), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0012169963323841), 'optimizer': 'Adam', 'weight_decay': np.float64(6.901341243838163e-06)}
# -3.8055937413259966 86.75823409297634
# Validation ROI for this configuration: -4.3864%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21220009997561978), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00040413924830603846), 'optimizer': 'Adam', 'weight_decay': np.float64(1.339863364992539e-06)}
# -5.699644359771901 101.10817637130414
# Validation ROI for this configuration: -5.6372%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5311476015150355), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00014814770564945435), 'optimizer': 'Adam', 'weight_decay': np.float64(1.5645160902228388e-06)}
# -4.628877827192171 61.46859251513507
# Validation ROI for this configuration: -7.5305%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.41625404864404264), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0010779551620950165), 'optimizer': 'SGD', 'weight_decay': np.float64(1.099176707572297e-06)}
# -8.606912892371659 94.274393678382
# Validation ROI for this configuration: -9.1296%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.37340829503229683), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.00011238322401194937), 'optimizer': 'Adam', 'weight_decay': np.float64(1.204683512670898e-06)}
# -7.784973786927362 99.04726430734061
# Validation ROI for this configuration: -7.8599%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4783896824374792), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.006767487390617127), 'optimizer': 'Adam', 'weight_decay': np.float64(1.779274268680342e-06)}
# -6.989862004558786 135.59823976293623
# Validation ROI for this configuration: -5.1548%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23754931603251672), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0018903454995625151), 'optimizer': 'Adam', 'weight_decay': np.float64(5.468861396433842e-06)}
# 3.2652897808006625 94.49388378878905
# Validation ROI for this configuration: 3.4556%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.37426915947115647), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00031294064907273154), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4409418256708586e-06)}
# -10.821322882732755 122.09428229119668
# Validation ROI for this configuration: -8.8631%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.20575739545190236), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00041959143915411615), 'optimizer': 'SGD', 'weight_decay': np.float64(5.054263262694104e-06)}
# -7.372885524530614 144.54350141490232
# Validation ROI for this configuration: -5.1008%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5053457692015644), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0002220259514481054), 'optimizer': 'SGD', 'weight_decay': np.float64(4.4645087928322005e-06)}
# -13.769812402148627 136.42402122511785
# Validation ROI for this configuration: -10.0934%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4463400392208866), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0005613390163158121), 'optimizer': 'SGD', 'weight_decay': np.float64(8.578992893608775e-06)}
# -9.190557719605453 95.12368188398557
# Validation ROI for this configuration: -9.6617%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.41575097936002503), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00011298547638502803), 'optimizer': 'SGD', 'weight_decay': np.float64(4.329159605151062e-06)}
# -17.91231783494567 143.71418887024538
# Validation ROI for this configuration: -12.4638%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.42934681666877333), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.004378032200510873), 'optimizer': 'SGD', 'weight_decay': np.float64(2.4327788852967082e-06)}
# -10.848097822950995 103.85553360417894
# Validation ROI for this configuration: -10.4454%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.46059390874311523), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00011965373635710245), 'optimizer': 'SGD', 'weight_decay': np.float64(4.819553143187268e-06)}
# -4.159317251270591 142.0870043714425
# Validation ROI for this configuration: -2.9273%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4622890541522969), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.00011131248325404502), 'optimizer': 'SGD', 'weight_decay': np.float64(1.8226132712395298e-06)}
# -17.44808658932035 93.33501295034083
# Validation ROI for this configuration: -18.6940%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2472659310486625), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.005687796203968948), 'optimizer': 'SGD', 'weight_decay': np.float64(2.6178576758186335e-06)}
# -13.077501650840919 100.65811952068498
# Validation ROI for this configuration: -12.9920%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3128138290285226), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0013710098263768832), 'optimizer': 'Adam', 'weight_decay': np.float64(9.783745385669451e-06)}
# -4.424725203122128 91.53919417136751
# Validation ROI for this configuration: -4.8337%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3000065796864419), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0003000500611290206), 'optimizer': 'Adam', 'weight_decay': np.float64(5.634703493906651e-06)}
# -8.065993179560648 77.32382237156612
# Validation ROI for this configuration: -10.4314%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2952944609615918), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0010244829732647415), 'optimizer': 'SGD', 'weight_decay': np.float64(2.4525512205849157e-06)}
# -7.995314164297582 105.72971184200868
# Validation ROI for this configuration: -7.5620%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5582092913984802), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.004946366454603174), 'optimizer': 'Adam', 'weight_decay': np.float64(2.0859967986741853e-06)}
# 3.4230638743956954 77.39644195686867
# Validation ROI for this configuration: 4.4228%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.47070796176972135), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0018351620695519345), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2351057604967103e-06)}
# -9.846186269608506 152.5518479426096
# Validation ROI for this configuration: -6.4543%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4214812209383203), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0036525157803808015), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2336901664320326e-06)}
# -6.398072183736253 78.48788742333014
# Validation ROI for this configuration: -8.1517%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5896992834137641), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0007639430825545341), 'optimizer': 'Adam', 'weight_decay': np.float64(3.5149226327124444e-06)}
# -4.043741390534922 59.55021442554861
# Validation ROI for this configuration: -6.7905%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.24682680657104236), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.004719845128935752), 'optimizer': 'Adam', 'weight_decay': np.float64(1.262184016150726e-06)}
# -17.493538777613143 265.2192363511252
# Validation ROI for this configuration: -6.5959%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3704365900187765), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0060784635611185744), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2060040899560858e-06)}
# -6.951840918027448 83.49891370154921
# Validation ROI for this configuration: -8.3257%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.29329122896981114), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.004222786597659888), 'optimizer': 'Adam', 'weight_decay': np.float64(8.085254715579302e-06)}
# -4.175414984434767 109.77706278001
# Validation ROI for this configuration: -3.8035%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5013512741035766), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.003583387974072159), 'optimizer': 'SGD', 'weight_decay': np.float64(5.070892038138333e-06)}
# -11.423049631570727 103.45381193509895
# Validation ROI for this configuration: -11.0417%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5625417540378944), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0003216357743681944), 'optimizer': 'SGD', 'weight_decay': np.float64(2.9421217593944137e-06)}
# -1.710983854763819 117.285118166988
# Validation ROI for this configuration: -1.4588%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.49638954436426735), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0030790965980082665), 'optimizer': 'Adam', 'weight_decay': np.float64(3.831499428350751e-06)}
# -1.2550842698120823 90.46864085325883
# Validation ROI for this configuration: -1.3873%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.36008915714880996), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.00546007057621134), 'optimizer': 'SGD', 'weight_decay': np.float64(2.7310888651949228e-06)}
# -6.75259417752195 74.5654065951469
# Validation ROI for this configuration: -9.0559%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.20486178987592654), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00012212415354459548), 'optimizer': 'Adam', 'weight_decay': np.float64(9.839313451216209e-06)}
# -14.798999645710792 132.44582474818964
# Validation ROI for this configuration: -11.1736%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.30119606719569647), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00021499623954099835), 'optimizer': 'Adam', 'weight_decay': np.float64(4.963050439824975e-06)}
# -6.283846696377664 82.30041305783557
# Validation ROI for this configuration: -7.6353%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5983325500117482), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.006343311240451776), 'optimizer': 'Adam', 'weight_decay': np.float64(8.227243319085804e-06)}
# -4.530624437408829 103.43620958671835
# Validation ROI for this configuration: -4.3801%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5801645936306234), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0002184539026816473), 'optimizer': 'SGD', 'weight_decay': np.float64(2.9086964772397663e-06)}
# -37.03094472484142 222.6044515129801
# Validation ROI for this configuration: -16.6353%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2917578982819799), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0003310546754142205), 'optimizer': 'Adam', 'weight_decay': np.float64(4.9907028682304075e-06)}
# -12.990106673588922 79.73475765519471
# Validation ROI for this configuration: -16.2916%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3119054028675783), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.004416461875953999), 'optimizer': 'SGD', 'weight_decay': np.float64(2.609991288286347e-06)}
# -6.567843955869583 95.43388141482066
# Validation ROI for this configuration: -6.8821%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.44536607837431597), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.005666605409239297), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1097334326431901e-06)}
# -8.181307904134629 103.44531867701818
# Validation ROI for this configuration: -7.9088%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.36450204663414765), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00943088086367435), 'optimizer': 'Adam', 'weight_decay': np.float64(2.3808880209277667e-06)}
# -6.00980489367381 135.69132019779707
# Validation ROI for this configuration: -4.4290%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3523563426524086), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.00137455758393629), 'optimizer': 'Adam', 'weight_decay': np.float64(2.9423420590187546e-06)}
# -6.4482353746679575 86.70014528629135
# Validation ROI for this configuration: -7.4374%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2535408475202533), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0024178468822764134), 'optimizer': 'Adam', 'weight_decay': np.float64(9.993501299743475e-06)}
# -9.457449178631999 122.34935720951893
# Validation ROI for this configuration: -7.7299%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5652663009030572), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.007754101110919913), 'optimizer': 'SGD', 'weight_decay': np.float64(2.386989723474738e-06)}
# -18.030565474072574 91.20665027844609
# Validation ROI for this configuration: -19.7689%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3802176541240374), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00035437542252607287), 'optimizer': 'SGD', 'weight_decay': np.float64(1.6929448301287222e-06)}
# -15.053687406075914 115.99961922551911
# Validation ROI for this configuration: -12.9774%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5027996528688915), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00011075656652280413), 'optimizer': 'SGD', 'weight_decay': np.float64(3.313658135010504e-06)}
# -15.46603201479075 214.98229774984455
# Validation ROI for this configuration: -7.1941%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5325485960250005), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00862874293644351), 'optimizer': 'SGD', 'weight_decay': np.float64(7.527549198597607e-06)}
# -8.917498711585512 69.98599451977009
# Validation ROI for this configuration: -12.7418%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.43598235885505443), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.003237982605211301), 'optimizer': 'Adam', 'weight_decay': np.float64(4.358743943946543e-06)}
# -3.870770403083382 96.83280762945246
# Validation ROI for this configuration: -3.9974%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2851856646035643), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.001645037108263601), 'optimizer': 'SGD', 'weight_decay': np.float64(2.4674254795084354e-06)}
# -10.477707591464693 134.57923661590624
# Validation ROI for this configuration: -7.7855%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2364008364205321), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0007976656582084649), 'optimizer': 'Adam', 'weight_decay': np.float64(2.4919698429507505e-06)}
# -7.475043944037151 112.71757581655811
# Validation ROI for this configuration: -6.6317%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4094409104060045), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0008292655346047046), 'optimizer': 'Adam', 'weight_decay': np.float64(3.1053910219894902e-06)}
# -6.1796786649197415 81.31147260031001
# Validation ROI for this configuration: -7.6000%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5920130301141908), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0014431114381789683), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1908671847454492e-06)}
# -3.681402269013252 75.23403028637236
# Validation ROI for this configuration: -4.8933%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.38404766359342885), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.002485050092084016), 'optimizer': 'SGD', 'weight_decay': np.float64(1.5201277403788455e-06)}
# -3.551389447799116 92.14628383049497
# Validation ROI for this configuration: -3.8541%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5587153639624047), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0015990822076470705), 'optimizer': 'Adam', 'weight_decay': np.float64(1.0986734160245662e-06)}
# -4.708561374240721 106.75252954786578
# Validation ROI for this configuration: -4.4107%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3380330511289547), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0001504544604259194), 'optimizer': 'Adam', 'weight_decay': np.float64(3.423130875745384e-06)}
# -13.762886940039245 89.66344972667481
# Validation ROI for this configuration: -15.3495%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5576869051583704), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 8, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.002403198571977138), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2367746820021125e-06)}
# -8.091468989396676 98.68280443872995
# Validation ROI for this configuration: -8.1995%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.45116015579636315), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.006946160292694277), 'optimizer': 'Adam', 'weight_decay': np.float64(1.005993151964207e-06)}
# -1.8241183306369688 110.19480214050829
# Validation ROI for this configuration: -1.6554%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.23380680307227278), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0002622398251592931), 'optimizer': 'Adam', 'weight_decay': np.float64(8.395407077503135e-06)}
# -13.911591091127304 109.31897161869459
# Validation ROI for this configuration: -12.7257%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4473019086121184), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.002760782051130817), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0881360604103362e-06)}
# -6.29736528806007 71.3518335684656
# Validation ROI for this configuration: -8.8258%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.485339834353821), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0011593831134486484), 'optimizer': 'Adam', 'weight_decay': np.float64(7.365716192168347e-06)}
# -3.1628365202998667 72.8092076064914
# Validation ROI for this configuration: -4.3440%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.41304690658200927), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0005682877914899339), 'optimizer': 'SGD', 'weight_decay': np.float64(3.6640812209336885e-06)}
# -7.849620710770011 85.46562796720467
# Validation ROI for this configuration: -9.1845%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.28457920279861787), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 8, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.006040245096887873), 'optimizer': 'SGD', 'weight_decay': np.float64(2.978310286251128e-06)}
# -9.7325339801873 89.14842617003693
# Validation ROI for this configuration: -10.9172%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5156684954429354), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0011863506802965848), 'optimizer': 'SGD', 'weight_decay': np.float64(3.611954459307813e-06)}
# -9.31851838950207 111.36902484829167
# Validation ROI for this configuration: -8.3672%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.42578341700905653), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0005323099606209218), 'optimizer': 'SGD', 'weight_decay': np.float64(4.05093451126657e-06)}
# -16.022214874825828 98.69215385071853
# Validation ROI for this configuration: -16.2345%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.34243869035913854), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.007368577362395163), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2641030308912534e-06)}
# -2.6406006117421543 133.42063155144788
# Validation ROI for this configuration: -1.9792%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3461427278696231), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.00014989089372106597), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4906428293975966e-06)}
# -11.700128586651807 131.1052348686003
# Validation ROI for this configuration: -8.9242%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5369256141192726), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.002476982422703723), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2943117749495197e-06)}
# -19.743823679020313 91.28321880005436
# Validation ROI for this configuration: -21.6292%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.430399367122264), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.008915266418252249), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4821344004164957e-06)}
# -7.41037075568853 80.8298790905755
# Validation ROI for this configuration: -9.1679%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.528344589261341), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.001390674140149984), 'optimizer': 'Adam', 'weight_decay': np.float64(6.895766681594235e-06)}
# -3.987753295830457 75.75264508792431
# Validation ROI for this configuration: -5.2642%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.27481749942300937), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0010356684762667942), 'optimizer': 'Adam', 'weight_decay': np.float64(3.3871936241100627e-06)}
# -9.573550689981314 161.1519407270018
# Validation ROI for this configuration: -5.9407%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.44424801697665306), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.007311873757428549), 'optimizer': 'Adam', 'weight_decay': np.float64(3.408705116949428e-06)}
# -4.156793839739189 88.8281869726637
# Validation ROI for this configuration: -4.6796%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.34769219260395845), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0012526910073452128), 'optimizer': 'SGD', 'weight_decay': np.float64(2.1006507088892956e-06)}
# -5.8538357831489405 86.30468553046103
# Validation ROI for this configuration: -6.7828%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23514724449706273), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0033147877085280015), 'optimizer': 'Adam', 'weight_decay': np.float64(2.9728034823795807e-06)}
# -9.708161547302955 152.71846436991854
# Validation ROI for this configuration: -6.3569%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.36473636565890744), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.005028690651008761), 'optimizer': 'SGD', 'weight_decay': np.float64(9.226285952336877e-06)}
# -5.474122605648771 119.86868035383695
# Validation ROI for this configuration: -4.5668%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5731752268399819), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0002303913302543585), 'optimizer': 'Adam', 'weight_decay': np.float64(8.44207922694021e-06)}
# -5.021379143321004 72.84074805995888
# Validation ROI for this configuration: -6.8936%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21923785758563508), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0031695955578077764), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4576590148984936e-06)}
# -3.4052567026795195 87.40466303633451
# Validation ROI for this configuration: -3.8960%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.27456199471525766), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.006542327204769315), 'optimizer': 'Adam', 'weight_decay': np.float64(7.5370351525086285e-06)}
# -4.099053717098281 135.82358591067953
# Validation ROI for this configuration: -3.0179%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.473192825366853), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0017709369048225063), 'optimizer': 'Adam', 'weight_decay': np.float64(5.592543620519214e-06)}
# -5.474490342078331 108.58258464394694
# Validation ROI for this configuration: -5.0418%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4309945083624503), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0011580170650041996), 'optimizer': 'Adam', 'weight_decay': np.float64(8.062544245508247e-06)}
# -6.925990101334522 90.15386795997787
# Validation ROI for this configuration: -7.6824%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4171397242453636), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0018005952749128046), 'optimizer': 'SGD', 'weight_decay': np.float64(4.93989374349446e-06)}
# -17.475253123252546 114.57615521985855
# Validation ROI for this configuration: -15.2521%
# ...
# -13.226359756675228 128.37627776131396
# Validation ROI for this configuration: -10.3028%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5083648814983288), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.000504754642725934), 'optimizer': 'Adam', 'weight_decay': np.float64(3.1296178936832092e-06)}
# -6.569184512479002 66.18709515196872
# Validation ROI for this configuration: -9.9252%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4393144233072619), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.004347150094182582), 'optimizer': 'Adam', 'weight_decay': np.float64(1.0054011800439712e-06)}
# -5.019518162567257 175.2976660092967
# Validation ROI for this configuration: -2.8634%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3088580548919851), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00015246288961438044), 'optimizer': 'Adam', 'weight_decay': np.float64(9.164289197464569e-06)}
# -16.650394327246115 93.88533806441339
# Validation ROI for this configuration: -17.7348%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.580094941528321), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.003286887410036355), 'optimizer': 'Adam', 'weight_decay': np.float64(6.405619651627239e-06)}
# -4.315015327826511 89.797831624023
# Validation ROI for this configuration: -4.8053%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.48964133170925545), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0009524669772402284), 'optimizer': 'Adam', 'weight_decay': np.float64(4.933728097843621e-06)}
# -8.68949097517128 99.30811251109752
# Validation ROI for this configuration: -8.7500%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5776237358746453), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.009970271830727314), 'optimizer': 'SGD', 'weight_decay': np.float64(3.69781543203667e-06)}
# -5.669988738985284 64.62943507961171
# Validation ROI for this configuration: -8.7731%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.32514194260223506), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0003932765168114087), 'optimizer': 'SGD', 'weight_decay': np.float64(1.3040133010109623e-06)}
# -4.5255122834910235 104.84802810506424
# Validation ROI for this configuration: -4.3163%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5777065956453735), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.004887635348588299), 'optimizer': 'SGD', 'weight_decay': np.float64(3.329925951392819e-06)}
# -12.484928341270917 95.59840668216879
# Validation ROI for this configuration: -13.0598%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.21480305388619705), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.005888391987151447), 'optimizer': 'Adam', 'weight_decay': np.float64(2.1871318436814158e-06)}
# -13.127723446924083 180.59556943073395
# Validation ROI for this configuration: -7.2691%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3617941798727403), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00119945120407958), 'optimizer': 'Adam', 'weight_decay': np.float64(4.588335594998449e-06)}
# -5.892353619802993 78.69722510320892
# Validation ROI for this configuration: -7.4874%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.45035655057480367), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00011189265091892585), 'optimizer': 'SGD', 'weight_decay': np.float64(9.780055365032013e-06)}
# -19.449422328589336 162.88874299485127
# Validation ROI for this configuration: -11.9403%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5498806690736797), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00013805731141185035), 'optimizer': 'SGD', 'weight_decay': np.float64(2.2423934462088653e-06)}
# -43.53321748891753 241.76914768406084
# Validation ROI for this configuration: -18.0061%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23541736424544726), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0014504889159706385), 'optimizer': 'SGD', 'weight_decay': np.float64(9.640142844821018e-06)}
# -15.650107962188908 118.3983419314459
# Validation ROI for this configuration: -13.2182%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23667973404457207), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.002986514331666628), 'optimizer': 'SGD', 'weight_decay': np.float64(1.007735045444389e-06)}
# -18.985400467024512 135.6820925217242
# Validation ROI for this configuration: -13.9926%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3418488630563106), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0026984018782012526), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1017756999772791e-06)}
# -5.539382012558352 77.49694116531477
# Validation ROI for this configuration: -7.1479%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5641356408230138), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0006071000673896077), 'optimizer': 'SGD', 'weight_decay': np.float64(1.6529278148136077e-06)}
# -9.40815335966167 93.92833881912794
# Validation ROI for this configuration: -10.0163%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5191957288573534), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.009218516347279769), 'optimizer': 'Adam', 'weight_decay': np.float64(8.805053970009188e-06)}
# -5.202281181541082 122.7473330607441
# Validation ROI for this configuration: -4.2382%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5614895868701082), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.009601459454014048), 'optimizer': 'Adam', 'weight_decay': np.float64(2.521042902310876e-06)}
# 2.471553418243427 111.35615888666274
# Validation ROI for this configuration: 2.2195%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4598586595969474), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0001241339897969432), 'optimizer': 'Adam', 'weight_decay': np.float64(1.6614459180636926e-06)}
# -7.309290807406115 81.90443579437108
# Validation ROI for this configuration: -8.9242%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5829081051933303), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00181784079748647), 'optimizer': 'Adam', 'weight_decay': np.float64(7.65219246963617e-06)}
# -7.208892880481078 64.20564294587844
# Validation ROI for this configuration: -11.2278%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4389096289721364), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0006201318507156901), 'optimizer': 'SGD', 'weight_decay': np.float64(3.0987485807701254e-06)}
# -27.750902514681975 151.98347402651825
# Validation ROI for this configuration: -18.2592%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.26155836253594206), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0031314336070643466), 'optimizer': 'Adam', 'weight_decay': np.float64(3.9168770093987675e-06)}
# -3.178184594265591 83.61169288941794
# Validation ROI for this configuration: -3.8011%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5440507265671695), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00033978177846787896), 'optimizer': 'SGD', 'weight_decay': np.float64(2.9969315815326983e-06)}
# -8.890905484378674 117.05089411486804
# Validation ROI for this configuration: -7.5958%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5822605992919014), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 8, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.00045509569860877264), 'optimizer': 'Adam', 'weight_decay': np.float64(3.55514542620511e-06)}
# -8.228673464971813 62.966317129172
# Validation ROI for this configuration: -13.0684%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.31255638423101073), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0003307558753839457), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1188801823439863e-06)}
# -8.009397104196857 87.27952606311285
# Validation ROI for this configuration: -9.1767%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23241848636305917), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.009615030590341713), 'optimizer': 'SGD', 'weight_decay': np.float64(3.1271342558566116e-06)}
# -9.962757022731006 104.67888153147155
# Validation ROI for this configuration: -9.5174%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.43696311386380704), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.002109716114896794), 'optimizer': 'SGD', 'weight_decay': np.float64(3.6790184347952644e-06)}
# -5.835893972821244 74.40985707415143
# Validation ROI for this configuration: -7.8429%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4935639675814807), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.005427357155377507), 'optimizer': 'Adam', 'weight_decay': np.float64(2.1577885226736326e-06)}
# -6.342583945959715 133.3107067421258
# Validation ROI for this configuration: -4.7577%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4789885846677135), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.003202088118393478), 'optimizer': 'Adam', 'weight_decay': np.float64(7.6144253404783825e-06)}
# -9.447312254530397 89.94121797192759
# Validation ROI for this configuration: -10.5039%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5487374110980928), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00010239773292433367), 'optimizer': 'SGD', 'weight_decay': np.float64(2.1633104803261937e-06)}
# -8.224508845043427 118.76897079927036
# Validation ROI for this configuration: -6.9248%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5634805237077471), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 8, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00024336926426098314), 'optimizer': 'Adam', 'weight_decay': np.float64(4.139300141990877e-06)}
# -6.62202387456568 68.42292429603049
# Validation ROI for this configuration: -9.6781%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4239377249235318), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.004338692199470628), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2793242696527893e-06)}
# -5.471369958639779 74.54061058195026
# Validation ROI for this configuration: -7.3401%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.207371087495287), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 8, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00016033172161735484), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4919472741254382e-06)}
# -26.99843591709343 163.88315422798996
# Validation ROI for this configuration: -16.4742%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5789191553025352), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 8, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0014599598763239273), 'optimizer': 'Adam', 'weight_decay': np.float64(1.142669039981644e-06)}
# -7.447771382428453 115.63237072583671
# Validation ROI for this configuration: -6.4409%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5409658636794591), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0019730917777914182), 'optimizer': 'SGD', 'weight_decay': np.float64(5.731432683579709e-06)}
# -15.235299116435371 102.24513551828572
# Validation ROI for this configuration: -14.9008%
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.22625045782960518), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0003199024007941085), 'optimizer': 'Adam', 'weight_decay': np.float64(2.791918306517658e-06)}
# -5.9705856497898315 118.06708270858671
# Validation ROI for this configuration: -5.0569%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3874157667074338), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00079941823172062), 'optimizer': 'Adam', 'weight_decay': np.float64(3.3653024075944885e-06)}
# -7.320187005946707 119.32231942741807
# Validation ROI for this configuration: -6.1348%
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4774728903125955), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 8, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0020371472807574694), 'optimizer': 'Adam', 'weight_decay': np.float64(7.379965346254625e-06)}
# -4.2964446500742355 106.63452076181068
# Validation ROI for this configuration: -4.0291%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2604231567123601), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.006592483050723688), 'optimizer': 'Adam', 'weight_decay': np.float64(4.350367518665135e-06)}
# -5.787901725302731 103.99845239444804
# Validation ROI for this configuration: -5.5654%
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5040376313752388), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0006586701960370478), 'optimizer': 'SGD', 'weight_decay': np.float64(5.301791842907571e-06)}
# -12.80100176805431 180.41478905402562
# Validation ROI for this configuration: -7.0953%
# Best Configuration: {'batch_size': 32, 'dropout': np.float64(0.5582092913984802), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.004946366454603174), 'optimizer': 'Adam', 'weight_decay': np.float64(2.0859967986741853e-06)}
# Best Validation ROI: 4.4228%

# %% [markdown]
#     ### Zostawiamy tylko CO kolumny

# %%
list(matches.columns)
# Out:
# ['outdoor',
#  'player1_Sets_Before',
#  'player1_Gems_Before',
#  'player2_Sets_Before',
#  'player2_Gems_Before',
#  'tournament_level',
#  'player1_right_handed',
#  'player1_age',
#  'player2_right_handed',
#  'player2_age',
#  'best_of',
#  'player1_rank',
#  'player2_rank',
#  'player1_entry_LL',
#  'player1_entry_Q',
#  'player1_entry_WC',
#  'player2_entry_LL',
#  'player2_entry_Q',
#  'player2_entry_WC',
#  'player1_is_seeded',
#  'player2_is_seeded',
#  'player1_h2h_wins',
#  'player2_h2h_wins',
#  'player1_home',
#  'player2_home',
#  'Round_Num',
#  'player1_win_pct_last_10',
#  'player2_win_pct_last_10',
#  'player1_win_pct_last_10_surface',
#  'player2_win_pct_last_10_surface',
#  'player1_elo',
#  'player2_elo',
#  'player1_surface_elo',
#  'player2_surface_elo',
#  'player1_blended_elo',
#  'player2_blended_elo',
#  'num_CO_matches',
#  'player1_CO_1st_serve_in_pct_avg',
#  'player2_CO_1st_serve_in_pct_avg',
#  'player1_1st_serve_in_pct_avg',
#  'player2_1st_serve_in_pct_avg',
#  'player1_CO_1st_serve_win_pct_avg',
#  'player2_CO_1st_serve_win_pct_avg',
#  'player1_1st_serve_win_pct_avg',
#  'player2_1st_serve_win_pct_avg',
#  'player1_CO_2nd_serve_win_pct_avg',
#  'player2_CO_2nd_serve_win_pct_avg',
#  'player1_2nd_serve_win_pct_avg',
#  'player2_2nd_serve_win_pct_avg',
#  'player1_CO_serve_games_win_pct_avg',
#  'player2_CO_serve_games_win_pct_avg',
#  'player1_serve_games_win_pct_avg',
#  'player2_serve_games_win_pct_avg',
#  'player1_CO_ace_avg',
#  'player2_CO_ace_avg',
#  'player1_ace_avg',
#  'player2_ace_avg',
#  'player1_CO_df_avg',
#  'player2_CO_df_avg',
#  'player1_df_avg',
#  'player2_df_avg',
#  'player1_CO_1st_serve_return_win_pct_avg',
#  'player2_CO_1st_serve_return_win_pct_avg',
#  'player1_1st_serve_return_win_pct_avg',
#  'player2_1st_serve_return_win_pct_avg',
#  'player1_fatigue_score',
#  'player2_fatigue_score',
#  'player1_tournament_wins_before',
#  'player1_tournament_losses_before',
#  'player2_tournament_wins_before',
#  'player2_tournament_losses_before',
#  'Surface_Clay',
#  'Surface_Grass',
#  'Surface_Hard',
#  'target']

# %%
player1_cols = [col for col in matches.columns if col.startswith('player1_') and not ("avg" in col and "CO" not in col)]
player2_cols = [col for col in matches.columns if col.startswith('player2_') and not ("avg" in col and "CO" not in col)]
env_cols = [col for col in matches.columns if col not in player1_cols and col not in player2_cols and "diff" not in col and "CO" not in col and "target" not in col ]
target_col = 'target'
player1_cols
# Out:
# ['player1_Sets_Before',
#  'player1_Gems_Before',
#  'player1_right_handed',
#  'player1_age',
#  'player1_rank',
#  'player1_entry_LL',
#  'player1_entry_Q',
#  'player1_entry_WC',
#  'player1_is_seeded',
#  'player1_h2h_wins',
#  'player1_home',
#  'player1_win_pct_last_10',
#  'player1_win_pct_last_10_surface',
#  'player1_elo',
#  'player1_surface_elo',
#  'player1_blended_elo',
#  'player1_CO_1st_serve_in_pct_avg',
#  'player1_CO_1st_serve_win_pct_avg',
#  'player1_CO_2nd_serve_win_pct_avg',
#  'player1_CO_serve_games_win_pct_avg',
#  'player1_CO_ace_avg',
#  'player1_CO_df_avg',
#  'player1_CO_1st_serve_return_win_pct_avg',
#  'player1_fatigue_score',
#  'player1_tournament_wins_before',
#  'player1_tournament_losses_before']

# %%
player1_features = matches[player1_cols].values  # Convert to numpy array
player2_features = matches[player2_cols].values
env_features = matches[env_cols].values
match_outcomes = matches[target_col].values  # Target (1 for player1 win, 0 for player2 win)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
player1_features = scaler.fit_transform(player1_features)
player2_features = scaler.transform(player2_features)  
env_features = scaler.fit_transform(env_features)

# %%
import torch

player1_features = torch.tensor(player1_features, dtype=torch.float32)
player2_features = torch.tensor(player2_features, dtype=torch.float32)
env_features = torch.tensor(env_features, dtype=torch.float32)
match_outcomes = torch.tensor(match_outcomes, dtype=torch.float32).unsqueeze(1)  # Add dimension for compatibility

# %%
from sklearn.model_selection import train_test_split

player1_train, player1_test, player2_train, player2_test, env_train, env_test, y_train, y_test = train_test_split(
    player1_features, player2_features, env_features, match_outcomes, test_size=0.2, random_state=42, stratify=match_outcomes
)
player1_train, player1_val, player2_train, player2_val, env_train, env_val, y_train, y_val = train_test_split(
    player1_train, player2_train, env_train, y_train, test_size=0.2, random_state=42, stratify=y_train
)
y_val.unique(return_counts=True)
# Out:
# (tensor([0., 1.]), tensor([1129, 1129]))

# %%
# Create DataLoader for training
train_dataset = TensorDataset(player1_train, player2_train, env_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# Validation DataLoader
val_dataset = TensorDataset(player1_val, player2_val, env_val, y_val)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# %%
from sklearn.model_selection import ParameterSampler
import scipy.stats as stats
set_seed(42)

# Parameter grid for random search
param_grid = {
    'learning_rate': stats.loguniform(1e-5, 1e-2),
    'dropout': stats.uniform(0.1, 0.6),
    'hidden_layer_sizes': [
       [256], [256, 256], [512], [512,256], [128], [128, 128], [256, 128], [256, 128, 64], [512, 256, 128], [64], [32], [16, 8], [64, 32], [64, 64], [64, 32, 16],
    ],
    'batch_size': [32, 64, 128],
    'weight_decay': stats.loguniform(1e-6, 1e-3),
    'optimizer': ['Adam', 'SGD']
}

# Generate random hyperparameter samples
n_samples = 200
random_params = list(ParameterSampler(param_grid, n_iter=n_samples, random_state=42))

# Training and evaluation function
def train_and_evaluate(params):
    print(f"Testing configuration: {params}")
    
    # Extract parameters
    learning_rate = params['learning_rate']
    dropout = params['dropout']
    hidden_layer_sizes = params['hidden_layer_sizes']
    batch_size = params['batch_size']
    weight_decay = params['weight_decay']
    optimizer_choice = params['optimizer']
    
    # DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Model
    model = SymmetricNNWithEnvInteraction(
        player_feature_size=player1_train.shape[1],
        env_feature_size=env_train.shape[1],
        embedding_size=8,
        hidden_sizes=hidden_layer_sizes,
        dropout=dropout
    )
    
    # Initialize weights
    def initialize_weights(m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            nn.init.zeros_(m.bias)
    model.apply(initialize_weights)

    # Optimizer
    if optimizer_choice == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    elif optimizer_choice == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=weight_decay, momentum=0.9)
    elif optimizer_choice == 'RMSprop':
        optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate, weight_decay=weight_decay)


    # Loss function
    criterion = nn.BCELoss()

     # Training loop
    best_val_accuracy = 0.0
    for epoch in range(20):
        model.train()
        for p1, p2, env, labels in train_loader:
            optimizer.zero_grad()
            predictions = model(p1, p2, env)
            loss = criterion(predictions, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        # Validation loop
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for p1, p2, env, labels in val_loader:
                predictions = model(p1, p2, env)
                predicted = (predictions > 0.5).float()
                correct += (predicted == labels).sum().item()
                total += labels.size(0)
        val_accuracy = correct / total
        best_val_accuracy = max(best_val_accuracy, val_accuracy)

    print(f"Best Validation Accuracy for this configuration: {best_val_accuracy:.4f}")
    return best_val_accuracy

# Run random search
best_params = None
best_val_accuracy = 0.0

for params in random_params:
    val_accuracy = train_and_evaluate(params)
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        best_params = params

print(f"Best Configuration: {best_params}")
print(f"Best Validation Accuracy: {best_val_accuracy:.4f}")
# Out:
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5779257921161397), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.001570297088405539), 'optimizer': 'Adam', 'weight_decay': np.float64(6.173770394704566e-05)}
# Best Validation Accuracy for this configuration: 0.6603
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.1935967122017216), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00023864188780056055), 'optimizer': 'Adam', 'weight_decay': np.float64(6.358358856676247e-05)}
# Best Validation Accuracy for this configuration: 0.6506
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.11235069657748148), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.0014655354118727707), 'optimizer': 'SGD', 'weight_decay': np.float64(4.335281794951567e-06)}
# Best Validation Accuracy for this configuration: 0.6479
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.47048890577662994), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00037520558551242813), 'optimizer': 'SGD', 'weight_decay': np.float64(1.1727009450102251e-06)}
# Best Validation Accuracy for this configuration: 0.6284
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.46711173683342766), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(1.3803746963532802e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2562773503807034e-05)}
# Best Validation Accuracy for this configuration: 0.5655
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.1543638607196925), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(3.972110727381908e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0008906204386161679)}
# Best Validation Accuracy for this configuration: 0.6426
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.12787024763199864), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.0010988100318524605), 'optimizer': 'Adam', 'weight_decay': np.float64(1.5673095467235414e-06)}
# Best Validation Accuracy for this configuration: 0.6554
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6793792198447356), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.00014330109455635691), 'optimizer': 'SGD', 'weight_decay': np.float64(1.9634341572933354e-06)}
# Best Validation Accuracy for this configuration: 0.6098
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5099581112952749), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0003058656666978527), 'optimizer': 'Adam', 'weight_decay': np.float64(3.312027701465944e-06)}
# Best Validation Accuracy for this configuration: 0.6023
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.25526798896001013), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.001845373292661593), 'optimizer': 'SGD', 'weight_decay': np.float64(3.632486956676606e-05)}
# Best Validation Accuracy for this configuration: 0.6519
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4406201966919949), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.008105016126411584), 'optimizer': 'SGD', 'weight_decay': np.float64(2.2349221517675526e-05)}
# Best Validation Accuracy for this configuration: 0.6532
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6368964102565893), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0015199034037054083), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8427970406864558e-06)}
# Best Validation Accuracy for this configuration: 0.6537
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4125005560154942), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(9.46217535646148e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00017456626922659343)}
# Best Validation Accuracy for this configuration: 0.5713
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5972425054911575), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.007866216981266844), 'optimizer': 'SGD', 'weight_decay': np.float64(4.247058562261871e-05)}
# Best Validation Accuracy for this configuration: 0.6470
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.27776410342244945), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(1.6736010167825783e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8629639119246215e-05)}
# Best Validation Accuracy for this configuration: 0.6036
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.21922940892050344), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(1.1021468611551662e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00013199942261535007)}
# Best Validation Accuracy for this configuration: 0.6289
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5741053243187234), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(1.667761543019792e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(8.979064194712974e-05)}
# Best Validation Accuracy for this configuration: 0.5394
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6100231466738796), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(9.833181933644887e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2955517240662165e-05)}
# Best Validation Accuracy for this configuration: 0.5230
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.29510999321604825), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.0005941462537454564), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0004588156549160974)}
# Best Validation Accuracy for this configuration: 0.6426
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3297561248522739), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0013795402040204172), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0001462812165489284)}
# Best Validation Accuracy for this configuration: 0.6546
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5625803079727366), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(1.3222110082400286e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.9170041589170666e-05)}
# Best Validation Accuracy for this configuration: 0.5996
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3636019011194621), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(1.2424747083660186e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(2.6675383361699188e-05)}
# Best Validation Accuracy for this configuration: 0.6156
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4051424146988216), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(2.618149026594371e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.7027416886764403e-05)}
# Best Validation Accuracy for this configuration: 0.6151
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.22183673484086164), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(1.7019223026554023e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00012143805397783965)}
# Best Validation Accuracy for this configuration: 0.5890
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.474612428880276), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.000794714742465374), 'optimizer': 'SGD', 'weight_decay': np.float64(2.3420907100434134e-05)}
# Best Validation Accuracy for this configuration: 0.6333
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6299681553513209), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(2.324148449297575e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(8.995191735587168e-06)}
# Best Validation Accuracy for this configuration: 0.6010
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2632793496307812), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00019112758217777883), 'optimizer': 'SGD', 'weight_decay': np.float64(1.1421064100297764e-05)}
# Best Validation Accuracy for this configuration: 0.6231
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.10417127831871442), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.00040019186681149307), 'optimizer': 'SGD', 'weight_decay': np.float64(4.637921903458029e-06)}
# Best Validation Accuracy for this configuration: 0.6240
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2616474002791129), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.0067410742656406975), 'optimizer': 'SGD', 'weight_decay': np.float64(4.53202877576487e-06)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3423017026348245), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.008228984573308165), 'optimizer': 'SGD', 'weight_decay': np.float64(5.503363365456096e-06)}
# Best Validation Accuracy for this configuration: 0.6585
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3983491035354313), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(2.7813829613946106e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2902113024567156e-06)}
# Best Validation Accuracy for this configuration: 0.5802
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6859689734995917), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(1.4270403521460843e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.0844605150525019e-05)}
# Best Validation Accuracy for this configuration: 0.5208
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24373713440018346), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.0003915648958243002), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0009056311714376344)}
# Best Validation Accuracy for this configuration: 0.6461
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5032813284435271), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0001285178253319705), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00015298506868937454)}
# Best Validation Accuracy for this configuration: 0.6289
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4793834983561477), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.00015720752387932209), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8658181360124843e-06)}
# Best Validation Accuracy for this configuration: 0.6475
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.19043052637925767), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(3.627066608804409e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00037590353898082695)}
# Best Validation Accuracy for this configuration: 0.6408
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.232144628539329), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0003437788661779579), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1117265099859662e-05)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.20461985740299488), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.000155853321857154), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0006459367085984855)}
# Best Validation Accuracy for this configuration: 0.6470
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5054140702235684), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(2.1898812429056927e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(4.2105993732656564e-05)}
# Best Validation Accuracy for this configuration: 0.6408
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.25476497662909336), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(3.348611630346182e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(4.630228617122102e-05)}
# Best Validation Accuracy for this configuration: 0.5779
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24511137454027102), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.004916400722913764), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00044453814157375464)}
# Best Validation Accuracy for this configuration: 0.6594
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.30341787462922043), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.0012620410750629133), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0004912819179585587)}
# Best Validation Accuracy for this configuration: 0.6311
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5679253275145743), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.0035709629668132267), 'optimizer': 'Adam', 'weight_decay': np.float64(3.054120318443385e-06)}
# Best Validation Accuracy for this configuration: 0.6585
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5013929528285371), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(1.0655924993232572e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0006613027479748718)}
# Best Validation Accuracy for this configuration: 0.5434
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.10303695030773122), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00044279363365000874), 'optimizer': 'SGD', 'weight_decay': np.float64(2.2144833991983438e-05)}
# Best Validation Accuracy for this configuration: 0.6457
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.23456158567633587), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(1.1329900368822794e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(9.466710461838324e-06)}
# Best Validation Accuracy for this configuration: 0.5992
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5325639545512776), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.00042424886748968307), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2680822080429415e-05)}
# Best Validation Accuracy for this configuration: 0.6466
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.2502770911633505), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00829911273846603), 'optimizer': 'Adam', 'weight_decay': np.float64(2.885535747082002e-05)}
# Best Validation Accuracy for this configuration: 0.6568
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.36063661930625723), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00032204108362516746), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00010157157317146243)}
# Best Validation Accuracy for this configuration: 0.6227
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2171457926788267), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0003144706654325595), 'optimizer': 'SGD', 'weight_decay': np.float64(1.182899639110128e-06)}
# Best Validation Accuracy for this configuration: 0.6315
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.12616226305266026), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.006627897035983008), 'optimizer': 'Adam', 'weight_decay': np.float64(6.897330321733754e-06)}
# Best Validation Accuracy for this configuration: 0.6616
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.32209522015326664), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.007231286044841392), 'optimizer': 'Adam', 'weight_decay': np.float64(1.925539557201562e-05)}
# Best Validation Accuracy for this configuration: 0.6625
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.44337548150250294), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.003622666594728667), 'optimizer': 'Adam', 'weight_decay': np.float64(8.262111618519662e-06)}
# Best Validation Accuracy for this configuration: 0.6612
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.26108491413409407), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(3.22461774864237e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.527827773064012e-05)}
# Best Validation Accuracy for this configuration: 0.6360
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5176178780049838), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(1.626478746126889e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(6.998769331752381e-05)}
# Best Validation Accuracy for this configuration: 0.5097
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.31518806877769834), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0003589128083678785), 'optimizer': 'SGD', 'weight_decay': np.float64(9.282229301554022e-06)}
# Best Validation Accuracy for this configuration: 0.5837
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.18197279886521728), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.00011980458901470991), 'optimizer': 'Adam', 'weight_decay': np.float64(7.75408274187192e-06)}
# Best Validation Accuracy for this configuration: 0.6479
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5860680368075084), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.0006831894206766534), 'optimizer': 'SGD', 'weight_decay': np.float64(3.420008587735e-05)}
# Best Validation Accuracy for this configuration: 0.6222
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.47673664896918166), 'hidden_layer_sizes': [512, 256], 'learning_rate': np.float64(0.0008910289040644941), 'optimizer': 'SGD', 'weight_decay': np.float64(1.5500706089539408e-05)}
# Best Validation Accuracy for this configuration: 0.6337
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6340032050905398), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(1.2101809594595502e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.9140171266136668e-06)}
# Best Validation Accuracy for this configuration: 0.5102
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5032156811771197), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.00024934120524149533), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0008821098364250345)}
# Best Validation Accuracy for this configuration: 0.6439
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.4544999563414065), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(5.633185873834517e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00029363084977630154)}
# Best Validation Accuracy for this configuration: 0.5788
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.42224945631799327), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00036874809057925315), 'optimizer': 'Adam', 'weight_decay': np.float64(6.525724687264681e-06)}
# Best Validation Accuracy for this configuration: 0.6515
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3743590969682371), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(1.4290425609432082e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.714200885741935e-05)}
# Best Validation Accuracy for this configuration: 0.4876
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4824579408989239), 'hidden_layer_sizes': [512, 256], 'learning_rate': np.float64(2.5017059802726544e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(3.5391669108220064e-05)}
# Best Validation Accuracy for this configuration: 0.5558
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.12464051006072548), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(6.493767776722161e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00017065850192860937)}
# Best Validation Accuracy for this configuration: 0.6023
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.11521044604927451), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(1.7483118445198648e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00012243980190472075)}
# Best Validation Accuracy for this configuration: 0.6382
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.13491615730506618), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(2.946531769463084e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(5.240371517221391e-06)}
# Best Validation Accuracy for this configuration: 0.5704
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5287575536200374), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.0063656387975889565), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0007321428778380783)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.49426679710010013), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0006841671828013816), 'optimizer': 'Adam', 'weight_decay': np.float64(1.3904276100386608e-06)}
# Best Validation Accuracy for this configuration: 0.6541
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.31358360719075695), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(2.2934746458906674e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(2.2295536203910113e-06)}
# Best Validation Accuracy for this configuration: 0.6262
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.15649419296113606), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0036845270736218664), 'optimizer': 'SGD', 'weight_decay': np.float64(3.357305095994101e-06)}
# Best Validation Accuracy for this configuration: 0.6554
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5580186538023465), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00026327844992182515), 'optimizer': 'Adam', 'weight_decay': np.float64(2.4775443578601082e-05)}
# Best Validation Accuracy for this configuration: 0.6479
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.33910284063842405), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.007037804438066345), 'optimizer': 'SGD', 'weight_decay': np.float64(1.3674518065224924e-06)}
# Best Validation Accuracy for this configuration: 0.6537
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.10918272417423086), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.0003231534343074978), 'optimizer': 'Adam', 'weight_decay': np.float64(4.150805133739246e-05)}
# Best Validation Accuracy for this configuration: 0.6568
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.1977606562488578), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.006786952562305611), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2009749020630263e-06)}
# Best Validation Accuracy for this configuration: 0.6612
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5805695768094398), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00014605276344629992), 'optimizer': 'SGD', 'weight_decay': np.float64(2.4294113699066827e-06)}
# Best Validation Accuracy for this configuration: 0.5567
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4273700735895609), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0007547776129399451), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0007648419348470309)}
# Best Validation Accuracy for this configuration: 0.6603
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.22401061592604724), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(1.614670469622491e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.354494511814094e-05)}
# Best Validation Accuracy for this configuration: 0.6209
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.15666577645355703), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.00010224984178178771), 'optimizer': 'SGD', 'weight_decay': np.float64(9.0558014273489e-06)}
# Best Validation Accuracy for this configuration: 0.6311
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5089682013836738), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0027759104241881884), 'optimizer': 'Adam', 'weight_decay': np.float64(3.076892781138969e-05)}
# Best Validation Accuracy for this configuration: 0.6572
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5180422992184904), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0064557165786175786), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00016040323816074402)}
# Best Validation Accuracy for this configuration: 0.6435
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6805483309121484), 'hidden_layer_sizes': [512, 256], 'learning_rate': np.float64(3.406580305821766e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(5.0764586293790986e-05)}
# Best Validation Accuracy for this configuration: 0.6293
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.694303085200404), 'hidden_layer_sizes': [512, 256], 'learning_rate': np.float64(0.00013063340811682268), 'optimizer': 'Adam', 'weight_decay': np.float64(5.5160988091309545e-05)}
# Best Validation Accuracy for this configuration: 0.6213
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6584543953621388), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(5.1974531032483503e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00017890117928710345)}
# Best Validation Accuracy for this configuration: 0.6182
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24294169144238767), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.005101039893789344), 'optimizer': 'SGD', 'weight_decay': np.float64(3.0880446562679646e-05)}
# Best Validation Accuracy for this configuration: 0.6554
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.29202976061836705), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(1.995054028860687e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0777374007231593e-06)}
# Best Validation Accuracy for this configuration: 0.5593
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6082858864573538), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(9.076970265355104e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00010722837222998311)}
# Best Validation Accuracy for this configuration: 0.5651
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.395815394663083), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(1.884136842103437e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(9.682636678036e-06)}
# Best Validation Accuracy for this configuration: 0.4681
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.22763673701453738), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.002369938800028332), 'optimizer': 'Adam', 'weight_decay': np.float64(2.189746324513344e-06)}
# Best Validation Accuracy for this configuration: 0.6568
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3966521828215489), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.009722853143192526), 'optimizer': 'SGD', 'weight_decay': np.float64(2.11150203402512e-05)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.42754946209899336), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(2.244920931433379e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00011590175990143796)}
# Best Validation Accuracy for this configuration: 0.5297
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.47093083798975666), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0032767423281870813), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00012673815903184202)}
# Best Validation Accuracy for this configuration: 0.6386
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3379909611725511), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0013143973700871993), 'optimizer': 'Adam', 'weight_decay': np.float64(3.4671969032042624e-05)}
# Best Validation Accuracy for this configuration: 0.6559
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6919837471007052), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00012939766550813187), 'optimizer': 'SGD', 'weight_decay': np.float64(5.129270242369176e-06)}
# Best Validation Accuracy for this configuration: 0.5283
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6916006382937225), 'hidden_layer_sizes': [512, 256], 'learning_rate': np.float64(0.0001123711279211307), 'optimizer': 'SGD', 'weight_decay': np.float64(1.7803367228855955e-06)}
# Best Validation Accuracy for this configuration: 0.5354
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.32679255407335267), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00018735531924000186), 'optimizer': 'SGD', 'weight_decay': np.float64(9.789434097441845e-06)}
# Best Validation Accuracy for this configuration: 0.6196
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.39557506257451547), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00016428815800640663), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4754001628061713e-06)}
# Best Validation Accuracy for this configuration: 0.6187
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5936742111260158), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0017303527113379845), 'optimizer': 'Adam', 'weight_decay': np.float64(5.158452239241319e-06)}
# Best Validation Accuracy for this configuration: 0.6554
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.32492234771422246), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(1.7728580556091035e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(4.6858406496824244e-06)}
# Best Validation Accuracy for this configuration: 0.6373
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5812655494160405), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00812150432873865), 'optimizer': 'Adam', 'weight_decay': np.float64(9.290929504070812e-06)}
# Best Validation Accuracy for this configuration: 0.6612
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6547859981341576), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(1.664905907163967e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00012196448023200595)}
# Best Validation Accuracy for this configuration: 0.5089
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.41385870650208934), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(4.471233183495585e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(2.310059649904301e-05)}
# Best Validation Accuracy for this configuration: 0.6377
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5181550335182888), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.005052124349891388), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0005568818006274345)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6702468904459352), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.00015260381674960595), 'optimizer': 'SGD', 'weight_decay': np.float64(7.250998134673018e-05)}
# Best Validation Accuracy for this configuration: 0.5199
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21287269583425678), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00014615213097091153), 'optimizer': 'SGD', 'weight_decay': np.float64(5.63596562454906e-05)}
# Best Validation Accuracy for this configuration: 0.6089
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6846368845996998), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0012430401086355436), 'optimizer': 'Adam', 'weight_decay': np.float64(6.907016945696073e-06)}
# Best Validation Accuracy for this configuration: 0.6590
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5882770118241691), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(6.499394933822215e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0005404823964051239)}
# Best Validation Accuracy for this configuration: 0.5275
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.66431909628123), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.0015036907396360991), 'optimizer': 'Adam', 'weight_decay': np.float64(0.000572176023973468)}
# Best Validation Accuracy for this configuration: 0.6541
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6596370900124079), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.00045161007038916565), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1997780810987998e-06)}
# Best Validation Accuracy for this configuration: 0.6492
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5665613702411353), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.009158585158712831), 'optimizer': 'Adam', 'weight_decay': np.float64(1.3496367948399508e-05)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3285345139786129), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0030725054514874808), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00032733022885465075)}
# Best Validation Accuracy for this configuration: 0.6572
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.12209312058159483), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(6.610300699552027e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.6829731256669612e-06)}
# Best Validation Accuracy for this configuration: 0.6182
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4206077650176778), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.009770358765701473), 'optimizer': 'Adam', 'weight_decay': np.float64(5.6944082121699187e-05)}
# Best Validation Accuracy for this configuration: 0.6594
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6668594379294568), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00013600398943955082), 'optimizer': 'Adam', 'weight_decay': np.float64(2.247151774034238e-05)}
# Best Validation Accuracy for this configuration: 0.6391
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2508654637070791), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0006584516697990204), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0004311833699266513)}
# Best Validation Accuracy for this configuration: 0.6448
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3148976308197043), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(1.1656125803581685e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(3.638506061069969e-05)}
# Best Validation Accuracy for this configuration: 0.5027
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5988228940375007), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.0036020065726995155), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0008015327949118781)}
# Best Validation Accuracy for this configuration: 0.6479
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6259921615950069), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.0005886642904109713), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2199668475623268e-06)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5708009583665857), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0012949091638211228), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0005122160421126091)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3103525352839582), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.0008127050621251254), 'optimizer': 'Adam', 'weight_decay': np.float64(2.0531693199466856e-05)}
# Best Validation Accuracy for this configuration: 0.6532
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.535838219590137), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.00034831202446644225), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0005387829392842869)}
# Best Validation Accuracy for this configuration: 0.5939
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.47325202013672407), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.0012385844248738976), 'optimizer': 'Adam', 'weight_decay': np.float64(2.761979448859579e-06)}
# Best Validation Accuracy for this configuration: 0.6590
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.39526977584772294), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(1.5801849950581864e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0008711595980645578)}
# Best Validation Accuracy for this configuration: 0.5403
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3084480449352485), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0007946988104669661), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0584969997394116e-05)}
# Best Validation Accuracy for this configuration: 0.6422
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.17732783314638956), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0005679345869870709), 'optimizer': 'Adam', 'weight_decay': np.float64(2.609044688849346e-06)}
# Best Validation Accuracy for this configuration: 0.6599
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.638073045943607), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.00035132427975547565), 'optimizer': 'SGD', 'weight_decay': np.float64(3.288210513615226e-06)}
# Best Validation Accuracy for this configuration: 0.6262
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23430943954379235), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(3.2122193153226806e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.1037167754046556e-05)}
# Best Validation Accuracy for this configuration: 0.6085
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.15322152025423336), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.00040111648528343873), 'optimizer': 'SGD', 'weight_decay': np.float64(4.159117168120245e-06)}
# Best Validation Accuracy for this configuration: 0.6430
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.17724903897978633), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0011781063202742131), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8917849175428211e-06)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.47674023369454466), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00034274493107721085), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0005789181979829949)}
# Best Validation Accuracy for this configuration: 0.6399
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.10155701463018794), 'hidden_layer_sizes': [512, 256], 'learning_rate': np.float64(0.0026218258396521815), 'optimizer': 'Adam', 'weight_decay': np.float64(6.192047037327748e-05)}
# Best Validation Accuracy for this configuration: 0.6585
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.42195438759239956), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.0002841639333505349), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00019048738804360626)}
# Best Validation Accuracy for this configuration: 0.5686
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.37752082967988876), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(1.5382399542566003e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(5.718878014855691e-06)}
# Best Validation Accuracy for this configuration: 0.6258
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5122993032419987), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0003427933011298978), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2342878621258998e-06)}
# Best Validation Accuracy for this configuration: 0.6444
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.36844742009407283), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.00015541448638894275), 'optimizer': 'SGD', 'weight_decay': np.float64(6.422878295869772e-06)}
# Best Validation Accuracy for this configuration: 0.6298
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.20937032708557485), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(9.252039894137946e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8518806171584944e-06)}
# Best Validation Accuracy for this configuration: 0.6537
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.17185727909155074), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.00010685149251813225), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0001089700016400601)}
# Best Validation Accuracy for this configuration: 0.6448
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.48929370417494555), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(1.8228916863732688e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00016235565727085389)}
# Best Validation Accuracy for this configuration: 0.6138
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.547263684510598), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.0004936005416178069), 'optimizer': 'SGD', 'weight_decay': np.float64(7.101134154276106e-06)}
# Best Validation Accuracy for this configuration: 0.6351
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6397884382870074), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(5.408283715752505e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.000911057413380846)}
# Best Validation Accuracy for this configuration: 0.6156
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6602150942559247), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(2.019981620383053e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.24758590353462e-05)}
# Best Validation Accuracy for this configuration: 0.5089
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21194021443078348), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0026157405212333014), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0004901130584259783)}
# Best Validation Accuracy for this configuration: 0.6475
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.1309812867247077), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00017029052365462639), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0009812204802186945)}
# Best Validation Accuracy for this configuration: 0.5753
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.33871335942744496), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0056518007049294345), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0002826286687254133)}
# Best Validation Accuracy for this configuration: 0.6603
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.39444926755527066), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.001013747181528548), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00014301178012225606)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.44296761368193993), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.0032790472602062374), 'optimizer': 'Adam', 'weight_decay': np.float64(3.640250294459699e-06)}
# Best Validation Accuracy for this configuration: 0.6603
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.526571487302049), 'hidden_layer_sizes': [512, 256], 'learning_rate': np.float64(0.00033329679390406945), 'optimizer': 'Adam', 'weight_decay': np.float64(3.88615456171366e-05)}
# Best Validation Accuracy for this configuration: 0.6554
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4663720254649796), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0005542614381064704), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0006252346334537663)}
# Best Validation Accuracy for this configuration: 0.6532
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4195536595309515), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.00012814198421127212), 'optimizer': 'SGD', 'weight_decay': np.float64(2.5307196127108794e-06)}
# Best Validation Accuracy for this configuration: 0.6165
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4293531879333864), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(9.269611546439877e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(1.834865917382776e-06)}
# Best Validation Accuracy for this configuration: 0.6293
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5089016333343576), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(2.2391758030937736e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(2.598534969391131e-05)}
# Best Validation Accuracy for this configuration: 0.6209
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5765736699798775), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0061459274988269275), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00017295119880053793)}
# Best Validation Accuracy for this configuration: 0.6147
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.17457833409132684), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.009392656270366251), 'optimizer': 'SGD', 'weight_decay': np.float64(3.4970287155610613e-06)}
# Best Validation Accuracy for this configuration: 0.6608
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6558696541538267), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(1.394067915097477e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(2.6261354962079175e-06)}
# Best Validation Accuracy for this configuration: 0.5726
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5503011548591881), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(3.097189858969044e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(3.624223402326765e-06)}
# Best Validation Accuracy for this configuration: 0.5651
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4991183324177201), 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.005291738703741362), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0004281555938400685)}
# Best Validation Accuracy for this configuration: 0.6568
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.5097892380502794), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.00020768480625669864), 'optimizer': 'SGD', 'weight_decay': np.float64(0.000500037224447186)}
# Best Validation Accuracy for this configuration: 0.6213
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2808267244984852), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0002071257176451309), 'optimizer': 'Adam', 'weight_decay': np.float64(4.973224739993161e-06)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.33488926612090114), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.0004272268935624074), 'optimizer': 'SGD', 'weight_decay': np.float64(4.8649252622243826e-06)}
# Best Validation Accuracy for this configuration: 0.6492
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.17013882442501843), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(9.964312921001782e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.0109201286713742e-05)}
# Best Validation Accuracy for this configuration: 0.6395
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.6271774692240629), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.0003984586653383022), 'optimizer': 'Adam', 'weight_decay': np.float64(5.2414632818816124e-05)}
# Best Validation Accuracy for this configuration: 0.6417
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.19100492783965073), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.0013211173123382123), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00017054495536480716)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.22272675590167795), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.001938099445157674), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00018361403544674783)}
# Best Validation Accuracy for this configuration: 0.6590
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5927543828032077), 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00013691930836407567), 'optimizer': 'Adam', 'weight_decay': np.float64(2.412492583993925e-06)}
# Best Validation Accuracy for this configuration: 0.5111
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.5783772194677321), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00028778784423756274), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0001468106985712441)}
# Best Validation Accuracy for this configuration: 0.6275
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.10732184339082672), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.0012073837693216015), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00014077878873452822)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.30741759610235164), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00753744894903947), 'optimizer': 'SGD', 'weight_decay': np.float64(5.625684654372199e-05)}
# Best Validation Accuracy for this configuration: 0.6546
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3772034821864796), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0006996015926088926), 'optimizer': 'SGD', 'weight_decay': np.float64(5.737061375884856e-05)}
# Best Validation Accuracy for this configuration: 0.6165
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.1604767618095319), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(1.133262587137631e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(6.0101971162137436e-05)}
# Best Validation Accuracy for this configuration: 0.5766
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6534996287063773), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.0008997081052816714), 'optimizer': 'Adam', 'weight_decay': np.float64(5.356302308323079e-05)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.14135292362033128), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.0016193201008636677), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00033213825218426457)}
# Best Validation Accuracy for this configuration: 0.6492
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3705036228424793), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(5.101737437929794e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00032862020280829984)}
# Best Validation Accuracy for this configuration: 0.4916
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6024944734014952), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.004070887363880804), 'optimizer': 'Adam', 'weight_decay': np.float64(4.810462823214782e-06)}
# Best Validation Accuracy for this configuration: 0.6568
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.33940162232207816), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.0017090271242320007), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0002561889217260505)}
# Best Validation Accuracy for this configuration: 0.6351
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4622329190380834), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.00015649702309972657), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0003895421185245975)}
# Best Validation Accuracy for this configuration: 0.6532
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.30780759661957674), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(0.0002770198783804095), 'optimizer': 'Adam', 'weight_decay': np.float64(2.2732846669041587e-05)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.11970800214606302), 'hidden_layer_sizes': [32], 'learning_rate': np.float64(2.6458855905382108e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(5.4062467318826165e-05)}
# Best Validation Accuracy for this configuration: 0.5598
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.120327496147957), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(0.00012223109358432208), 'optimizer': 'Adam', 'weight_decay': np.float64(6.803956335980234e-06)}
# Best Validation Accuracy for this configuration: 0.6506
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.10785667395300019), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0003511729430038696), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0007642068961412463)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.43438322133402874), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(1.803221198410817e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(3.5759267517847253e-06)}
# Best Validation Accuracy for this configuration: 0.6408
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.4572310103920263), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0001555802074976315), 'optimizer': 'Adam', 'weight_decay': np.float64(4.263014200122849e-06)}
# Best Validation Accuracy for this configuration: 0.6253
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.3096321994295998), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(3.733044457006199e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(1.3588697858738468e-05)}
# Best Validation Accuracy for this configuration: 0.6129
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.13942518365701143), 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0013873230415259138), 'optimizer': 'SGD', 'weight_decay': np.float64(3.7425775487296376e-05)}
# Best Validation Accuracy for this configuration: 0.6391
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.34045783652519557), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0019772830488868276), 'optimizer': 'SGD', 'weight_decay': np.float64(3.5138594922130605e-06)}
# Best Validation Accuracy for this configuration: 0.6497
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.14530201828233352), 'hidden_layer_sizes': [512], 'learning_rate': np.float64(0.00013180380527254247), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0004923695985057285)}
# Best Validation Accuracy for this configuration: 0.6368
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.34524050265885786), 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.008645583444926514), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00014057778190091605)}
# Best Validation Accuracy for this configuration: 0.6510
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3447906972189068), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(4.633578081317681e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(3.875603139842979e-06)}
# Best Validation Accuracy for this configuration: 0.6231
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.11182632265261849), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.00010418704911178378), 'optimizer': 'Adam', 'weight_decay': np.float64(3.4326852679397646e-06)}
# Best Validation Accuracy for this configuration: 0.6408
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.4340329508700197), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(1.9875779875247875e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0009250950259884371)}
# Best Validation Accuracy for this configuration: 0.5226
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.5981319187401949), 'hidden_layer_sizes': [512, 256], 'learning_rate': np.float64(0.006811286947557053), 'optimizer': 'SGD', 'weight_decay': np.float64(4.120528157721554e-06)}
# Best Validation Accuracy for this configuration: 0.6466
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.29439403666407976), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(1.093970901921631e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00016132951922988547)}
# Best Validation Accuracy for this configuration: 0.6187
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.11591932232429183), 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0042592411298169), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8376959227633293e-05)}
# Best Validation Accuracy for this configuration: 0.6568
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6463744021241823), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00010603568714526016), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0002987596859654259)}
# Best Validation Accuracy for this configuration: 0.6165
# Testing configuration: {'batch_size': 128, 'dropout': np.float64(0.45417696550888464), 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0031042988191650705), 'optimizer': 'Adam', 'weight_decay': np.float64(1.6913557203040614e-05)}
# Best Validation Accuracy for this configuration: 0.6594
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.31765473679956724), 'hidden_layer_sizes': [128], 'learning_rate': np.float64(7.645348356750789e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0008387678886391071)}
# Best Validation Accuracy for this configuration: 0.6103
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.6210807855387477), 'hidden_layer_sizes': [256, 128, 64], 'learning_rate': np.float64(0.009038616013990274), 'optimizer': 'Adam', 'weight_decay': np.float64(0.00025093761607131664)}
# Best Validation Accuracy for this configuration: 0.6510
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3908670202902077), 'hidden_layer_sizes': [256], 'learning_rate': np.float64(6.397820897579585e-05), 'optimizer': 'SGD', 'weight_decay': np.float64(0.00012489284521294733)}
# Best Validation Accuracy for this configuration: 0.6205
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.25473261125992136), 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0008613159771227359), 'optimizer': 'SGD', 'weight_decay': np.float64(0.0008978556958963887)}
# Best Validation Accuracy for this configuration: 0.6506
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.6403433807418314), 'hidden_layer_sizes': [256, 256], 'learning_rate': np.float64(6.56027401242039e-05), 'optimizer': 'Adam', 'weight_decay': np.float64(0.0002935970095506951)}
# Best Validation Accuracy for this configuration: 0.6209
# Best Configuration: {'batch_size': 64, 'dropout': np.float64(0.32209522015326664), 'hidden_layer_sizes': [512, 256, 128], 'learning_rate': np.float64(0.007231286044841392), 'optimizer': 'Adam', 'weight_decay': np.float64(1.925539557201562e-05)}
# Best Validation Accuracy: 0.6625

# %%
from sklearn.model_selection import ParameterSampler
import scipy.stats as stats
set_seed(42)

# Parameter grid for random search
param_grid = {
    'learning_rate': stats.loguniform(1e-4, 1e-2),
    'dropout': stats.uniform(0.2, 0.2),
    'hidden_layer_sizes': [
        [128], [256, 128], [64], [32], [16, 8], [64, 32], [64, 64], [64, 32, 16], [32,32], [128,128], [64,16]
    ],
    'batch_size': [32, 64],
    'weight_decay': stats.loguniform(1e-6, 1e-5),
    'optimizer': ['Adam', 'SGD'],
    'embedding_size': [4,8,16],
    'embedding_hidden_layer_sizes': [[128], [256, 128], [64], [32], [16, 8], [64, 32], [16]]
}

# Generate random hyperparameter samples
n_samples = 200
random_params = list(ParameterSampler(param_grid, n_iter=n_samples, random_state=42))

# Training and evaluation function
def train_and_evaluate(params):
    print(f"Testing configuration: {params}")
    
    # Extract parameters
    learning_rate = params['learning_rate']
    dropout = params['dropout']
    hidden_layer_sizes = params['hidden_layer_sizes']
    batch_size = params['batch_size']
    weight_decay = params['weight_decay']
    optimizer_choice = params['optimizer']
    embedding_size = params['embedding_size']
    embedding_hidden_layer_sizes = params['embedding_hidden_layer_sizes']
    
    # DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Model
    model = SymmetricNNWithEnvInteraction(
        player_feature_size=player1_train.shape[1],
        env_feature_size=env_train.shape[1],
        embedding_size=embedding_size,
        hidden_sizes=hidden_layer_sizes,
        dropout=dropout,
        embedding_hidden_sizes=embedding_hidden_layer_sizes
    )
    
    # Initialize weights
    def initialize_weights(m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            nn.init.zeros_(m.bias)
    model.apply(initialize_weights)

    # Optimizer
    if optimizer_choice == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    elif optimizer_choice == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=weight_decay, momentum=0.9)
    elif optimizer_choice == 'RMSprop':
        optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate, weight_decay=weight_decay)


    # Loss function
    criterion = nn.BCELoss()

     # Training loop
    best_val_accuracy = 0.0
    for epoch in range(20):
        model.train()
        for p1, p2, env, labels in train_loader:
            optimizer.zero_grad()
            predictions = model(p1, p2, env)
            loss = criterion(predictions, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        # Validation loop
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for p1, p2, env, labels in val_loader:
                predictions = model(p1, p2, env)
                predicted = (predictions > 0.5).float()
                correct += (predicted == labels).sum().item()
                total += labels.size(0)
        val_accuracy = correct / total
        best_val_accuracy = max(best_val_accuracy, val_accuracy)

    print(f"Best Validation Accuracy for this configuration: {best_val_accuracy:.4f}")
    return best_val_accuracy

# Run random search
best_params = None
best_val_accuracy = 0.0

for params in random_params:
    val_accuracy = train_and_evaluate(params)
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        best_params = params

print(f"Best Configuration: {best_params}")
print(f"Best Validation Accuracy: {best_val_accuracy:.4f}")
# Out:
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.35930859737204657), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0015751320499779737), 'optimizer': 'Adam', 'weight_decay': np.float64(2.7914686374528733e-06)}
# Best Validation Accuracy for this configuration: 0.6532
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2116167224336399), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00012966511753760416), 'optimizer': 'SGD', 'weight_decay': np.float64(6.798962421591126e-06)}
# Best Validation Accuracy for this configuration: 0.5996
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2001557531682029), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0004059611610484307), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0164038588691218e-06)}
# Best Validation Accuracy for this configuration: 0.6373
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2582458280396084), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.00012397420340784152), 'optimizer': 'SGD', 'weight_decay': np.float64(2.3246728489504338e-06)}
# Best Validation Accuracy for this configuration: 0.6461
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21812128690656418), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.009256818992066877), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1128853174905741e-06)}
# Best Validation Accuracy for this configuration: 0.6647
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.33606150771755594), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 16, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.007902619549708232), 'optimizer': 'SGD', 'weight_decay': np.float64(3.658374977026925e-06)}
# Best Validation Accuracy for this configuration: 0.6594
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.26092275383467417), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0003034247005811288), 'optimizer': 'SGD', 'weight_decay': np.float64(1.3244581340099348e-06)}
# Best Validation Accuracy for this configuration: 0.6054
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3666389823472329), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 8, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00032927591344236165), 'optimizer': 'SGD', 'weight_decay': np.float64(5.693265147694793e-06)}
# Best Validation Accuracy for this configuration: 0.6417
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3040136042355622), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 8, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0035503048581283078), 'optimizer': 'SGD', 'weight_decay': np.float64(2.4839922470497287e-06)}
# Best Validation Accuracy for this configuration: 0.6541
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3195799957622171), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0011006988685589537), 'optimizer': 'SGD', 'weight_decay': np.float64(2.115097202168558e-06)}
# Best Validation Accuracy for this configuration: 0.6391
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3494640220274762), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0005170191786366995), 'optimizer': 'SGD', 'weight_decay': np.float64(4.046077970872007e-06)}
# Best Validation Accuracy for this configuration: 0.5182
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.22818484499495253), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00010746642789365083), 'optimizer': 'Adam', 'weight_decay': np.float64(5.918951335463644e-06)}
# Best Validation Accuracy for this configuration: 0.6559
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.25869763494360765), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.002592475660475161), 'optimizer': 'Adam', 'weight_decay': np.float64(6.168442780928038e-06)}
# Best Validation Accuracy for this configuration: 0.6581
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.21480893034681808), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.006759574377750826), 'optimizer': 'Adam', 'weight_decay': np.float64(4.200472316702196e-06)}
# Best Validation Accuracy for this configuration: 0.6608
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21908202329808227), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00214706263102288), 'optimizer': 'SGD', 'weight_decay': np.float64(4.340677011889402e-06)}
# Best Validation Accuracy for this configuration: 0.6413
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.31224868516954024), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0033233042062267943), 'optimizer': 'SGD', 'weight_decay': np.float64(1.7218087866151137e-06)}
# Best Validation Accuracy for this configuration: 0.6585
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2987591192728782), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0001124186209579306), 'optimizer': 'Adam', 'weight_decay': np.float64(1.5911796004861243e-06)}
# Best Validation Accuracy for this configuration: 0.6577
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3272820822527561), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.006533305220227739), 'optimizer': 'Adam', 'weight_decay': np.float64(4.021771380417216e-06)}
# Best Validation Accuracy for this configuration: 0.6612
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3511102277086098), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0003797544798678418), 'optimizer': 'SGD', 'weight_decay': np.float64(7.593951847871437e-06)}
# Best Validation Accuracy for this configuration: 0.6364
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3616240759128834), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0008185951005222201), 'optimizer': 'SGD', 'weight_decay': np.float64(1.5366326576125025e-06)}
# Best Validation Accuracy for this configuration: 0.6501
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3766560517837737), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0004325207525386532), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8712518787439869e-06)}
# Best Validation Accuracy for this configuration: 0.6546
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2854215577252513), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0004069701125895779), 'optimizer': 'SGD', 'weight_decay': np.float64(3.2415095286272737e-06)}
# Best Validation Accuracy for this configuration: 0.6439
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.29696599427179665), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.00047340227734041945), 'optimizer': 'Adam', 'weight_decay': np.float64(1.4732995024087021e-06)}
# Best Validation Accuracy for this configuration: 0.6621
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3037581243486732), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0003219814322305041), 'optimizer': 'SGD', 'weight_decay': np.float64(1.7855922645162278e-06)}
# Best Validation Accuracy for this configuration: 0.6382
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.34245411798488845), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00011851515660043118), 'optimizer': 'Adam', 'weight_decay': np.float64(9.475779710186507e-06)}
# Best Validation Accuracy for this configuration: 0.6147
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2102957502499979), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00030138649046798047), 'optimizer': 'SGD', 'weight_decay': np.float64(3.395741195444872e-06)}
# Best Validation Accuracy for this configuration: 0.6045
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.39713009082212014), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0005486670911103226), 'optimizer': 'Adam', 'weight_decay': np.float64(5.348307249011089e-06)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2940601268892077), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0011790965486776312), 'optimizer': 'SGD', 'weight_decay': np.float64(6.28557662373629e-06)}
# Best Validation Accuracy for this configuration: 0.6554
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2641560129943472), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0015197980620034217), 'optimizer': 'Adam', 'weight_decay': np.float64(1.6605082878338255e-06)}
# Best Validation Accuracy for this configuration: 0.6616
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.30241861165985623), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.007604077403300607), 'optimizer': 'SGD', 'weight_decay': np.float64(2.436325699083497e-06)}
# Best Validation Accuracy for this configuration: 0.6541
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3675420211814656), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.00026190466946509494), 'optimizer': 'Adam', 'weight_decay': np.float64(7.539444583132283e-06)}
# Best Validation Accuracy for this configuration: 0.6559
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24571000435945994), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0011463075602214), 'optimizer': 'SGD', 'weight_decay': np.float64(9.914109236071422e-06)}
# Best Validation Accuracy for this configuration: 0.6523
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3794431515906654), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0004764963542138519), 'optimizer': 'Adam', 'weight_decay': np.float64(5.016003489764549e-06)}
# Best Validation Accuracy for this configuration: 0.6457
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.37942205199051543), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.005033347298469074), 'optimizer': 'Adam', 'weight_decay': np.float64(1.450870712623418e-06)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.33379765094284575), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.002123261760236048), 'optimizer': 'Adam', 'weight_decay': np.float64(1.922741830375281e-06)}
# Best Validation Accuracy for this configuration: 0.6590
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.30974675787331724), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.00022482805601745356), 'optimizer': 'SGD', 'weight_decay': np.float64(1.7268280218698493e-06)}
# Best Validation Accuracy for this configuration: 0.6125
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.23576454184426576), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00041316315364585784), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2407228136107147e-06)}
# Best Validation Accuracy for this configuration: 0.6413
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3272665236371791), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.009073727166787787), 'optimizer': 'Adam', 'weight_decay': np.float64(7.799137106526667e-06)}
# Best Validation Accuracy for this configuration: 0.6603
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.28687887310208576), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.001424976719890157), 'optimizer': 'SGD', 'weight_decay': np.float64(7.314212353782314e-06)}
# Best Validation Accuracy for this configuration: 0.6377
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.34449042305230104), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0001222383681374562), 'optimizer': 'SGD', 'weight_decay': np.float64(8.71883751827232e-06)}
# Best Validation Accuracy for this configuration: 0.6160
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.25591206835935176), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0080564495905871), 'optimizer': 'Adam', 'weight_decay': np.float64(2.6803045790696394e-06)}
# Best Validation Accuracy for this configuration: 0.6581
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3144584938341677), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0003880590213919323), 'optimizer': 'Adam', 'weight_decay': np.float64(1.552069023093634e-06)}
# Best Validation Accuracy for this configuration: 0.6541
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.26338440103125554), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0074526297929126415), 'optimizer': 'SGD', 'weight_decay': np.float64(8.51171032003087e-06)}
# Best Validation Accuracy for this configuration: 0.6546
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2194352987541537), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00019061980918553997), 'optimizer': 'Adam', 'weight_decay': np.float64(1.9737429347913066e-06)}
# Best Validation Accuracy for this configuration: 0.6466
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3481537235508409), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0026171101019856905), 'optimizer': 'Adam', 'weight_decay': np.float64(1.9660377127695594e-06)}
# Best Validation Accuracy for this configuration: 0.6554
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2839561712892553), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.006706271090367465), 'optimizer': 'SGD', 'weight_decay': np.float64(1.0120101371205066e-06)}
# Best Validation Accuracy for this configuration: 0.6594
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.35965903579335506), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0004742314081112146), 'optimizer': 'SGD', 'weight_decay': np.float64(3.7919700238294456e-06)}
# Best Validation Accuracy for this configuration: 0.6426
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.31565602819923483), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.00020421292855620022), 'optimizer': 'SGD', 'weight_decay': np.float64(1.934377589719021e-06)}
# Best Validation Accuracy for this configuration: 0.6014
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3720809236623351), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00040413924830603846), 'optimizer': 'Adam', 'weight_decay': np.float64(1.339863364992539e-06)}
# Best Validation Accuracy for this configuration: 0.6572
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3655738007575178), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00014814770564945435), 'optimizer': 'Adam', 'weight_decay': np.float64(1.5645160902228388e-06)}
# Best Validation Accuracy for this configuration: 0.6497
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3081270243220213), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0010779551620950165), 'optimizer': 'SGD', 'weight_decay': np.float64(1.099176707572297e-06)}
# Best Validation Accuracy for this configuration: 0.6426
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.25416645025241486), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0003174834234508597), 'optimizer': 'SGD', 'weight_decay': np.float64(9.17589456473821e-06)}
# Best Validation Accuracy for this configuration: 0.6293
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.28566289498802155), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.000222120498838994), 'optimizer': 'Adam', 'weight_decay': np.float64(2.7691866530691e-06)}
# Best Validation Accuracy for this configuration: 0.6484
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3098453329412241), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0018903454995625151), 'optimizer': 'Adam', 'weight_decay': np.float64(5.468861396433842e-06)}
# Best Validation Accuracy for this configuration: 0.6625
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2871345797355782), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00031294064907273154), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4409418256708586e-06)}
# Best Validation Accuracy for this configuration: 0.6302
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.20287869772595118), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00041959143915411615), 'optimizer': 'SGD', 'weight_decay': np.float64(5.054263262694104e-06)}
# Best Validation Accuracy for this configuration: 0.6329
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.20343222036635006), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0004927295881136123), 'optimizer': 'SGD', 'weight_decay': np.float64(2.71551151812582e-06)}
# Best Validation Accuracy for this configuration: 0.6413
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.20961178483940676), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.00012319923739394199), 'optimizer': 'Adam', 'weight_decay': np.float64(1.0358682939127023e-06)}
# Best Validation Accuracy for this configuration: 0.6466
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.30062725171601756), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0017049134180784924), 'optimizer': 'SGD', 'weight_decay': np.float64(4.389542701552222e-06)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.37343978671100075), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0019345343114003423), 'optimizer': 'Adam', 'weight_decay': np.float64(6.474469312238083e-06)}
# Best Validation Accuracy for this configuration: 0.6612
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.38829296175530503), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00200895192351347), 'optimizer': 'Adam', 'weight_decay': np.float64(1.5696077514530494e-06)}
# Best Validation Accuracy for this configuration: 0.6581
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24291782394167483), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0017238829276328498), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1781176120963398e-06)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.27707932419311304), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 8, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00033219191364984655), 'optimizer': 'Adam', 'weight_decay': np.float64(1.3126980122725883e-06)}
# Best Validation Accuracy for this configuration: 0.6515
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2696673208906395), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.002952174928235019), 'optimizer': 'Adam', 'weight_decay': np.float64(9.280696094809067e-06)}
# Best Validation Accuracy for this configuration: 0.6585
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23548790875594458), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 16, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0029059993351330735), 'optimizer': 'SGD', 'weight_decay': np.float64(2.3551473597915168e-06)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.316108802468782), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.0003000500611290206), 'optimizer': 'Adam', 'weight_decay': np.float64(5.634703493906651e-06)}
# Best Validation Accuracy for this configuration: 0.6417
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2476472304807959), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0010244829732647415), 'optimizer': 'SGD', 'weight_decay': np.float64(2.4525512205849157e-06)}
# Best Validation Accuracy for this configuration: 0.6439
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.37910464569924013), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.004946366454603174), 'optimizer': 'Adam', 'weight_decay': np.float64(2.0859967986741853e-06)}
# Best Validation Accuracy for this configuration: 0.6577
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3353539808848607), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0018351620695519345), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2351057604967103e-06)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2657329090739832), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.007805290757759147), 'optimizer': 'SGD', 'weight_decay': np.float64(6.160530936099101e-06)}
# Best Validation Accuracy for this configuration: 0.6559
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.38618582113745853), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0007639430825545341), 'optimizer': 'Adam', 'weight_decay': np.float64(3.5149226327124444e-06)}
# Best Validation Accuracy for this configuration: 0.6581
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.22341340328552117), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.004719845128935752), 'optimizer': 'Adam', 'weight_decay': np.float64(1.262184016150726e-06)}
# Best Validation Accuracy for this configuration: 0.6608
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2852182950093882), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0060784635611185744), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2060040899560858e-06)}
# Best Validation Accuracy for this configuration: 0.6599
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24664561448490557), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.004222786597659888), 'optimizer': 'Adam', 'weight_decay': np.float64(8.085254715579302e-06)}
# Best Validation Accuracy for this configuration: 0.6585
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.35067563705178834), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.003583387974072159), 'optimizer': 'SGD', 'weight_decay': np.float64(5.070892038138333e-06)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.38127087701894724), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0003216357743681944), 'optimizer': 'SGD', 'weight_decay': np.float64(2.9421217593944137e-06)}
# Best Validation Accuracy for this configuration: 0.6280
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3481947721821337), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0030790965980082665), 'optimizer': 'Adam', 'weight_decay': np.float64(3.831499428350751e-06)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.280044578574405), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.00546007057621134), 'optimizer': 'SGD', 'weight_decay': np.float64(2.7310888651949228e-06)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2024308949379633), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00012212415354459548), 'optimizer': 'Adam', 'weight_decay': np.float64(9.839313451216209e-06)}
# Best Validation Accuracy for this configuration: 0.6098
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.25059803359784827), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00021499623954099835), 'optimizer': 'Adam', 'weight_decay': np.float64(4.963050439824975e-06)}
# Best Validation Accuracy for this configuration: 0.6581
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.39916627500587415), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.006343311240451776), 'optimizer': 'Adam', 'weight_decay': np.float64(8.227243319085804e-06)}
# Best Validation Accuracy for this configuration: 0.6599
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.39008229681531176), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0002184539026816473), 'optimizer': 'SGD', 'weight_decay': np.float64(2.9086964772397663e-06)}
# Best Validation Accuracy for this configuration: 0.5930
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.24587894914098996), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0003310546754142205), 'optimizer': 'Adam', 'weight_decay': np.float64(4.9907028682304075e-06)}
# Best Validation Accuracy for this configuration: 0.6484
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2559527014337892), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.004416461875953999), 'optimizer': 'SGD', 'weight_decay': np.float64(2.609991288286347e-06)}
# Best Validation Accuracy for this configuration: 0.6523
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.322683039187158), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.005666605409239297), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1097334326431901e-06)}
# Best Validation Accuracy for this configuration: 0.6616
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.28225102331707386), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00943088086367435), 'optimizer': 'Adam', 'weight_decay': np.float64(2.3808880209277667e-06)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2761781713262043), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.00137455758393629), 'optimizer': 'Adam', 'weight_decay': np.float64(2.9423420590187546e-06)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.22677042376012665), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0024178468822764134), 'optimizer': 'Adam', 'weight_decay': np.float64(9.993501299743475e-06)}
# Best Validation Accuracy for this configuration: 0.6554
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.38263315045152857), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.007754101110919913), 'optimizer': 'SGD', 'weight_decay': np.float64(2.386989723474738e-06)}
# Best Validation Accuracy for this configuration: 0.6448
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.29010882706201874), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00035437542252607287), 'optimizer': 'SGD', 'weight_decay': np.float64(1.6929448301287222e-06)}
# Best Validation Accuracy for this configuration: 0.6444
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3513998264344458), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00011075656652280413), 'optimizer': 'SGD', 'weight_decay': np.float64(3.313658135010504e-06)}
# Best Validation Accuracy for this configuration: 0.5589
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3662742980125003), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00862874293644351), 'optimizer': 'SGD', 'weight_decay': np.float64(7.527549198597607e-06)}
# Best Validation Accuracy for this configuration: 0.6590
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.31799117942752725), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.003237982605211301), 'optimizer': 'Adam', 'weight_decay': np.float64(4.358743943946543e-06)}
# Best Validation Accuracy for this configuration: 0.6577
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24259283230178216), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.001645037108263601), 'optimizer': 'SGD', 'weight_decay': np.float64(2.4674254795084354e-06)}
# Best Validation Accuracy for this configuration: 0.6488
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.21820041821026606), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0007976656582084649), 'optimizer': 'Adam', 'weight_decay': np.float64(2.4919698429507505e-06)}
# Best Validation Accuracy for this configuration: 0.6594
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3047204552030023), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0008292655346047046), 'optimizer': 'Adam', 'weight_decay': np.float64(3.1053910219894902e-06)}
# Best Validation Accuracy for this configuration: 0.6568
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2132471955703732), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0009665764018232937), 'optimizer': 'Adam', 'weight_decay': np.float64(1.618567408107854e-06)}
# Best Validation Accuracy for this configuration: 0.6501
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.24802912375563863), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0008322203245630678), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4187396082894413e-06)}
# Best Validation Accuracy for this configuration: 0.6479
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.33953351473938637), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.005605769156531545), 'optimizer': 'Adam', 'weight_decay': np.float64(4.651122077279864e-06)}
# Best Validation Accuracy for this configuration: 0.6581
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3203870791081921), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00021770586351835763), 'optimizer': 'SGD', 'weight_decay': np.float64(2.2264821335814518e-06)}
# Best Validation Accuracy for this configuration: 0.6058
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21774050675141113), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.000515208439577299), 'optimizer': 'SGD', 'weight_decay': np.float64(2.3135019028808917e-06)}
# Best Validation Accuracy for this configuration: 0.6457
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2660199026620311), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.003970276908151301), 'optimizer': 'Adam', 'weight_decay': np.float64(4.87286878607263e-06)}
# Best Validation Accuracy for this configuration: 0.6612
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.37471572482135546), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.00035789472410260544), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2148341944293501e-06)}
# Best Validation Accuracy for this configuration: 0.6541
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.23690420387127548), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0009312064391199294), 'optimizer': 'SGD', 'weight_decay': np.float64(5.753808572383158e-06)}
# Best Validation Accuracy for this configuration: 0.6444
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2925069432266296), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0003197966342900488), 'optimizer': 'Adam', 'weight_decay': np.float64(4.865926060719042e-06)}
# Best Validation Accuracy for this configuration: 0.6457
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.30233548842313324), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0007849188043830674), 'optimizer': 'Adam', 'weight_decay': np.float64(2.4955359610947715e-06)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.25384864618987624), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0004407155063074604), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2280168578516186e-06)}
# Best Validation Accuracy for this configuration: 0.6426
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.22395242636385027), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0008870332161189294), 'optimizer': 'SGD', 'weight_decay': np.float64(6.1541947952575405e-06)}
# Best Validation Accuracy for this configuration: 0.6453
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2959164203508501), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0014917025634138866), 'optimizer': 'SGD', 'weight_decay': np.float64(3.85953900798947e-06)}
# Best Validation Accuracy for this configuration: 0.6453
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.22551606055911277), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.006299336297470396), 'optimizer': 'SGD', 'weight_decay': np.float64(3.722016590907773e-06)}
# Best Validation Accuracy for this configuration: 0.6599
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.29964953956978807), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0002981628860349919), 'optimizer': 'SGD', 'weight_decay': np.float64(1.6800909703642655e-06)}
# Best Validation Accuracy for this configuration: 0.6187
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.24919154567690163), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.00014989089372106597), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4906428293975966e-06)}
# Best Validation Accuracy for this configuration: 0.6058
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.36846280705963635), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.002476982422703723), 'optimizer': 'SGD', 'weight_decay': np.float64(1.2943117749495197e-06)}
# Best Validation Accuracy for this configuration: 0.6506
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.31519968356113204), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.008915266418252249), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4821344004164957e-06)}
# Best Validation Accuracy for this configuration: 0.6590
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3641722946306705), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.001390674140149984), 'optimizer': 'Adam', 'weight_decay': np.float64(6.895766681594235e-06)}
# Best Validation Accuracy for this configuration: 0.6585
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2374087497115047), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0010356684762667942), 'optimizer': 'Adam', 'weight_decay': np.float64(3.3871936241100627e-06)}
# Best Validation Accuracy for this configuration: 0.6594
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.32212400848832656), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.007311873757428549), 'optimizer': 'Adam', 'weight_decay': np.float64(3.408705116949428e-06)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.27384609630197926), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0012526910073452128), 'optimizer': 'SGD', 'weight_decay': np.float64(2.1006507088892956e-06)}
# Best Validation Accuracy for this configuration: 0.6630
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21757362224853138), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0033147877085280015), 'optimizer': 'Adam', 'weight_decay': np.float64(2.9728034823795807e-06)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.28236818282945375), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.005028690651008761), 'optimizer': 'SGD', 'weight_decay': np.float64(9.226285952336877e-06)}
# Best Validation Accuracy for this configuration: 0.6559
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3865876134199909), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0002303913302543585), 'optimizer': 'Adam', 'weight_decay': np.float64(8.44207922694021e-06)}
# Best Validation Accuracy for this configuration: 0.6528
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3148946226359824), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0031695955578077764), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4576590148984936e-06)}
# Best Validation Accuracy for this configuration: 0.6249
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.23728099735762884), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.006542327204769315), 'optimizer': 'Adam', 'weight_decay': np.float64(7.5370351525086285e-06)}
# Best Validation Accuracy for this configuration: 0.6612
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3365964126834265), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0017709369048225063), 'optimizer': 'Adam', 'weight_decay': np.float64(5.592543620519214e-06)}
# Best Validation Accuracy for this configuration: 0.6519
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.31549725418122515), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.0011580170650041996), 'optimizer': 'Adam', 'weight_decay': np.float64(8.062544245508247e-06)}
# Best Validation Accuracy for this configuration: 0.6616
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3085698621226818), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0018005952749128046), 'optimizer': 'SGD', 'weight_decay': np.float64(4.93989374349446e-06)}
# Best Validation Accuracy for this configuration: 0.6554
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3588050378540592), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0030403376826218754), 'optimizer': 'Adam', 'weight_decay': np.float64(6.1460658807651895e-06)}
# Best Validation Accuracy for this configuration: 0.6546
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3504806240077646), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0030753360921253873), 'optimizer': 'SGD', 'weight_decay': np.float64(1.6015650879120765e-06)}
# Best Validation Accuracy for this configuration: 0.6444
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.35249173714813814), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 8, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0001606319980667638), 'optimizer': 'Adam', 'weight_decay': np.float64(1.2901248392777058e-06)}
# Best Validation Accuracy for this configuration: 0.6439
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.29140004385633567), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00019945037385407478), 'optimizer': 'Adam', 'weight_decay': np.float64(2.564219373433278e-06)}
# Best Validation Accuracy for this configuration: 0.6399
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3440073073092149), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0013521245390022488), 'optimizer': 'SGD', 'weight_decay': np.float64(1.785661186889716e-06)}
# Best Validation Accuracy for this configuration: 0.6559
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3653597655618157), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.001468194488855067), 'optimizer': 'SGD', 'weight_decay': np.float64(2.652142544918623e-06)}
# Best Validation Accuracy for this configuration: 0.6470
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3894566679223631), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.001027489417878588), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8030822240838284e-06)}
# Best Validation Accuracy for this configuration: 0.6550
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3744247817888303), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00011118474633488189), 'optimizer': 'Adam', 'weight_decay': np.float64(1.4208199383089715e-06)}
# Best Validation Accuracy for this configuration: 0.6484
# ...
# Best Validation Accuracy for this configuration: 0.6590
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.22355021657802823), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00013625448288518975), 'optimizer': 'Adam', 'weight_decay': np.float64(4.481468914972315e-06)}
# Best Validation Accuracy for this configuration: 0.6479
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.34404051632645916), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.00018783272544168123), 'optimizer': 'Adam', 'weight_decay': np.float64(1.8471339616091153e-06)}
# Best Validation Accuracy for this configuration: 0.6258
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.31948262043406167), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0009739747549444256), 'optimizer': 'SGD', 'weight_decay': np.float64(8.211300501953524e-06)}
# Best Validation Accuracy for this configuration: 0.6506
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.28087630030980487), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00021506351394714012), 'optimizer': 'Adam', 'weight_decay': np.float64(1.528871273695205e-06)}
# Best Validation Accuracy for this configuration: 0.6519
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3206304218932777), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.004722347928102217), 'optimizer': 'Adam', 'weight_decay': np.float64(2.2681549302200485e-06)}
# Best Validation Accuracy for this configuration: 0.6577
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3443065722243811), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 8, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.0006212962697189355), 'optimizer': 'SGD', 'weight_decay': np.float64(8.646288834805789e-06)}
# Best Validation Accuracy for this configuration: 0.6510
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.29675098838648256), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0002108762916775634), 'optimizer': 'SGD', 'weight_decay': np.float64(1.1257081581410336e-06)}
# Best Validation Accuracy for this configuration: 0.6311
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3910472625446958), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 8, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.003481965049128929), 'optimizer': 'Adam', 'weight_decay': np.float64(2.2099565344679883e-06)}
# Best Validation Accuracy for this configuration: 0.6639
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3456377512407207), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.001572432880280064), 'optimizer': 'Adam', 'weight_decay': np.float64(1.7636078905724134e-06)}
# Best Validation Accuracy for this configuration: 0.6599
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.21555306881579142), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0015151698985443685), 'optimizer': 'Adam', 'weight_decay': np.float64(2.0634623864647106e-06)}
# Best Validation Accuracy for this configuration: 0.6630
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.38346271509244856), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0024050298162586648), 'optimizer': 'Adam', 'weight_decay': np.float64(1.5315561686017188e-06)}
# Best Validation Accuracy for this configuration: 0.6568
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3916341586007861), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 16, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.003296641269281476), 'optimizer': 'Adam', 'weight_decay': np.float64(4.923529728095202e-06)}
# Best Validation Accuracy for this configuration: 0.6603
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3961153600359977), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.009447915839398248), 'optimizer': 'Adam', 'weight_decay': np.float64(4.676462590566531e-06)}
# Best Validation Accuracy for this configuration: 0.6608
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.34111503450313774), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.001293043581592578), 'optimizer': 'SGD', 'weight_decay': np.float64(8.2316765571209e-06)}
# Best Validation Accuracy for this configuration: 0.6364
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2241045157572929), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.007059799883532963), 'optimizer': 'SGD', 'weight_decay': np.float64(2.640965085582238e-06)}
# Best Validation Accuracy for this configuration: 0.6479
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2948428433314928), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0004347113170001252), 'optimizer': 'SGD', 'weight_decay': np.float64(4.411097432776689e-06)}
# Best Validation Accuracy for this configuration: 0.6426
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3192539756964106), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.005888391987151447), 'optimizer': 'Adam', 'weight_decay': np.float64(2.1871318436814158e-06)}
# Best Validation Accuracy for this configuration: 0.6563
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2808970899363702), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00119945120407958), 'optimizer': 'Adam', 'weight_decay': np.float64(4.588335594998449e-06)}
# Best Validation Accuracy for this configuration: 0.6608
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.32517827528740184), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [256, 128], 'learning_rate': np.float64(0.00011189265091892585), 'optimizer': 'SGD', 'weight_decay': np.float64(9.780055365032013e-06)}
# Best Validation Accuracy for this configuration: 0.6165
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3749403345368399), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.00013805731141185035), 'optimizer': 'SGD', 'weight_decay': np.float64(2.2423934462088653e-06)}
# Best Validation Accuracy for this configuration: 0.6178
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21770868212272365), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.0014504889159706385), 'optimizer': 'SGD', 'weight_decay': np.float64(9.640142844821018e-06)}
# Best Validation Accuracy for this configuration: 0.6466
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.21833986702228603), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 16, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.002986514331666628), 'optimizer': 'SGD', 'weight_decay': np.float64(1.007735045444389e-06)}
# Best Validation Accuracy for this configuration: 0.6470
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2709244315281553), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 8, 'hidden_layer_sizes': [32], 'learning_rate': np.float64(0.0026984018782012526), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1017756999772791e-06)}
# Best Validation Accuracy for this configuration: 0.6599
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3820678204115069), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 4, 'hidden_layer_sizes': [128], 'learning_rate': np.float64(0.0006071000673896077), 'optimizer': 'SGD', 'weight_decay': np.float64(1.6529278148136077e-06)}
# Best Validation Accuracy for this configuration: 0.6426
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.3595978644286767), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.009218516347279769), 'optimizer': 'Adam', 'weight_decay': np.float64(8.805053970009188e-06)}
# Best Validation Accuracy for this configuration: 0.6546
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.38074479343505413), 'embedding_hidden_layer_sizes': [256, 128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.009601459454014048), 'optimizer': 'Adam', 'weight_decay': np.float64(2.521042902310876e-06)}
# Best Validation Accuracy for this configuration: 0.6590
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.32992932979847367), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0001241339897969432), 'optimizer': 'Adam', 'weight_decay': np.float64(1.6614459180636926e-06)}
# Best Validation Accuracy for this configuration: 0.6337
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.39145405259666516), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00181784079748647), 'optimizer': 'Adam', 'weight_decay': np.float64(7.65219246963617e-06)}
# Best Validation Accuracy for this configuration: 0.6599
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3194548144860682), 'embedding_hidden_layer_sizes': [128], 'embedding_size': 4, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.0006201318507156901), 'optimizer': 'SGD', 'weight_decay': np.float64(3.0987485807701254e-06)}
# Best Validation Accuracy for this configuration: 0.6413
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.23077918126797103), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 8, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.0031314336070643466), 'optimizer': 'Adam', 'weight_decay': np.float64(3.9168770093987675e-06)}
# Best Validation Accuracy for this configuration: 0.6608
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.37202536328358476), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00033978177846787896), 'optimizer': 'SGD', 'weight_decay': np.float64(2.9969315815326983e-06)}
# Best Validation Accuracy for this configuration: 0.5957
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3911302996459507), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 8, 'hidden_layer_sizes': [32, 32], 'learning_rate': np.float64(0.00045509569860877264), 'optimizer': 'Adam', 'weight_decay': np.float64(3.55514542620511e-06)}
# Best Validation Accuracy for this configuration: 0.6510
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2562781921155054), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0003307558753839457), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1188801823439863e-06)}
# Best Validation Accuracy for this configuration: 0.6541
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2162092431815296), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.009615030590341713), 'optimizer': 'SGD', 'weight_decay': np.float64(3.1271342558566116e-06)}
# Best Validation Accuracy for this configuration: 0.6519
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.30321580408872334), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 8, 'hidden_layer_sizes': [64], 'learning_rate': np.float64(0.0004961561921251729), 'optimizer': 'SGD', 'weight_decay': np.float64(3.4976706117980963e-06)}
# Best Validation Accuracy for this configuration: 0.6448
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.25340565403388426), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32, 16], 'learning_rate': np.float64(0.00030943616108630967), 'optimizer': 'Adam', 'weight_decay': np.float64(7.367059898886059e-06)}
# Best Validation Accuracy for this configuration: 0.6532
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.2668017757490476), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 4, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.002292353253158894), 'optimizer': 'Adam', 'weight_decay': np.float64(5.000238711281931e-06)}
# Best Validation Accuracy for this configuration: 0.6541
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.23172102105861475), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [128, 128], 'learning_rate': np.float64(0.0008529822964720056), 'optimizer': 'Adam', 'weight_decay': np.float64(6.696020129599233e-06)}
# Best Validation Accuracy for this configuration: 0.6546
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.36398938348162), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 8, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.00020966203273649055), 'optimizer': 'SGD', 'weight_decay': np.float64(3.5989990750614894e-06)}
# Best Validation Accuracy for this configuration: 0.5319
# Testing configuration: {'batch_size': 32, 'dropout': np.float64(0.3014935467521673), 'embedding_hidden_layer_sizes': [16], 'embedding_size': 8, 'hidden_layer_sizes': [64, 16], 'learning_rate': np.float64(0.009170063774757266), 'optimizer': 'Adam', 'weight_decay': np.float64(1.3057013609387426e-06)}
# Best Validation Accuracy for this configuration: 0.6572
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.32680114061992227), 'embedding_hidden_layer_sizes': [16, 8], 'embedding_size': 16, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.0003687108320159777), 'optimizer': 'Adam', 'weight_decay': np.float64(3.477495516044976e-06)}
# Best Validation Accuracy for this configuration: 0.6422
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.36802430054824375), 'embedding_hidden_layer_sizes': [32], 'embedding_size': 16, 'hidden_layer_sizes': [16, 8], 'learning_rate': np.float64(0.00016033172161735484), 'optimizer': 'SGD', 'weight_decay': np.float64(1.4919472741254382e-06)}
# Best Validation Accuracy for this configuration: 0.5226
# Testing configuration: {'batch_size': 64, 'dropout': np.float64(0.2135674118210344), 'embedding_hidden_layer_sizes': [64], 'embedding_size': 4, 'hidden_layer_sizes': [64, 32], 'learning_rate': np.float64(0.002613027673617746), 'optimizer': 'SGD', 'weight_decay': np.float64(2.2175992035394375e-06)}
# Best Validation Accuracy for this configuration: 0.6506
# Best Configuration: {'batch_size': 64, 'dropout': np.float64(0.21812128690656418), 'embedding_hidden_layer_sizes': [64, 32], 'embedding_size': 16, 'hidden_layer_sizes': [64, 64], 'learning_rate': np.float64(0.009256818992066877), 'optimizer': 'Adam', 'weight_decay': np.float64(1.1128853174905741e-06)}
# Best Validation Accuracy: 0.6647
