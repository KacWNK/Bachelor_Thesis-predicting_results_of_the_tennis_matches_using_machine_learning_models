# %%
import json
import pandas as pd

# %%
matches = pd.read_csv("../data/merged_matches.csv")

# %%
scraped_time_json = {}
for year in range(2018, 2024):
    with open(f"../../raw_data/tennis_explorer/scraped_match_time_{year}.json") as f:
        data = json.load(f)
        scraped_time_json.update(data)

# %% [markdown]
# ### Zrobimy player_dict żeby można było dopisać player_id z matches df do scraped_time_json na podstawie nazw zawodników

# %%
winner_dict = dict(zip(matches['winner_name'], matches['winner_id']))
loser_dict = dict(zip(matches['loser_name'], matches['loser_id']))

player_dict = {**loser_dict, **winner_dict}
player_dict
# Out:
# {'Diego Schwartzman': 106043,
#  'Steve Johnson': 105449,
#  'Leonardo Mayer': 104919,
#  'Frances Tiafoe': 126207,
#  'John Patrick Smith': 105441,
#  'Ernesto Escobedo': 124014,
#  'Jordan Thompson': 111442,
#  'Federico Delbonis': 105643,
#  'Gilles Muller': 104180,
#  'Denis Shapovalov': 133430,
#  'Damir Dzumhur': 106000,
#  'Peter Polansky': 105166,
#  'Horacio Zeballos': 104547,
#  'Matthew Ebden': 105051,
#  'Mischa Zverev': 104999,
#  'Milos Raonic': 105683,
#  'Jared Donaldson': 111577,
#  'Yannick Hanfmann': 105870,
#  'Hyeon Chung': 111202,
#  'John Millman': 105357,
#  'Michael Mmoh': 111581,
#  'Alexandr Dolgopolov': 105238,
#  'Denis Istomin': 104797,
#  'Kyle Edmund': 106378,
#  'Alex De Minaur': 200282,
#  'Grigor Dimitrov': 105777,
#  'Ryan Harrison': 105992,
#  'Cedrik Marcel Stebe': 105649,
#  'Dudi Sela': 104534,
#  'Evgeny Donskoy': 105539,
#  'Thomas Fabbiano': 105341,
#  'Florian Mayer': 104252,
#  'Pablo Carreno Busta': 105807,
#  'Andreas Haider Maurer': 104890,
#  'Guillermo Garcia Lopez': 104198,
#  'Filip Krajinovic': 105936,
#  'Malek Jaziri': 104291,
#  'Viktor Troicki': 104678,
#  'Tomas Berdych': 104607,
#  'Jabor Al Mutawa': 106325,
#  'Victor Estrella': 103607,
#  'Albert Ramos': 105077,
#  'Paolo Lorenzi': 103893,
#  'Nikoloz Basilashvili': 105932,
#  'Feliciano Lopez': 103852,
#  'Fernando Verdasco': 104269,
#  'Matteo Berrettini': 126610,
#  'Aljaz Bedene': 105379,
#  'Stefano Travaglia': 105882,
#  'Jan Lennard Struff': 105526,
#  'Richard Gasquet': 104755,
#  'Mirza Basic': 105806,
#  'Borna Coric': 106432,
#  'Stefanos Tsitsipas': 126774,
#  'Peter Gojowczyk': 105376,
#  'Guido Pella': 105550,
#  'Dominic Thiem': 106233,
#  'Andrey Rublev': 126094,
#  'Pablo Andujar': 104665,
#  'Nicolas Kicker': 106044,
#  'Radu Albot': 105430,
#  'Jiri Vesely': 106210,
#  'Marco Cecchinato': 106065,
#  'Tennys Sandgren': 105815,
#  'Roberto Carballes Baena': 106148,
#  'Sumit Nagal': 111576,
#  'Marius Copil': 105657,
#  'Blaz Kavcic': 104882,
#  'Arjun Kadhe': 111459,
#  'Ruben Bemelmans': 105074,
#  'Marton Fucsovics': 105916,
#  'Yuki Bhambri': 106026,
#  'Nicolas Jarry': 111797,
#  'Roberto Bautista Agut': 105138,
#  'Laslo Djere': 111513,
#  'Ramkumar Ramanathan': 106368,
#  'Ilya Ivashka': 125802,
#  'Thiago Monteiro': 106329,
#  'Pierre Hugues Herbert': 105732,
#  'Ricardo Ojeda Lara': 106120,
#  'Mikhail Kukushkin': 105062,
#  'Robin Haase': 104898,
#  'Marin Cilic': 105227,
#  'Benoit Paire': 105332,
#  'Kevin Anderson': 104731,
#  'Donald Young': 105385,
#  'Yibing Wu': 200059,
#  'Yuichi Sugita': 105216,
#  'Michael Venus': 105030,
#  'Rogerio Dutra Silva': 104297,
#  'Taro Daniel': 106121,
#  'Tim Smyczek': 105065,
#  'Liam Caruana': 132482,
#  'Casper Ruud': 134770,
#  'Lukas Lacko': 105041,
#  'Sam Querrey': 105023,
#  'Jack Sock': 106058,
#  'Joao Sousa': 105311,
#  'Pablo Cuevas': 104655,
#  'John Isner': 104545,
#  'Karen Khachanov': 111575,
#  'David Ferrer': 103970,
#  'Juan Martin del Potro': 105223,
#  'Alex Bolt': 106109,
#  'Alexei Popyrin': 200615,
#  'Philipp Kohlschreiber': 104259,
#  'Aleksandar Vukic': 126846,
#  'Gilles Simon': 104468,
#  'Ricardas Berankis': 105575,
#  'Adrian Mannarino': 105173,
#  'Fabio Fognini': 104926,
#  'Jason Kubler': 106186,
#  'Mikhail Youzhny': 104022,
#  'Corentin Moutet': 144895,
#  'Dennis Novak': 110602,
#  'Dusan Lajovic': 105583,
#  'Vasek Pospisil': 105577,
#  'Elias Ymer': 111200,
#  'Gerald Melzer': 105589,
#  'Quentin Halys': 111460,
#  'Lucas Pouille': 106298,
#  'Salvatore Caruso': 106099,
#  'Dustin Brown': 104460,
#  'Kevin King': 110536,
#  'Vaclav Safranek': 106324,
#  'Matthias Bachinger': 104897,
#  'Jeremy Chardy': 104871,
#  'Soon Woo Kwon': 126952,
#  'Thanasi Kokkinakis': 106423,
#  'Jaume Munar': 144719,
#  'Yoshihito Nishioka': 106415,
#  'Marcos Baghdatis': 104571,
#  'Mackenzie Mcdonald': 111456,
#  'Denis Kudla': 106045,
#  'Gael Monfils': 104792,
#  'David Goffin': 105676,
#  'Daniil Medvedev': 106421,
#  'Lorenzo Sonego': 132283,
#  'Stan Wawrinka': 104527,
#  'Ivo Karlovic': 103333,
#  'Jo-Wilfried Tsonga': 104542,
#  'Maximilian Marterer': 109739,
#  'Julien Benneteau': 103898,
#  'Alexander Zverev': 100644,
#  'Andreas Seppi': 104312,
#  'Nick Kyrgios': 106401,
#  'Novak Djokovic': 104925,
#  'Rafael Nadal': 104745,
#  'Norbert Gombos': 105613,
#  'Yannick Maden': 120424,
#  'Kenny De Schepper': 104932,
#  'Calvin Hemery': 123921,
#  'Nicolas Mahut': 103917,
#  'Carlos Taberner': 126535,
#  'Adrian Menendez Maceiras': 104629,
#  'Carlos Berlocq': 104122,
#  'Thomaz Bellucci': 105064,
#  'Federico Gaio': 105943,
#  'Facundo Bagnis': 105487,
#  'Roberto Quiroz': 105933,
#  'Alessandro Giannessi': 105561,
#  'Andrej Martin': 105413,
#  'Dimitar Kuzmanov': 106220,
#  'Alexander Donski': 200574,
#  'Adrian Andreev': 202090,
#  'Ernests Gulbis': 105208,
#  'Martin Klizan': 105373,
#  'Jozef Kovalik': 106075,
#  'Pedro Cachin': 106398,
#  'Gastao Elias': 105671,
#  'Sebastian Korda': 200624,
#  'Bjorn Fratangelo': 106216,
#  'Noah Rubin': 111511,
#  'Kei Nishikori': 105453,
#  'Felix Auger Aliassime': 200000,
#  'Thiemo De Bakker': 105217,
#  'Tallon Griekspoor': 134868,
#  'Cameron Norrie': 111815,
#  'Alexander Bublik': 122330,
#  'Darian King': 105985,
#  'Franko Skugor': 105015,
#  'Reilly Opelka': 124187,
#  'Taylor Fritz': 126203,
#  'Hugo Gaston': 200384,
#  'Sergiy Stakhovsky': 104660,
#  'Lucas Gomez': 106412,
#  'Gleb Sakharov': 105163,
#  'Renzo Olivo': 105952,
#  'Thiago Seyboth Wild': 205734,
#  'Joao Domingues': 106249,
#  'Sebastian Ofner': 124116,
#  'Guilherme Clezar': 106105,
#  'Evan King': 105960,
#  'Bradley Klahn': 105614,
#  'Mitchell Krueger': 106283,
#  'Roger Federer': 103819,
#  'Christopher Eubanks': 111153,
#  'Miomir Kecmanovic': 200175,
#  'Liam Broady': 106281,
#  'Mikael Ymer': 144707,
#  'Nicola Kuhn': 200095,
#  'Stefan Kozlov': 111578,
#  'Henri Laaksonen': 105967,
#  'Amine Ahouda': 144760,
#  'Pedro Martinez': 124079,
#  'Andrea Arnaboldi': 105063,
#  'Lamine Ouahab': 104467,
#  'Alexey Vatutin': 106072,
#  'Lucas Catarina': 200031,
#  'Tommy Robredo': 103990,
#  'Marcel Granollers': 104719,
#  'Hubert Hurkacz': 128034,
#  'Jurgen Zopp': 105132,
#  'Attila Balazs': 105226,
#  'Zsombor Piros': 200436,
#  'Frederico Ferreira Silva': 106393,
#  'Pedro Sousa': 105155,
#  'Simone Bolelli': 104620,
#  'Bernard Tomic': 106071,
#  'Cem Ilkel': 117356,
#  'Daniel Gimeno Traver': 104593,
#  'Marsel Ilhan': 104947,
#  'Marco Trungelliti': 105477,
#  'Daniel Masur': 109054,
#  'Filippo Baldi': 111795,
#  'Dominik Koepfer': 136440,
#  'Bernabe Zapata Miralles': 126523,
#  'Lukas Rosol': 104586,
#  'Jordi Samper Montana': 105515,
#  'Jose Hernandez': 105497,
#  'Gregoire Barrere': 106296,
#  'Filip Horansky': 106110,
#  'Federico Coria': 105948,
#  'Joris De Loore': 106167,
#  'Mohamed Safwat': 105633,
#  'Elliot Benchetrit': 200611,
#  'Maxime Janvier': 126125,
#  'Oscar Otte': 106214,
#  'James Duckworth': 105902,
#  'Santiago Giraldo': 105053,
#  'Guido Andreozzi': 105819,
#  'Adam Pavlasek': 106361,
#  'Max Purcell': 126845,
#  'Matteo Viola': 104970,
#  'Viktor Galovic': 105634,
#  'Rudolf Molleker': 200484,
#  'Prajnesh Gunneswaran': 105432,
#  'Jay Clarke': 126652,
#  'Andy Murray': 104918,
#  'Daniel Evans': 105554,
#  'Daniel Brands': 104978,
#  'Cristian Garin': 106426,
#  'Benjamin Bonzi': 126127,
#  'Christian Harrison': 106328,
#  'Jason Jung': 105359,
#  'Stephane Robert': 103565,
#  'Juan Ignacio Londero': 106228,
#  'Zdenek Kolar': 144645,
#  'Jc Aragone': 111574,
#  'Nino Serdarusic': 126120,
#  'Emil Reinberg': 202130,
#  'Nicolas Almagro': 104597,
#  'Oriol Roca Batalla': 106177,
#  'Marc Andrea Huesler': 144817,
#  'Jurij Rodionov': 200514,
#  'Takanyi Garanganga': 105626,
#  'Marcelo Arevalo': 105656,
#  'Daniel Elahi Galan': 123755,
#  'Marcos Giron': 106218,
#  'Egor Gerasimov': 106078,
#  'Thai Son Kwiatkowski': 111515,
#  'Yosuke Watanuki': 133297,
#  'Vincent Millot': 104672,
#  'Tommy Paul': 126205,
#  'Brayden Schnur': 111790,
#  'Borna Gojo': 127339,
#  'Lloyd Harris': 144750,
#  'Collin Altamirano': 123768,
#  'Jenson Brooksby': 202385,
#  'Ugo Humbert': 200005,
#  'Constant Lestienne': 106005,
#  'Lucas Miedler': 111192,
#  'Luca Vanni': 104563,
#  'Chun Hsin Tseng': 202358,
#  'Di Wu': 105842,
#  'Tatsuma Ito': 105147,
#  'Zhizhen Zhang': 111190,
#  'Zhe Li': 104810,
#  'Ze Zhang': 105585,
#  'Evgeny Karlovskiy': 106348,
#  'Jurgen Melzer': 103781,
#  'Yasutaka Uchiyama': 106034,
#  'Mubarak Shannan Zayid': 122570,
#  'Antoine Hoang': 126156,
#  'Steve Darcis': 104327,
#  'Jose Rubin Statham': 104907,
#  'Janko Tipsarevic': 104386,
#  'Marc Polmans': 117360,
#  'Kamil Majchrzak': 111794,
#  'Hugo Dellien': 106198,
#  'Alexandar Lazarov': 200247,
#  'Francisco Cerundolo': 202103,
#  'Jack Mingjie Lin': 200368,
#  'Gerardo Lopez Villasenor': 126204,
#  'Emilio Nava': 207182,
#  'Pedro Sakamoto': 106203,
#  'Pedja Krstin': 106353,
#  'Alejandro Davidovich Fokina': 200221,
#  'Mate Valkusz': 200218,
#  'Jannik Sinner': 206173,
#  'Andrea Basso': 109640,
#  'Steven Diez': 105731,
#  'Tristan Lamasine': 106137,
#  'Kimmer Coppejans': 106293,
#  'Alexandre Muller': 124186,
#  'Blaz Rola': 105641,
#  'Mats Moraing': 121531,
#  'James Ward': 104868,
#  'Ergi Kirkin': 144985,
#  'Altug Celikbilek': 123795,
#  'Kevin Krawietz': 105906,
#  'Paul Jubb': 206703,
#  'Facundo Arguello': 106032,
#  'Alastair Gray': 202400,
#  'Peter Torebko': 105091,
#  'Cole Gromley': 211415,
#  'Sandro Ehrat': 105757,
#  'Gian Marco Moroni': 126237,
#  'Daniel Altmaier': 127157,
#  'Julian Lenz': 109699,
#  'Mikael Torpegaard': 111453,
#  'Amir Weintraub': 104804,
#  'Raymond Sarmiento': 106031,
#  'Duck Hee Lee': 117353,
#  'Zachary Svajda': 208260,
#  'Tobias Kamke': 104735,
#  'Rayane Roumane': 144946,
#  'Yan Bai': 105339,
#  'Go Soeda': 104424,
#  'Artem Dubrivnyy': 144984,
#  'Alibek Kachmazov': 208230,
#  'Alen Avidzba': 200553,
#  'Nikola Milojevic': 110748,
#  'Gianluca Mager': 126149,
#  'Andrew Harris': 106302,
#  'Lorenzo Giustino': 105841,
#  'Mario Vilella Martinez': 106408,
#  'Christopher Oconnell': 106331,
#  'Yen Hsun Lu': 104229,
#  'Alejandro Tabilo': 126214,
#  'Juan Pablo Ficovich': 126663,
#  'Enzo Couacaud': 111505,
#  'Emil Ruusuvuori': 200325,
#  'Sasi Kumar Mukund': 124154,
#  'Roberto Marcora': 105406,
#  'Facundo Diaz Acosta': 207680,
#  'Danilo Petrovic': 105905,
#  'Brian Shi': 208108,
#  'Emilio Gomez': 105877,
#  'Brandon Nakashima': 206909,
#  'Harold Mayot': 208004,
#  'Felipe Meligeni Alves': 200335,
#  'Carlos Alcaraz': 207989,
#  'Lorenzo Musetti': 207518,
#  'Tomas Barrios Vera': 144642,
#  'Juan Pablo Varillas': 122669,
#  'J J Wolf': 200670,
#  'Ulises Blanch': 200265,
#  'Maxime Cressy': 202195,
#  'Andrey Kuznetsov': 105723,
#  'Tomas Machac': 207830,
#  'Arthur Rinderknech': 126239,
#  'Giulio Zeppieri': 206748,
#  'Andrea Pellegrino': 126504,
#  'Pavel Kotov': 200303,
#  'Roman Safiullin': 126128,
#  'Aslan Karatsev': 106234,
#  'Luca Nardi': 208134,
#  'Zizou Bergs': 200267,
#  'Dmitry Popko': 122078,
#  'Timofey Skatov': 207608,
#  'Vitaliy Sachko': 126964,
#  'Illya Marchenko': 105011,
#  'Jonas Forejtek': 207797,
#  'Kacper Zuk': 200390,
#  'Alex Molcan': 144684,
#  'Michael Vrbensky': 202398,
#  'Hugo Grenier': 126409,
#  'Ji Sung Nam': 106227,
#  'Tomas Martin Etcheverry': 144869,
#  'Botic Van De Zandschulp': 122298,
#  'Li Tu': 111454,
#  'Joao Menezes': 110778,
#  'Shintaro Mochizuki': 208278,
#  'Thiago Agustin Tirante': 202058,
#  'Holger Rune': 208029,
#  'Juan Manuel Cerundolo': 207678,
#  'Lukas Klein': 127760,
#  'Petros Tsitsipas': 202065,
#  'Sebastian Baez': 202104,
#  'Gonzalo Lama': 106174,
#  'Jack Draper': 207733,
#  'Nuno Borges': 132686,
#  'Arthur Cazaux': 209070,
#  'Dominic Stricker': 208502,
#  'Marko Topo': 209916,
#  'Hamad Medjedovic': 209098,
#  'Raul Brancaccio': 134840,
#  'Flavio Cobolli': 207925,
#  'Mathias Bourgue': 106288,
#  'Johan Nikles': 126627,
#  'Leandro Riedi': 209857,
#  'Vit Kopriva': 200240,
#  'Alexander Sarkissian': 105512,
#  'Nicolas Mejia': 200711,
#  'Andrea Collarini': 105911,
#  'Duje Ajdukovic': 207213,
#  'Trent Bryde': 200336,
#  'Lukas Neumayer': 209903,
#  'Alexander Erler': 126623,
#  'Tung Lin Wu': 126555,
#  'Eduardo Nava': 124013,
#  'Sam Riffice': 200589,
#  'August Holmgren': 200416,
#  'Evgenii Tiurnev': 126185,
#  'Yshai Oliel': 200075,
#  'Leo Borg': 209863,
#  'Viktor Durasovic': 126340,
#  'Andrea Vavassori': 131934,
#  'Jiri Lehecka': 208103,
#  'Caleb Chakravarthi': 207531,
#  'Juncheng Shang': 209992,
#  'Juan Alejandro Hernandez Serrano': 207834,
#  'Matheus Pucinelli De Almeida': 207799,
#  'Gijs Brouwer': 133835,
#  'Nicolas Alvarez Varona': 200374,
#  'Manuel Guinard': 131905,
#  'Max Hans Rehberg': 208819,
#  'Carlos Gimeno Valero': 202197,
#  'Francesco Passaro': 208859,
#  'Matteo Arnaldi': 208286,
#  'Santiago Fa Rodriguez Taverna': 144973,
#  'Franco Agamenone': 106162,
#  'Geoffrey Blancaneaux': 144972,
#  'Camilo Ugo Carabelli': 200116,
#  'Jesper De Jong': 207411,
#  'Henri Squire': 202260,
#  'Ryan Peniston': 126106,
#  'Antoine Bellier': 134472,
#  'Alexander Ritschard': 106310,
#  'Tim Van Rijthoven': 126646,
#  'William Blumberg': 144652,
#  'Andres Martin': 211346,
#  'Ben Shelton': 210097,
#  'Daniel Dutra Da Silva': 105180,
#  'Hernan Casanova': 106292,
#  'Alexander Shevchenko': 207686,
#  'Ivan Gakhov': 123809,
#  'Filip Misolic': 209209,
#  'Mili Poljicak': 209890,
#  'Dino Prizmic': 209976,
#  'Rodrigo Pacheco Mendez': 210202,
#  'Nick Chappell': 111436,
#  'Nicolas Barrientos': 104905,
#  'Gonzalo Villanueva': 106380,
#  'Kaichi Uchida': 111187,
#  'Rinky Hijikata': 208014,
#  'Alexis Galarneau': 200008,
#  'Michail Pervolarakis': 133018,
#  'Learner Tien': 210530,
#  'Brandon Holt': 200587,
#  'Evan Furness': 145001,
#  'Facundo Mena': 106057,
#  'Hiroki Moriya': 105655,
#  'Seong Chan Hong': 111805,
#  'Yunseong Chung': 126283,
#  'Aleksandar Kovacevic': 206499,
#  'Dragos Nicolae Madaras': 200096,
#  'Edan Leshem': 122548,
#  'Beibit Zhukayev': 202320,
#  'Sho Shimabukuro': 200647,
#  'Yuta Shimizu': 202122,
#  'Rio Noguchi': 200677,
#  'Francesco Maestrelli': 208353,
#  'Martin Landaluce': 211776,
#  'Luca Van Assche': 209414,
#  'Gilles Arnaud Bailly': 211451,
#  'Michael Geerts': 126107,
#  'Arthur Fils': 209950,
#  'Manas Dhamne': 211768,
#  'Kiranpal Pannu': 208485,
#  'Mattia Bellucci': 208233,
#  'Oleksii Krutykh': 208071,
#  'Yu Hsiou Hsu': 200318,
#  'Laurent Lokoli': 106362,
#  'Dalibor Svrcina': 207494,
#  'Luciano Darderi': 209260,
#  'Alex Rybakov': 126206,
#  'Liam Krall': 210740,
#  'Gabriel Diallo': 209113,
#  'Clement Chidekh': 206889,
#  'Matija Pecotic': 123896,
#  'Abedallah Shelbayh': 209406,
#  'Joao Fonseca': 211663,
#  'Mateus Alves': 127123,
#  'Jacopo Berrettini': 202235,
#  'Riccardo Bonadio': 109686,
#  'Henrique Rocha': 210012,
#  'Younes Lalami Laaroussi': 207794,
#  'Adam Moundir': 125842,
#  'Valentin Vacherot': 200473,
#  'Daniel Rincon': 209405,
#  'Stefano Napolitano': 109303,
#  'Fabian Marozsan': 206681,
#  'Alvaro Lopez San Martin': 126533,
#  'Pablo Llamas Ruiz': 208010,
#  'Patrick Kypson': 200516,
#  'Giovanni Mpetshi Perricard': 208659,
#  'Genaro Alberto Olivieri': 144821,
#  'Louis Wessels': 144923,
#  'Jan Choinski': 123828,
#  'George Loffhagen': 207785,
#  'Alex Michelsen': 210506,
#  'Arthur Fery': 209259,
#  'Otto Virtanen': 202261,
#  'Eliot Spizzirri': 208118,
#  'Ethan Quinn': 210319,
#  'Omni Kumar': 208300,
#  'Skander Mansouri': 109734,
#  'Strong Kirchheimer': 126177,
#  'Nicolas Moreno De Alboran': 134457,
#  'Titouan Droguet': 208169,
#  'Jakub Mensik': 210150,
#  'Tao Mu': 200307,
#  'Jie Cui': 200666,
#  'Benjamin Lock': 111761,
#  'Philip Sekulic': 210340,
#  'Terence Atmane': 209279,
#  'Dane Sweeny': 208013,
#  'Luke Saville': 106291,
#  'Yi Zhou': 212044,
#  'Ye Cong Mo': 202168,
#  'Rigele Te': 144751,
#  'Denis Yevseyev': 106187,
#  'Bu Yunchaokete': 207352,
#  'Alexander Blockx': 210696,
#  'Mark Lajal': 210136,
#  'Karl Friberg': 200418,
#  'Benjamin Hassan': 133975,
#  'Matteo Martineau': 200188,
#  'Billy Harris': 126129}

# %% [markdown]
# ### Zauważmy że jedynie Jo-Wilfried Tsonga ma myślnik w nazwie, a za to wiele zawodników w scraped_time_json ma myślinik, wykorzystamy to

# %%
for player in player_dict:
    if "-" in player:
        print(player)
# Out:
# Jo-Wilfried Tsonga

# %% [markdown]
# ### Często nazwy tych samych zawodników między dwoma zbiorami różnią się kolejnością członów lub duża/wielka litera, dlatego uwzględniamy to przy matchowaniu nazw

# %%
def normalize_string(s):
    return " ".join(sorted(s.lower().split()))

normalized_player_dict = {normalize_string(key): value for key, value in player_dict.items()}

def get_player_id(player_name):
    normalized_player_name = normalize_string(player_name)
    return normalized_player_dict.get(normalized_player_name)

# %% [markdown]
# ### Niektóre nazwy trzeba ręcznie poprawić aby się zgadzały

# %%
def fix_player_names_json(name: str):
    if name == "Ramos-Vinolas Albert":
        return "Ramos Albert"
    if name == "O'Connell Christopher":
        return "Oconnell Christopher"
    if name == "Barrios Vera Marcelo Tomas":
        return "Barrios Vera Tomas"
    if name == "Wolf Jeffrey John":
        return "J J Wolf"
    if name == "Meligeni Rodrigues Alves Felipe":
        return "Meligeni Alves Felipe"
    if name == "Rodriguez Taverna Santiago":
        return "Rodriguez Taverna Santiago Fa"
    if name == "Granollers-Pujol Marcel":
        return "Granollers Marcel"
    if name == "Statham Rubin":
        return "Statham Jose Rubin"
    if name == "Skugor Franco":
        return "Skugor Franko"
    if name == "Gromley Colton":
        return "Gromley Cole"
    if name == "Ali Mutawa Jabor Mohammed":
        return "Jabor Al Mutawa"
    if name == "Dolgopolov Aleksandr":
        return "Dolgopolov Alexandr"
    if name == "Hernandez-Fernandez Jose":
        return "Hernandez Jose"
    if name != "Tsonga Jo-Wilfried" and "-" in name:
        return name.replace("-", " ")
    return name

# %% [markdown]
# ### Sprawdzamy czy dla każdej nazwy zawodnika w scraped_time_json możemy wyciągnąć player_id z matches df

# %%
for year in scraped_time_json:
    for tournament in scraped_time_json[year]:
        for round in scraped_time_json[year][tournament]:
            for match in scraped_time_json[year][tournament][round]:
                match['Player1'] = fix_player_names_json(match['Player1'])
                match['Player2'] = fix_player_names_json(match['Player2'])
                if get_player_id(match['Player1']) is None:
                    print(match['Player1'])
                if get_player_id(match['Player2']) is None:
                    print(match['Player2'])

# %% [markdown]
# ### Dopisujemy zatem player_id

# %%
for year in scraped_time_json: 
    for tournament in scraped_time_json[year]:
        for round in scraped_time_json[year][tournament]:
            for match in scraped_time_json[year][tournament][round]:
                match['Player1Id'] = get_player_id(match['Player1'])
                match['Player2Id'] = get_player_id(match['Player2'])

# %% [markdown]
# ### Chcemy teraz osiągnąć taką samą lokacje turnieju w scraped_time_json co tourney_location w matches df

# %%
for year in scraped_time_json:
    matches_df = matches[matches['match_id'].str.split("_").str[1] == year]
    matches_df_locations = set(matches_df['tournament_location'].unique())
    json_locations = []
    for tournament in scraped_time_json[year]:
        json_locations.append(tournament)
        
    only_in_one_df = matches_df_locations ^ set(json_locations)
    if only_in_one_df:
        print(f"Locations only in one df: {only_in_one_df}")
    else:
        print("Both dfs  have the same tournament locations.")
# Out:
# Locations only in one df: {'Winston-Salem', 'London', 'Winston Salem', 'Queens Club', 'Paris 2', 'US Open', "'s-Hertogenbosch", 'Hertogenbosch', 'Tokyo', 'French Open', 'St. Petersburg', 'KitzbĂĽhel', "Queen's Club", 'Australian Open', 'Wimbledon', 'Saint Petersburg', 'Melbourne', 'Tokyo (Japan Open)', 'Kitzbuhel'}
# Locations only in one df: {'Winston-Salem', 'London', 'Winston Salem', 'Queens Club', 'Paris 2', 'US Open', "'s-Hertogenbosch", 'Hertogenbosch', 'Tokyo', 'French Open', 'St. Petersburg', 'KitzbĂĽhel', "Queen's Club", 'Australian Open', 'Wimbledon', 'Saint Petersburg', 'Melbourne', 'Tokyo (Japan Open)', 'Kitzbuhel'}
# Locations only in one df: {'St. Petersburg', 'KitzbĂĽhel', 'Australian Open', 'Nur-Sultan', 'Kitzbuhel', 'Astana', 'Cincinnati Masters (New York)', 'Saint Petersburg', 'Cincinnati', 'Melbourne', 'French Open', 'Paris 2', 'US Open'}
# Locations only in one df: {'Winston-Salem', 'Winston Salem', 'Astana', 'Queens Club', 'French Open', 'Paris 2', 'St. Petersburg', 'KitzbĂĽhel', "Queen's Club", 'Nur-Sultan', 'Saint Petersburg', 'Kitzbuhel'}
# Locations only in one df: {'Winston-Salem', 'Naples', 'London', 'Winston Salem', 'Astana', 'Queens Club', 'Paris 2', 'US Open', "'s-Hertogenbosch", 'Hertogenbosch', 'New York', 'Tokyo', 'Napoli', 'French Open', 'KitzbĂĽhel', "Queen's Club", 'Australian Open', 'Wimbledon', 'Nur-Sultan', 'Melbourne', 'Tokyo (Japan Open)', 'Kitzbuhel'}
# Locations only in one df: {'Winston-Salem', 'London', 'Winston Salem', 'Astana', 'Queens Club', 'Paris 2', 'US Open', "'s-Hertogenbosch", 'Hertogenbosch', 'New York', 'Tokyo', 'French Open', 'KitzbĂĽhel', "Queen's Club", 'Australian Open', 'Wimbledon', 'Nur-Sultan', 'Melbourne', 'Tokyo (Japan Open)', 'Kitzbuhel'}

# %% [markdown]
# ### Musimy ręczenie poprawić

# %%
def fix_tournament_name(name):
    if name == "Queen's Club":
        return "Queens Club"
    if name == "Kitzbühel":
        return "Kitzbuhel"
    if name == "KitzbĂĽhel": 
        return "Kitzbuhel"
    if name == "Winston Salem":
        return "Winston-Salem"
    if name == "Astana":
        return "Nur-Sultan"
    if name == "Saint Petersburg":
        return "St. Petersburg"
    if name == "US Open":
        return "New York"
    if name == "Australian Open":
        return "Melbourne"
    if name == "Wimbledon":
        return "London"
    if name == "French Open":
        return "Paris"
    if name == "Paris":
        return "Paris 2"
    if name == "Tokyo (Japan Open)":
        return "Tokyo"
    if name == "Napoli":
        return "Naples"
    if name == "Hertogenbosch":
        return "'s-Hertogenbosch"
    if name == "Cincinnati Masters (New York)":
        return "Cincinnati"
    
    return name

# %%
for year in scraped_time_json:
    matches_df = matches[matches['match_id'].str.split("_").str[1] == year]
    matches_df_locations = set(matches_df['tournament_location'].unique())
    json_locations = []
    for tournament in scraped_time_json[year]:
        tournament = fix_tournament_name(tournament)
        json_locations.append(tournament)
        
    only_in_one_df = matches_df_locations ^ set(json_locations)
    if only_in_one_df:
        print(f"Locations only in one df: {only_in_one_df}")
    else:
        print("Both dfs have the same tournament locations.")
# Out:
# Both dfs have the same tournament locations.
# Both dfs have the same tournament locations.
# Both dfs have the same tournament locations.
# Both dfs have the same tournament locations.
# Both dfs have the same tournament locations.
# Both dfs have the same tournament locations.

# %% [markdown]
# ### Teraz już jest ok, zatem możemy w scraped_time_json stworzyć match_id

# %%
for year in scraped_time_json:
    for tournament in scraped_time_json[year]:
        for round in scraped_time_json[year][tournament]:
            for match in scraped_time_json[year][tournament][round]:
                match['match_id'] = fix_tournament_name(tournament) + '_' + year + '_' + str(match['Player1Id']) + '_' + str(match['Player2Id'])

# %% [markdown]
# ### Sprawdźmy czy stworzone match_id jest unikatowe

# %%
match_ids = []
for year in scraped_time_json:
    for tournament in scraped_time_json[year]:
        for round in scraped_time_json[year][tournament]:
            for match in scraped_time_json[year][tournament][round]:
                match_ids.append(match["match_id"])
print(len(match_ids) == len(set(match_ids)))
# Out:
# True

# %% [markdown]
# ### Sprawdźmy teraz czy mamy 1 do 1 relacje między match_id z dwóch zbiorów

# %%
for match_id in match_ids:
    if match_id not in matches['match_id'].values:
        print(match_id)

# %%
for match_id in matches['match_id'].values:
    if match_id not in match_ids:
        print(match_id)

# %% [markdown]
# ## Super, możemy zatem mergeować

# %%
time_mapping = {
    match['match_id']: {'Time': match['Time']}
    for year in scraped_time_json.values()
    for tournament in year.values()
    for round_info in tournament.values()
    for match in round_info
}

matches['time'] = matches['match_id'].map(lambda match_id: time_mapping.get(match_id, {}).get('Time'))

matches
# Out:
#       tournament_location         tournament_name        Date  \
# 0                Brisbane  Brisbane International  2017-12-31
# 1                Brisbane  Brisbane International  2017-12-31
# 2                Brisbane  Brisbane International  2018-01-01
# 3                Brisbane  Brisbane International  2018-01-01
# 4                Brisbane  Brisbane International  2018-01-01
# ...                   ...                     ...         ...
# 14106               Sofia              Sofia Open  2023-11-09
# 14107               Sofia              Sofia Open  2023-11-09
# 14108               Sofia              Sofia Open  2023-11-10
# 14109               Sofia              Sofia Open  2023-11-10
# 14110               Sofia              Sofia Open  2023-11-11
#
#       tournament_level indoor_or_outdoor Surface          Round   W1   L1  \
# 0               ATP250           Outdoor    Hard      1st Round  6.0  4.0
# 1               ATP250           Outdoor    Hard      1st Round  7.0  6.0
# 2               ATP250           Outdoor    Hard      1st Round  6.0  4.0
# 3               ATP250           Outdoor    Hard      1st Round  6.0  3.0
# 4               ATP250           Outdoor    Hard      1st Round  6.0  4.0
# ...                ...               ...     ...            ...  ...  ...
# 14106           ATP250            Indoor    Hard  Quarterfinals  6.0  7.0
# 14107           ATP250            Indoor    Hard  Quarterfinals  6.0  3.0
# 14108           ATP250            Indoor    Hard     Semifinals  6.0  3.0
# 14109           ATP250            Indoor    Hard     Semifinals  6.0  2.0
# 14110           ATP250            Indoor    Hard      The Final  7.0  6.0
#
#         W2  ...  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  \
# 0      7.0  ...      22.0      20.0     11.0        1.0        3.0
# 1      6.0  ...      33.0      17.0     11.0        4.0        6.0
# 2      3.0  ...      33.0      19.0     14.0        1.0        4.0
# 3      6.0  ...      18.0       6.0      8.0        1.0        5.0
# 4      7.0  ...      27.0       8.0     11.0        1.0        6.0
# ...    ...  ...       ...       ...      ...        ...        ...
# 14106  6.0  ...      47.0      14.0     15.0       11.0       16.0
# 14107  7.0  ...      22.0      19.0     10.0        0.0        2.0
# 14108  6.0  ...      22.0      10.0      9.0        1.0        4.0
# 14109  7.0  ...      27.0       8.0     10.0        1.0        3.0
# 14110  2.0  ...      40.0      19.0     14.0        0.0        2.0
#
#        winner_rank  winner_rank_points  loser_rank  loser_rank_points   time
# 0             38.0              1231.0        26.0             1675.0  07:25
# 1            208.0               245.0        44.0             1055.0  09:20
# 2             47.0              1010.0        52.0              909.0  02:10
# 3             76.0               670.0        79.0              662.0  04:00
# 4             33.0              1302.0       218.0              235.0  07:10
# ...            ...                 ...         ...                ...    ...
# 14106         25.0              1525.0        44.0             1019.0  17:00
# 14107         80.0               721.0        47.0              957.0  20:05
# 14108         82.0               706.0        28.0             1442.0  15:10
# 14109         25.0              1525.0        80.0              721.0  17:00
# 14110         25.0              1525.0        82.0              706.0  14:00
#
# [14111 rows x 67 columns]

# %% [markdown]
# ### Sprawdźmy jeszcze czy nie ma braków wartości w nowej kolumnie

# %%
nan_count = matches['time'].isna().sum()

print(f"Number of NaN values in column 'time': {nan_count}")
# Out:
# Number of NaN values in column 'time': 0

# %%
matches.to_csv("../data/merged_matches_with_time.csv", index=False)
