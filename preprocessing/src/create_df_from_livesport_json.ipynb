# %%
import json
import pandas as pd

# %%
livesport = json.load(open('../data/raw_data/match_details_2024.json'))
matches = pd.read_csv("../data/Merged_year_data/matches.csv")
matches2023 = matches[matches["match_id"].str.split('_').str[1] == '2023']
bets2024 = pd.read_excel("../data/raw_data/2024.xlsx")

# %%
github_2023 = pd.read_csv("../data/Processed_data/github2023.csv")
github_2022 = pd.read_csv("../data/Processed_data/github2022.csv")
github_2021 = pd.read_csv("../data/Processed_data/github2021.csv")
github_2020 = pd.read_csv("../data/Processed_data/github2020.csv")
github_2019 = pd.read_csv("../data/Processed_data/github2019.csv")
github_2018 = pd.read_csv("../data/Processed_data/github2018.csv")
github_df = pd.concat([github_2023, github_2022, github_2021, github_2020, github_2019, github_2018], ignore_index=True)

# %%
manual_mapping = {
    'Varillas J. P.': 'Varillas J.P.',
    'Tseng C. H.': 'Tseng C.H.',
}
bets2024['Winner'] = bets2024['Winner'].replace(manual_mapping)
bets2024['Loser'] = bets2024['Loser'].replace(manual_mapping)

# %%
livesport
# Out:
# {'https://www.livesport.com/en/match/hrB0HLYB/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': 'FINAL'},
#    'time_and_date': {'date': '07.01.2024', 'time': '07:55'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Rune H.',
#     'rank': '13',
#     'is_winner': False,
#     'seed': '1'},
#    'player2': {'name': 'Dimitrov G.',
#     'rank': '10',
#     'is_winner': True,
#     'seed': '2'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '6\n5', 'Set 2': '4'},
#     'player2': {'Set 1': '7\n7', 'Set 2': '6'}},
#    'duration': '2:19'},
#   'match_statistics': {'Aces': ['9', '8'],
#    'Double Faults': ['3', '2'],
#    '1st Serve Percentage': ['61%', '70%'],
#    '1st Serve Points Won': ['76% (44/58)', '77% (40/52)'],
#    '2nd Serve Points Won': ['43% (16/37)', '59% (13/22)'],
#    'Break Points Saved': ['89% (8/9)', '100% (3/3)'],
#    '1st Return Points Won': ['23% (12/52)', '24% (14/58)'],
#    '2nd Return Points Won': ['41% (9/22)', '57% (21/37)'],
#    'Break Points Converted': ['0% (0/3)', '11% (1/9)'],
#    'Winners': ['35', '27'],
#    'Unforced Errors': ['15', '8'],
#    'Net Points Won': ['64% (18/28)', '64% (16/25)'],
#    'Service Points Won': ['63% (60/95)', '72% (53/74)'],
#    'Return Points Won': ['28% (21/74)', '37% (35/95)'],
#    'Total Points Won': ['48% (81/169)', '52% (88/169)'],
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['2', '0'],
#    'Service Games Won': ['91% (10/11)', '100% (11/11)'],
#    'Return Games Won': ['0% (0/11)', '9% (1/11)'],
#    'Total Games Won': ['45% (10/22)', '55% (12/22)']}},
#  'https://www.livesport.com/en/match/rulXp2l4/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': 'SEMI-FINALS'},
#    'time_and_date': {'date': '06.01.2024', 'time': '11:40'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Thompson J.',
#     'rank': '26',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Dimitrov G.',
#     'rank': '10',
#     'is_winner': True,
#     'seed': '2'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '5'},
#     'player2': {'Set 1': '6', 'Set 2': '7'}},
#    'duration': '1:47'},
#   'match_statistics': {'Aces': ['5', '10'],
#    'Double Faults': ['1', '3'],
#    '1st Serve Percentage': ['63%', '67%'],
#    '1st Serve Points Won': ['62% (24/39)', '87% (39/45)'],
#    '2nd Serve Points Won': ['61% (14/23)', '45% (10/22)'],
#    'Break Points Saved': ['71% (5/7)', '100% (6/6)'],
#    '1st Return Points Won': ['13% (6/45)', '38% (15/39)'],
#    '2nd Return Points Won': ['55% (12/22)', '39% (9/23)'],
#    'Break Points Converted': ['0% (0/6)', '29% (2/7)'],
#    'Winners': ['11', '31'],
#    'Unforced Errors': ['9', '7'],
#    'Net Points Won': ['57% (8/14)', '88% (15/17)'],
#    'Service Points Won': ['61% (38/62)', '73% (49/67)'],
#    'Return Points Won': ['27% (18/67)', '39% (24/62)'],
#    'Total Points Won': ['43% (56/129)', '57% (73/129)'],
#    'Last 10 Balls': ['2', '8'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['80% (8/10)', '100% (11/11)'],
#    'Return Games Won': ['0% (0/11)', '20% (2/10)'],
#    'Total Games Won': ['38% (8/21)', '62% (13/21)']}},
#  'https://www.livesport.com/en/match/nBebMPXT/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': 'SEMI-FINALS'},
#    'time_and_date': {'date': '06.01.2024', 'time': '06:05'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Rune H.',
#     'rank': '13',
#     'is_winner': True,
#     'seed': '1'},
#    'player2': {'name': 'Safiullin R.',
#     'rank': '60',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 0},
#    'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7\n7'},
#     'player2': {'Set 1': '4', 'Set 2': '6\n0'}},
#    'duration': '1:39'},
#   'match_statistics': {'Aces': ['7', '5'],
#    'Double Faults': ['4', '5'],
#    '1st Serve Percentage': ['67%', '53%'],
#    '1st Serve Points Won': ['81% (39/48)', '89% (31/35)'],
#    '2nd Serve Points Won': ['46% (11/24)', '32% (10/31)'],
#    'Break Points Saved': ['50% (1/2)', '71% (5/7)'],
#    '1st Return Points Won': ['11% (4/35)', '19% (9/48)'],
#    '2nd Return Points Won': ['68% (21/31)', '54% (13/24)'],
#    'Break Points Converted': ['29% (2/7)', '50% (1/2)'],
#    'Winners': ['14', '24'],
#    'Unforced Errors': ['12', '17'],
#    'Net Points Won': ['60% (3/5)', '83% (15/18)'],
#    'Service Points Won': ['69% (50/72)', '62% (41/66)'],
#    'Return Points Won': ['38% (25/66)', '31% (22/72)'],
#    'Total Points Won': ['54% (75/138)', '46% (63/138)'],
#    'Last 10 Balls': ['10', '0'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['91% (10/11)', '82% (9/11)'],
#    'Return Games Won': ['18% (2/11)', '9% (1/11)'],
#    'Total Games Won': ['55% (12/22)', '45% (10/22)']}},
#  'https://www.livesport.com/en/match/8tKKk33i/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': 'QUARTER-FINALS'},
#    'time_and_date': {'date': '05.01.2024', 'time': '11:35'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Nadal R.',
#     'rank': '155',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Thompson J.',
#     'rank': '26',
#     'is_winner': True,
#     'seed': ''},
#    'sets_score': {'Wsets': 1, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '6\n6', 'Set 3': '3'},
#     'player2': {'Set 1': '5', 'Set 2': '7\n8', 'Set 3': '6'}},
#    'duration': '3:24'},
#   'match_statistics': {'Aces': ['7', '8'],
#    'Double Faults': ['2', '3'],
#    '1st Serve Percentage': ['73%', '61%'],
#    '1st Serve Points Won': ['73% (58/79)', '76% (51/67)'],
#    '2nd Serve Points Won': ['45% (13/29)', '48% (20/42)'],
#    'Break Points Saved': ['33% (1/3)', '75% (6/8)'],
#    '1st Return Points Won': ['24% (16/67)', '27% (21/79)'],
#    '2nd Return Points Won': ['52% (22/42)', '55% (16/29)'],
#    'Break Points Converted': ['25% (2/8)', '67% (2/3)'],
#    'Winners': ['32', '44'],
#    'Unforced Errors': ['14', '14'],
#    'Net Points Won': ['75% (12/16)', '78% (35/45)'],
#    'Service Points Won': ['66% (71/108)', '65% (71/109)'],
#    'Return Points Won': ['35% (38/109)', '34% (37/108)'],
#    'Total Points Won': ['50% (109/217)', '50% (108/217)'],
#    'Last 10 Balls': ['6', '4'],
#    'Match Points Saved': ['0', '3'],
#    'Service Games Won': ['88% (14/16)', '88% (15/17)'],
#    'Return Games Won': ['12% (2/17)', '13% (2/16)'],
#    'Total Games Won': ['48% (16/33)', '52% (17/33)']}},
#  'https://www.livesport.com/en/match/vaNo5gB0/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': 'QUARTER-FINALS'},
#    'time_and_date': {'date': '05.01.2024', 'time': '08:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Hijikata R.',
#     'rank': '73',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Dimitrov G.',
#     'rank': '10',
#     'is_winner': True,
#     'seed': '2'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '1', 'Set 2': '4'},
#     'player2': {'Set 1': '6', 'Set 2': '6'}},
#    'duration': '1:19'},
#   'match_statistics': {'Aces': ['4', '12'],
#    'Double Faults': ['4', '2'],
#    '1st Serve Percentage': ['60%', '66%'],
#    '1st Serve Points Won': ['68% (23/34)', '79% (26/33)'],
#    '2nd Serve Points Won': ['35% (8/23)', '71% (12/17)'],
#    'Break Points Saved': ['57% (4/7)', '100% (2/2)'],
#    '1st Return Points Won': ['21% (7/33)', '32% (11/34)'],
#    '2nd Return Points Won': ['29% (5/17)', '65% (15/23)'],
#    'Break Points Converted': ['0% (0/2)', '43% (3/7)'],
#    'Winners': ['16', '18'],
#    'Unforced Errors': ['9', '4'],
#    'Net Points Won': ['54% (7/13)', '100% (4/4)'],
#    'Service Points Won': ['54% (31/57)', '76% (38/50)'],
#    'Return Points Won': ['24% (12/50)', '46% (26/57)'],
#    'Total Points Won': ['40% (43/107)', '60% (64/107)'],
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['63% (5/8)', '100% (9/9)'],
#    'Return Games Won': ['0% (0/9)', '38% (3/8)'],
#    'Total Games Won': ['29% (5/17)', '71% (12/17)']}},
#  'https://www.livesport.com/en/match/pxjuNJus/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': 'QUARTER-FINALS'},
#    'time_and_date': {'date': '05.01.2024', 'time': '06:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Rune H.',
#     'rank': '13',
#     'is_winner': True,
#     'seed': '1'},
#    'player2': {'name': 'Duckworth J.',
#     'rank': '82',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 0},
#    'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7\n8'},
#     'player2': {'Set 1': '2', 'Set 2': '6\n6'}},
#    'duration': '1:47'},
#   'match_statistics': {'Aces': ['13', '5'],
#    'Double Faults': ['0', '2'],
#    '1st Serve Percentage': ['55%', '66%'],
#    '1st Serve Points Won': ['86% (31/36)', '61% (31/51)'],
#    '2nd Serve Points Won': ['59% (17/29)', '62% (16/26)'],
#    'Break Points Saved': ['100% (1/1)', '60% (3/5)'],
#    '1st Return Points Won': ['39% (20/51)', '14% (5/36)'],
#    '2nd Return Points Won': ['38% (10/26)', '41% (12/29)'],
#    'Break Points Converted': ['40% (2/5)', '0% (0/1)'],
#    'Winners': ['33', '16'],
#    'Unforced Errors': ['11', '6'],
#    'Net Points Won': ['68% (13/19)', '67% (12/18)'],
#    'Service Points Won': ['74% (48/65)', '61% (47/77)'],
#    'Return Points Won': ['39% (30/77)', '26% (17/65)'],
#    'Total Points Won': ['55% (78/142)', '45% (64/142)'],
#    'Last 10 Balls': ['6', '4'],
#    'Match Points Saved': ['0', '2'],
#    'Service Games Won': ['100% (10/10)', '80% (8/10)'],
#    'Return Games Won': ['20% (2/10)', '0% (0/10)'],
#    'Total Games Won': ['60% (12/20)', '40% (8/20)']}},
#  'https://www.livesport.com/en/match/YLdIEpdL/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': 'QUARTER-FINALS'},
#    'time_and_date': {'date': '05.01.2024', 'time': '03:50'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Safiullin R.',
#     'rank': '60',
#     'is_winner': True,
#     'seed': ''},
#    'player2': {'name': 'Arnaldi M.',
#     'rank': '37',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 0},
#    'scores_by_set': {'player1': {'Set 1': '7\n7', 'Set 2': '6'},
#     'player2': {'Set 1': '6\n4', 'Set 2': '2'}},
#    'duration': '1:48'},
#   'match_statistics': {'Aces': ['9', '3'],
#    'Double Faults': ['3', '2'],
#    '1st Serve Percentage': ['59%', '54%'],
#    '1st Serve Points Won': ['84% (36/43)', '73% (27/37)'],
#    '2nd Serve Points Won': ['47% (14/30)', '50% (16/32)'],
#    'Break Points Saved': ['67% (2/3)', '63% (5/8)'],
#    '1st Return Points Won': ['27% (10/37)', '16% (7/43)'],
#    '2nd Return Points Won': ['50% (16/32)', '53% (16/30)'],
#    'Break Points Converted': ['38% (3/8)', '33% (1/3)'],
#    'Winners': ['20', '12'],
#    'Unforced Errors': ['9', '6'],
#    'Net Points Won': ['54% (7/13)', '80% (4/5)'],
#    'Service Points Won': ['68% (50/73)', '62% (43/69)'],
#    'Return Points Won': ['38% (26/69)', '32% (23/73)'],
#    'Total Points Won': ['54% (76/142)', '46% (66/142)'],
#    'Last 10 Balls': ['5', '5'],
#    'Match Points Saved': ['0', '1'],
#    'Service Games Won': ['90% (9/10)', '70% (7/10)'],
#    'Return Games Won': ['30% (3/10)', '10% (1/10)'],
#    'Total Games Won': ['60% (12/20)', '40% (8/20)']}},
#  'https://www.livesport.com/en/match/8U59MXRu/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '04.01.2024', 'time': '09:40'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Kubler J.',
#     'rank': '752',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Nadal R.',
#     'rank': '155',
#     'is_winner': True,
#     'seed': ''},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '1', 'Set 2': '2'},
#     'player2': {'Set 1': '6', 'Set 2': '6'}},
#    'duration': '1:21'},
#   'match_statistics': {'Aces': ['1', '4'],
#    'Double Faults': ['3', '3'],
#    '1st Serve Percentage': ['76%', '65%'],
#    '1st Serve Points Won': ['57% (20/35)', '80% (24/30)'],
#    '2nd Serve Points Won': ['18% (2/11)', '63% (10/16)'],
#    'Break Points Saved': ['33% (2/6)', '100% (4/4)'],
#    '1st Return Points Won': ['20% (6/30)', '43% (15/35)'],
#    '2nd Return Points Won': ['38% (6/16)', '82% (9/11)'],
#    'Break Points Converted': ['0% (0/4)', '67% (4/6)'],
#    'Winners': ['8', '20'],
#    'Unforced Errors': ['12', '8'],
#    'Net Points Won': ['67% (8/12)', '75% (9/12)'],
#    'Service Points Won': ['48% (22/46)', '74% (34/46)'],
#    'Return Points Won': ['26% (12/46)', '52% (24/46)'],
#    'Total Points Won': ['37% (34/92)', '63% (58/92)'],
#    'Last 10 Balls': ['2', '8'],
#    'Match Points Saved': ['1', '0'],
#    'Service Games Won': ['43% (3/7)', '100% (8/8)'],
#    'Return Games Won': ['0% (0/8)', '57% (4/7)'],
#    'Total Games Won': ['20% (3/15)', '80% (12/15)']}},
#  'https://www.livesport.com/en/match/hjZ9jNlr/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '04.01.2024', 'time': '06:40'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Altmaier D.',
#     'rank': '88',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Dimitrov G.',
#     'rank': '10',
#     'is_winner': True,
#     'seed': '2'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '1', 'Set 2': '2'},
#     'player2': {'Set 1': '6', 'Set 2': '6'}},
#    'duration': '1:08'},
#   'match_statistics': {'Aces': ['3', '6'],
#    'Double Faults': ['3', '1'],
#    '1st Serve Percentage': ['57%', '63%'],
#    '1st Serve Points Won': ['61% (17/28)', '92% (24/26)'],
#    '2nd Serve Points Won': ['29% (6/21)', '67% (10/15)'],
#    'Break Points Saved': ['33% (2/6)', '100% (3/3)'],
#    '1st Return Points Won': ['8% (2/26)', '39% (11/28)'],
#    '2nd Return Points Won': ['33% (5/15)', '71% (15/21)'],
#    'Break Points Converted': ['0% (0/3)', '67% (4/6)'],
#    'Winners': ['9', '20'],
#    'Unforced Errors': ['10', '5'],
#    'Net Points Won': ['50% (7/14)', '74% (14/19)'],
#    'Service Points Won': ['47% (23/49)', '83% (34/41)'],
#    'Return Points Won': ['17% (7/41)', '53% (26/49)'],
#    'Total Points Won': ['33% (30/90)', '67% (60/90)'],
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['43% (3/7)', '100% (8/8)'],
#    'Return Games Won': ['0% (0/8)', '57% (4/7)'],
#    'Total Games Won': ['20% (3/15)', '80% (12/15)']}},
#  'https://www.livesport.com/en/match/Ot0xQhr1/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '04.01.2024', 'time': '03:30'},
#    'comment': 'WALKOVER',
#    'player1': {'name': 'Thompson J.', 'rank': '26', 'is_winner': True},
#    'player2': {'name': 'Humbert U.', 'rank': '14', 'is_winner': False}},
#   'match_statistics': {}},
#  'https://www.livesport.com/en/match/nkOqsfp3/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '04.01.2024', 'time': '02:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Machac T.',
#     'rank': '25',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Hijikata R.',
#     'rank': '73',
#     'is_winner': True,
#     'seed': ''},
#    'sets_score': {'Wsets': 1, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '2', 'Set 3': '6\n4'},
#     'player2': {'Set 1': '5', 'Set 2': '6', 'Set 3': '7\n7'}},
#    'duration': '2:30'},
#   'match_statistics': {'Aces': ['6', '11'],
#    'Double Faults': ['2', '4'],
#    '1st Serve Percentage': ['69%', '62%'],
#    '1st Serve Points Won': ['74% (45/61)', '69% (44/64)'],
#    '2nd Serve Points Won': ['43% (12/28)', '58% (23/40)'],
#    'Break Points Saved': ['20% (1/5)', '77% (10/13)'],
#    '1st Return Points Won': ['31% (20/64)', '26% (16/61)'],
#    '2nd Return Points Won': ['43% (17/40)', '57% (16/28)'],
#    'Break Points Converted': ['23% (3/13)', '80% (4/5)'],
#    'Winners': ['31', '40'],
#    'Unforced Errors': ['13', '12'],
#    'Net Points Won': ['65% (11/17)', '50% (13/26)'],
#    'Service Points Won': ['64% (57/89)', '64% (67/104)'],
#    'Return Points Won': ['36% (37/104)', '36% (32/89)'],
#    'Total Points Won': ['49% (94/193)', '51% (99/193)'],
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['75% (12/16)', '81% (13/16)'],
#    'Return Games Won': ['19% (3/16)', '25% (4/16)'],
#    'Total Games Won': ['47% (15/32)', '53% (17/32)']}},
#  'https://www.livesport.com/en/match/Wz914Soq/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '03.01.2024', 'time': '11:20'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Rune H.',
#     'rank': '13',
#     'is_winner': True,
#     'seed': '1'},
#    'player2': {'name': 'Shevchenko A.',
#     'rank': '78',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 1},
#    'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '5', 'Set 3': '6'},
#     'player2': {'Set 1': '4', 'Set 2': '7', 'Set 3': '2'}},
#    'duration': '2:29'},
#   'match_statistics': {'Aces': ['12', '5'],
#    'Double Faults': ['2', '2'],
#    '1st Serve Percentage': ['63%', '57%'],
#    '1st Serve Points Won': ['75% (43/57)', '73% (45/62)'],
#    '2nd Serve Points Won': ['65% (22/34)', '50% (23/46)'],
#    'Break Points Saved': ['83% (5/6)', '70% (7/10)'],
#    '1st Return Points Won': ['27% (17/62)', '25% (14/57)'],
#    '2nd Return Points Won': ['50% (23/46)', '35% (12/34)'],
#    'Break Points Converted': ['30% (3/10)', '17% (1/6)'],
#    'Winners': ['39', '27'],
#    'Unforced Errors': ['11', '15'],
#    'Net Points Won': ['67% (20/30)', '59% (22/37)'],
#    'Service Points Won': ['71% (65/91)', '63% (68/108)'],
#    'Return Points Won': ['37% (40/108)', '29% (26/91)'],
#    'Total Points Won': ['53% (105/199)', '47% (94/199)'],
#    'Last 10 Balls': ['5', '5'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['93% (14/15)', '80% (12/15)'],
#    'Return Games Won': ['20% (3/15)', '7% (1/15)'],
#    'Total Games Won': ['57% (17/30)', '43% (13/30)']}},
#  'https://www.livesport.com/en/match/bixEqIzT/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '03.01.2024', 'time': '06:00'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Safiullin R.',
#     'rank': '60',
#     'is_winner': True,
#     'seed': ''},
#    'player2': {'name': 'Popyrin A.',
#     'rank': '24',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 1},
#    'scores_by_set': {'player1': {'Set 1': '6\n9',
#      'Set 2': '6',
#      'Set 3': '7\n7'},
#     'player2': {'Set 1': '7\n11', 'Set 2': '4', 'Set 3': '6\n3'}},
#    'duration': '2:56'},
#   'match_statistics': {'Aces': ['23', '13'],
#    'Double Faults': ['4', '6'],
#    '1st Serve Percentage': ['64%', '70%'],
#    '1st Serve Points Won': ['81% (62/77)', '81% (64/79)'],
#    '2nd Serve Points Won': ['59% (26/44)', '44% (15/34)'],
#    'Break Points Saved': ['93% (13/14)', '78% (7/9)'],
#    '1st Return Points Won': ['19% (15/79)', '19% (15/77)'],
#    '2nd Return Points Won': ['56% (19/34)', '41% (18/44)'],
#    'Break Points Converted': ['22% (2/9)', '7% (1/14)'],
#    'Winners': ['45', '29'],
#    'Unforced Errors': ['9', '17'],
#    'Net Points Won': ['71% (10/14)', '64% (14/22)'],
#    'Service Points Won': ['73% (88/121)', '70% (79/113)'],
#    'Return Points Won': ['30% (34/113)', '27% (33/121)'],
#    'Total Points Won': ['52% (122/234)', '48% (112/234)'],
#    'Last 10 Balls': ['7', '3'],
#    'Match Points Saved': ['5', '0'],
#    'Service Games Won': ['94% (16/17)', '88% (15/17)'],
#    'Return Games Won': ['12% (2/17)', '6% (1/17)'],
#    'Total Games Won': ['53% (18/34)', '47% (16/34)']}},
#  'https://www.livesport.com/en/match/69sUh27r/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '03.01.2024', 'time': '04:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Arnaldi M.',
#     'rank': '37',
#     'is_winner': True,
#     'seed': ''},
#    'player2': {'name': 'Klein L.',
#     'rank': '137',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 1},
#    'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '3', 'Set 3': '7'},
#     'player2': {'Set 1': '4', 'Set 2': '6', 'Set 3': '5'}},
#    'duration': '2:05'},
#   'match_statistics': {'Aces': ['9', '5'],
#    'Double Faults': ['3', '3'],
#    '1st Serve Percentage': ['55%', '57%'],
#    '1st Serve Points Won': ['84% (37/44)', '84% (42/50)'],
#    '2nd Serve Points Won': ['58% (21/36)', '46% (17/37)'],
#    'Break Points Saved': ['50% (2/4)', '40% (2/5)'],
#    '1st Return Points Won': ['16% (8/50)', '16% (7/44)'],
#    '2nd Return Points Won': ['54% (20/37)', '42% (15/36)'],
#    'Break Points Converted': ['60% (3/5)', '50% (2/4)'],
#    'Winners': ['24', '26'],
#    'Unforced Errors': ['16', '14'],
#    'Net Points Won': ['60% (9/15)', '83% (24/29)'],
#    'Service Points Won': ['73% (58/80)', '68% (59/87)'],
#    'Return Points Won': ['32% (28/87)', '28% (22/80)'],
#    'Total Points Won': ['51% (86/167)', '49% (81/167)'],
#    'Last 10 Balls': ['8', '2'],
#    'Match Points Saved': ['0', '2'],
#    'Service Games Won': ['87% (13/15)', '81% (13/16)'],
#    'Return Games Won': ['19% (3/16)', '13% (2/15)'],
#    'Total Games Won': ['52% (16/31)', '48% (15/31)']}},
#  'https://www.livesport.com/en/match/tOch0qmk/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '03.01.2024', 'time': '04:00'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Duckworth J.',
#     'rank': '82',
#     'is_winner': True,
#     'seed': ''},
#    'player2': {'name': 'Hanfmann Y.',
#     'rank': '96',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 1},
#    'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '6', 'Set 3': '7\n7'},
#     'player2': {'Set 1': '6', 'Set 2': '1', 'Set 3': '6\n2'}},
#    'duration': '2:27'},
#   'match_statistics': {'Aces': ['22', '15'],
#    'Double Faults': ['4', '4'],
#    '1st Serve Percentage': ['73%', '58%'],
#    '1st Serve Points Won': ['79% (52/66)', '77% (43/56)'],
#    '2nd Serve Points Won': ['52% (13/25)', '49% (20/41)'],
#    'Break Points Saved': ['67% (2/3)', '83% (10/12)'],
#    '1st Return Points Won': ['23% (13/56)', '21% (14/66)'],
#    '2nd Return Points Won': ['51% (21/41)', '48% (12/25)'],
#    'Break Points Converted': ['17% (2/12)', '33% (1/3)'],
#    'Winners': ['35', '31'],
#    'Unforced Errors': ['13', '18'],
#    'Net Points Won': ['63% (12/19)', '68% (19/28)'],
#    'Service Points Won': ['71% (65/91)', '65% (63/97)'],
#    'Return Points Won': ['35% (34/97)', '29% (26/91)'],
#    'Total Points Won': ['53% (99/188)', '47% (89/188)'],
#    'Last 10 Balls': ['8', '2'],
#    'Match Points Saved': ['2', '0'],
#    'Service Games Won': ['93% (14/15)', '86% (12/14)'],
#    'Return Games Won': ['14% (2/14)', '7% (1/15)'],
#    'Total Games Won': ['55% (16/29)', '45% (13/29)']}},
#  'https://www.livesport.com/en/match/vmFMfqMf/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '03.01.2024', 'time': '02:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Michelsen A.',
#     'rank': '42',
#     'is_winner': False,
#     'seed': 'Q/LL'},
#    'player2': {'name': 'Humbert U.',
#     'rank': '14',
#     'is_winner': True,
#     'seed': '4'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '4'},
#     'player2': {'Set 1': '6', 'Set 2': '6'}},
#    'duration': '1:37'},
#   'match_statistics': {'Aces': ['5', '4'],
#    'Double Faults': ['5', '1'],
#    '1st Serve Percentage': ['53%', '55%'],
#    '1st Serve Points Won': ['63% (24/38)', '83% (24/29)'],
#    '2nd Serve Points Won': ['53% (18/34)', '79% (19/24)'],
#    'Break Points Saved': ['80% (8/10)', '100% (2/2)'],
#    '1st Return Points Won': ['17% (5/29)', '37% (14/38)'],
#    '2nd Return Points Won': ['21% (5/24)', '47% (16/34)'],
#    'Break Points Converted': ['0% (0/2)', '20% (2/10)'],
#    'Winners': ['8', '21'],
#    'Unforced Errors': ['10', '8'],
#    'Net Points Won': ['50% (3/6)', '100% (3/3)'],
#    'Service Points Won': ['58% (42/72)', '81% (43/53)'],
#    'Return Points Won': ['19% (10/53)', '42% (30/72)'],
#    'Total Points Won': ['42% (52/125)', '58% (73/125)'],
#    'Last 10 Balls': ['5', '5'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['80% (8/10)', '100% (10/10)'],
#    'Return Games Won': ['0% (0/10)', '20% (2/10)'],
#    'Total Games Won': ['40% (8/20)', '60% (12/20)']}},
#  'https://www.livesport.com/en/match/UgH0Nrx1/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '11:55'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Kokkinakis T.',
#     'rank': '77',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Hijikata R.',
#     'rank': '73',
#     'is_winner': True,
#     'seed': 'WC'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '6\n8', 'Set 2': '2'},
#     'player2': {'Set 1': '7\n10', 'Set 2': '6'}},
#    'duration': '1:39'},
#   'match_statistics': {'Aces': ['16', '4'],
#    'Double Faults': ['1', '1'],
#    '1st Serve Percentage': ['76%', '58%'],
#    '1st Serve Points Won': ['77% (36/47)', '85% (33/39)'],
#    '2nd Serve Points Won': ['40% (6/15)', '57% (16/28)'],
#    'Break Points Saved': ['50% (2/4)', '100% (2/2)'],
#    '1st Return Points Won': ['15% (6/39)', '23% (11/47)'],
#    '2nd Return Points Won': ['43% (12/28)', '60% (9/15)'],
#    'Break Points Converted': ['0% (0/2)', '50% (2/4)'],
#    'Winners': ['23', '13'],
#    'Unforced Errors': ['13', '5'],
#    'Net Points Won': ['75% (3/4)', '86% (6/7)'],
#    'Service Points Won': ['68% (42/62)', '73% (49/67)'],
#    'Return Points Won': ['27% (18/67)', '32% (20/62)'],
#    'Total Points Won': ['47% (60/129)', '53% (69/129)'],
#    'Last 10 Balls': ['3', '7'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['80% (8/10)', '100% (10/10)'],
#    'Return Games Won': ['0% (0/10)', '20% (2/10)'],
#    'Total Games Won': ['40% (8/20)', '60% (12/20)']}},
#  'https://www.livesport.com/en/match/Q3HYis6D/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '10:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Thiem D.',
#     'rank': '519',
#     'is_winner': False,
#     'seed': 'Q/LL'},
#    'player2': {'name': 'Nadal R.',
#     'rank': '155',
#     'is_winner': True,
#     'seed': 'WC'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '5', 'Set 2': '1'},
#     'player2': {'Set 1': '7', 'Set 2': '6'}},
#    'duration': '1:30'},
#   'match_statistics': {'Aces': ['3', '3'],
#    'Double Faults': ['3', '1'],
#    '1st Serve Percentage': ['63%', '67%'],
#    '1st Serve Points Won': ['68% (23/34)', '90% (28/31)'],
#    '2nd Serve Points Won': ['50% (10/20)', '80% (12/15)'],
#    'Break Points Saved': ['50% (3/6)', '0% (0/0)'],
#    '1st Return Points Won': ['10% (3/31)', '32% (11/34)'],
#    '2nd Return Points Won': ['20% (3/15)', '50% (10/20)'],
#    'Break Points Converted': ['0% (0/0)', '50% (3/6)'],
#    'Service Points Won': ['61% (33/54)', '87% (40/46)'],
#    'Return Points Won': ['13% (6/46)', '39% (21/54)'],
#    'Total Points Won': ['39% (39/100)', '61% (61/100)'],
#    'Last 10 Balls': ['2', '8'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['67% (6/9)', '100% (10/10)'],
#    'Return Games Won': ['0% (0/10)', '33% (3/9)'],
#    'Total Games Won': ['32% (6/19)', '68% (13/19)']}},
#  'https://www.livesport.com/en/match/0vm0rpEQ/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '09:45'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Arnaldi M.',
#     'rank': '37',
#     'is_winner': True,
#     'seed': ''},
#    'player2': {'name': 'Fucsovics M.',
#     'rank': '103',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 1},
#    'scores_by_set': {'player1': {'Set 1': '6\n5',
#      'Set 2': '6',
#      'Set 3': '7\n9'},
#     'player2': {'Set 1': '7\n7', 'Set 2': '4', 'Set 3': '6\n7'}},
#    'duration': '3:09'},
#   'match_statistics': {'Aces': ['6', '11'],
#    'Double Faults': ['2', '1'],
#    '1st Serve Percentage': ['54%', '60%'],
#    '1st Serve Points Won': ['73% (48/66)', '77% (47/61)'],
#    '2nd Serve Points Won': ['70% (39/56)', '75% (30/40)'],
#    'Break Points Saved': ['100% (2/2)', '50% (1/2)'],
#    '1st Return Points Won': ['23% (14/61)', '27% (18/66)'],
#    '2nd Return Points Won': ['25% (10/40)', '30% (17/56)'],
#    'Break Points Converted': ['50% (1/2)', '0% (0/2)'],
#    'Winners': ['24', '24'],
#    'Unforced Errors': ['16', '13'],
#    'Net Points Won': ['77% (17/22)', '63% (12/19)'],
#    'Service Points Won': ['71% (87/122)', '76% (77/101)'],
#    'Return Points Won': ['24% (24/101)', '29% (35/122)'],
#    'Total Points Won': ['50% (111/223)', '50% (112/223)'],
#    'Last 10 Balls': ['5', '5'],
#    'Match Points Saved': ['1', '1'],
#    'Service Games Won': ['100% (17/17)', '94% (16/17)'],
#    'Return Games Won': ['6% (1/17)', '0% (0/17)'],
#    'Total Games Won': ['53% (18/34)', '47% (16/34)']}},
#  'https://www.livesport.com/en/match/MTDhP47l/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '09:35'},
#    'comment': 'FINISHED / RETIRED -\nKARATSEV A.',
#    'player1': {'name': 'Karatsev A.',
#     'rank': '291',
#     'is_winner': False,
#     'seed': '8'},
#    'player2': {'name': 'Kubler J.',
#     'rank': '752',
#     'is_winner': True,
#     'seed': 'WC'},
#    'sets_score': {'Wsets': 1, 'Lsets': 1},
#    'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '7\n7'},
#     'player2': {'Set 1': '6', 'Set 2': '6\n4'}},
#    'duration': '2:05'},
#   'match_statistics': {'Aces': ['2', '5'],
#    'Double Faults': ['6', '1'],
#    '1st Serve Percentage': ['56%', '64%'],
#    '1st Serve Points Won': ['74% (29/39)', '63% (31/49)'],
#    '2nd Serve Points Won': ['45% (14/31)', '48% (13/27)'],
#    'Break Points Saved': ['50% (4/8)', '67% (6/9)'],
#    '1st Return Points Won': ['35% (17/49)', '26% (10/39)'],
#    '2nd Return Points Won': ['52% (14/27)', '55% (17/31)'],
#    'Break Points Converted': ['33% (3/9)', '50% (4/8)'],
#    'Winners': ['15', '11'],
#    'Unforced Errors': ['15', '8'],
#    'Net Points Won': ['91% (10/11)', '40% (2/5)'],
#    'Service Points Won': ['61% (43/70)', '58% (44/76)'],
#    'Return Points Won': ['42% (32/76)', '39% (27/70)'],
#    'Total Points Won': ['51% (75/146)', '49% (71/146)'],
#    'Last 10 Balls': ['6', '4'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['64% (7/11)', '73% (8/11)'],
#    'Return Games Won': ['27% (3/11)', '36% (4/11)'],
#    'Total Games Won': ['45% (10/22)', '55% (12/22)']}},
#  'https://www.livesport.com/en/match/j959LM6D/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '08:55'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Thompson J.',
#     'rank': '26',
#     'is_winner': True,
#     'seed': ''},
#    'player2': {'name': 'Vukic A.',
#     'rank': '69',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 0},
#    'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'},
#     'player2': {'Set 1': '3', 'Set 2': '2'}},
#    'duration': '1:30'},
#   'match_statistics': {'Aces': ['7', '3'],
#    'Double Faults': ['1', '0'],
#    '1st Serve Percentage': ['61%', '59%'],
#    '1st Serve Points Won': ['82% (23/28)', '56% (18/32)'],
#    '2nd Serve Points Won': ['61% (11/18)', '45% (10/22)'],
#    'Break Points Saved': ['0% (0/1)', '50% (4/8)'],
#    '1st Return Points Won': ['44% (14/32)', '18% (5/28)'],
#    '2nd Return Points Won': ['55% (12/22)', '39% (7/18)'],
#    'Break Points Converted': ['50% (4/8)', '100% (1/1)'],
#    'Winners': ['15', '14'],
#    'Unforced Errors': ['5', '11'],
#    'Net Points Won': ['71% (5/7)', '50% (5/10)'],
#    'Service Points Won': ['74% (34/46)', '52% (28/54)'],
#    'Return Points Won': ['48% (26/54)', '26% (12/46)'],
#    'Total Points Won': ['60% (60/100)', '40% (40/100)'],
#    'Last 10 Balls': ['5', '5'],
#    'Match Points Saved': ['0', '1'],
#    'Service Games Won': ['89% (8/9)', '50% (4/8)'],
#    'Return Games Won': ['50% (4/8)', '11% (1/9)'],
#    'Total Games Won': ['71% (12/17)', '29% (5/17)']}},
#  'https://www.livesport.com/en/match/nDIUhNj7/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '08:35'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Etcheverry T. M.',
#     'rank': '39',
#     'is_winner': False,
#     'seed': '7'},
#    'player2': {'name': 'Machac T.',
#     'rank': '25',
#     'is_winner': True,
#     'seed': 'Q/LL'},
#    'sets_score': {'Wsets': 1, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '7\n7',
#      'Set 2': '5',
#      'Set 3': '6\n1'},
#     'player2': {'Set 1': '6\n5', 'Set 2': '7', 'Set 3': '7\n7'}},
#    'duration': '2:57'},
#   'match_statistics': {'Aces': ['6', '5'],
#    'Double Faults': ['2', '1'],
#    '1st Serve Percentage': ['71%', '63%'],
#    '1st Serve Points Won': ['72% (59/82)', '81% (57/70)'],
#    '2nd Serve Points Won': ['50% (17/34)', '51% (21/41)'],
#    'Break Points Saved': ['63% (5/8)', '67% (4/6)'],
#    '1st Return Points Won': ['19% (13/70)', '28% (23/82)'],
#    '2nd Return Points Won': ['49% (20/41)', '50% (17/34)'],
#    'Break Points Converted': ['33% (2/6)', '38% (3/8)'],
#    'Winners': ['15', '21'],
#    'Unforced Errors': ['23', '20'],
#    'Net Points Won': ['36% (4/11)', '77% (10/13)'],
#    'Service Points Won': ['66% (76/116)', '70% (78/111)'],
#    'Return Points Won': ['30% (33/111)', '34% (40/116)'],
#    'Total Points Won': ['48% (109/227)', '52% (118/227)'],
#    'Last 10 Balls': ['3', '7'],
#    'Match Points Saved': ['3', '0'],
#    'Service Games Won': ['83% (15/18)', '89% (16/18)'],
#    'Return Games Won': ['11% (2/18)', '17% (3/18)'],
#    'Total Games Won': ['47% (17/36)', '53% (19/36)']}},
#  'https://www.livesport.com/en/match/IwEQg3y1/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '07:15'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Tu L.',
#     'rank': '172',
#     'is_winner': False,
#     'seed': 'Q/LL'},
#    'player2': {'name': 'Altmaier D.',
#     'rank': '88',
#     'is_winner': True,
#     'seed': ''},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '6\n5', 'Set 2': '6\n4'},
#     'player2': {'Set 1': '7\n7', 'Set 2': '7\n7'}},
#    'duration': '2:03'},
#   'match_statistics': {'Aces': ['3', '7'],
#    'Double Faults': ['2', '1'],
#    '1st Serve Percentage': ['55%', '68%'],
#    '1st Serve Points Won': ['83% (38/46)', '76% (42/55)'],
#    '2nd Serve Points Won': ['59% (22/37)', '65% (17/26)'],
#    'Break Points Saved': ['100% (2/2)', '0% (0/0)'],
#    '1st Return Points Won': ['24% (13/55)', '17% (8/46)'],
#    '2nd Return Points Won': ['35% (9/26)', '41% (15/37)'],
#    'Break Points Converted': ['0% (0/0)', '0% (0/2)'],
#    'Winners': ['20', '19'],
#    'Unforced Errors': ['19', '20'],
#    'Net Points Won': ['69% (22/32)', '79% (19/24)'],
#    'Service Points Won': ['72% (60/83)', '73% (59/81)'],
#    'Return Points Won': ['27% (22/81)', '28% (23/83)'],
#    'Total Points Won': ['50% (82/164)', '50% (82/164)'],
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['1', '0'],
#    'Service Games Won': ['100% (12/12)', '100% (12/12)'],
#    'Return Games Won': ['0% (0/12)', '0% (0/12)'],
#    'Total Games Won': ['50% (12/24)', '50% (12/24)']}},
#  'https://www.livesport.com/en/match/plMDd5ir/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '07:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Wolf J.J.',
#     'rank': '262',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Duckworth J.',
#     'rank': '82',
#     'is_winner': True,
#     'seed': 'Q/LL'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '4'},
#     'player2': {'Set 1': '6', 'Set 2': '6'}},
#    'duration': '1:05'},
#   'match_statistics': {'Aces': ['7', '7'],
#    'Double Faults': ['1', '0'],
#    '1st Serve Percentage': ['73%', '69%'],
#    '1st Serve Points Won': ['84% (27/32)', '86% (31/36)'],
#    '2nd Serve Points Won': ['33% (4/12)', '69% (11/16)'],
#    'Break Points Saved': ['50% (2/4)', '100% (1/1)'],
#    '1st Return Points Won': ['14% (5/36)', '16% (5/32)'],
#    '2nd Return Points Won': ['31% (5/16)', '67% (8/12)'],
#    'Break Points Converted': ['0% (0/1)', '50% (2/4)'],
#    'Winners': ['12', '20'],
#    'Unforced Errors': ['10', '7'],
#    'Net Points Won': ['77% (10/13)', '100% (8/8)'],
#    'Service Points Won': ['70% (31/44)', '81% (42/52)'],
#    'Return Points Won': ['19% (10/52)', '30% (13/44)'],
#    'Total Points Won': ['43% (41/96)', '57% (55/96)'],
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['78% (7/9)', '100% (10/10)'],
#    'Return Games Won': ['0% (0/10)', '22% (2/9)'],
#    'Total Games Won': ['37% (7/19)', '63% (12/19)']}},
#  'https://www.livesport.com/en/match/dOPHeP6l/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '06:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Klein L.',
#     'rank': '137',
#     'is_winner': True,
#     'seed': 'Q/LL'},
#    'player2': {'name': 'Baez S.',
#     'rank': '27',
#     'is_winner': False,
#     'seed': '6'},
#    'sets_score': {'Wsets': 2, 'Lsets': 1},
#    'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '6', 'Set 3': '6'},
#     'player2': {'Set 1': '6', 'Set 2': '3', 'Set 3': '4'}},
#    'duration': '2:16'},
#   'match_statistics': {'Aces': ['9', '3'],
#    'Double Faults': ['2', '2'],
#    '1st Serve Percentage': ['61%', '80%'],
#    '1st Serve Points Won': ['75% (38/51)', '58% (53/92)'],
#    '2nd Serve Points Won': ['56% (18/32)', '61% (14/23)'],
#    'Break Points Saved': ['60% (3/5)', '79% (11/14)'],
#    '1st Return Points Won': ['42% (39/92)', '25% (13/51)'],
#    '2nd Return Points Won': ['39% (9/23)', '44% (14/32)'],
#    'Break Points Converted': ['21% (3/14)', '40% (2/5)'],
#    'Winners': ['21', '10'],
#    'Unforced Errors': ['22', '17'],
#    'Net Points Won': ['71% (17/24)', '38% (5/13)'],
#    'Service Points Won': ['67% (56/83)', '58% (67/115)'],
#    'Return Points Won': ['42% (48/115)', '33% (27/83)'],
#    'Total Points Won': ['53% (104/198)', '47% (94/198)'],
#    'Last 10 Balls': ['6', '4'],
#    'Match Points Saved': ['0', '1'],
#    'Service Games Won': ['87% (13/15)', '79% (11/14)'],
#    'Return Games Won': ['21% (3/14)', '13% (2/15)'],
#    'Total Games Won': ['55% (16/29)', '45% (13/29)']}},
#  'https://www.livesport.com/en/match/zXwSw4Ms/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '02.01.2024', 'time': '02:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Hanfmann Y.',
#     'rank': '96',
#     'is_winner': True,
#     'seed': ''},
#    'player2': {'name': 'Korda S.',
#     'rank': '22',
#     'is_winner': False,
#     'seed': '5'},
#    'sets_score': {'Wsets': 2, 'Lsets': 0},
#    'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '6'},
#     'player2': {'Set 1': '5', 'Set 2': '4'}},
#    'duration': '1:38'},
#   'match_statistics': {'Aces': ['4', '12'],
#    'Double Faults': ['0', '3'],
#    '1st Serve Percentage': ['77%', '56%'],
#    '1st Serve Points Won': ['70% (35/50)', '73% (29/40)'],
#    '2nd Serve Points Won': ['60% (9/15)', '44% (14/32)'],
#    'Break Points Saved': ['75% (3/4)', '50% (3/6)'],
#    '1st Return Points Won': ['28% (11/40)', '30% (15/50)'],
#    '2nd Return Points Won': ['56% (18/32)', '40% (6/15)'],
#    'Break Points Converted': ['50% (3/6)', '25% (1/4)'],
#    'Winners': ['19', '24'],
#    'Unforced Errors': ['8', '15'],
#    'Net Points Won': ['94% (15/16)', '33% (5/15)'],
#    'Service Points Won': ['68% (44/65)', '60% (43/72)'],
#    'Return Points Won': ['40% (29/72)', '32% (21/65)'],
#    'Total Points Won': ['53% (73/137)', '47% (64/137)'],
#    'Last 10 Balls': ['6', '4'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['91% (10/11)', '73% (8/11)'],
#    'Return Games Won': ['27% (3/11)', '9% (1/11)'],
#    'Total Games Won': ['59% (13/22)', '41% (9/22)']}},
#  'https://www.livesport.com/en/match/vPbip6qE/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '01.01.2024', 'time': '09:50'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Murray A.',
#     'rank': '',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Dimitrov G.',
#     'rank': '10',
#     'is_winner': True,
#     'seed': '2'},
#    'sets_score': {'Wsets': 1, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '5', 'Set 3': '2'},
#     'player2': {'Set 1': '4', 'Set 2': '7', 'Set 3': '6'}},
#    'duration': '2:27'},
#   'match_statistics': {'Aces': ['4', '13'],
#    'Double Faults': ['0', '2'],
#    '1st Serve Percentage': ['59%', '62%'],
#    '1st Serve Points Won': ['63% (32/51)', '82% (42/51)'],
#    '2nd Serve Points Won': ['60% (21/35)', '52% (16/31)'],
#    'Break Points Saved': ['50% (4/8)', '60% (3/5)'],
#    '1st Return Points Won': ['18% (9/51)', '37% (19/51)'],
#    '2nd Return Points Won': ['48% (15/31)', '40% (14/35)'],
#    'Break Points Converted': ['40% (2/5)', '50% (4/8)'],
#    'Winners': ['17', '36'],
#    'Unforced Errors': ['19', '13'],
#    'Net Points Won': ['53% (8/15)', '89% (16/18)'],
#    'Service Points Won': ['62% (53/86)', '71% (58/82)'],
#    'Return Points Won': ['29% (24/82)', '38% (33/86)'],
#    'Total Points Won': ['46% (77/168)', '54% (91/168)'],
#    'Last 10 Balls': ['5', '5'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['73% (11/15)', '87% (13/15)'],
#    'Return Games Won': ['13% (2/15)', '27% (4/15)'],
#    'Total Games Won': ['43% (13/30)', '57% (17/30)']}},
#  'https://www.livesport.com/en/match/CI65M2i7/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '01.01.2024', 'time': '07:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Rune H.',
#     'rank': '13',
#     'is_winner': True,
#     'seed': '1'},
#    'player2': {'name': 'Purcell M.',
#     'rank': '104',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 1},
#    'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '6', 'Set 3': '6'},
#     'player2': {'Set 1': '6', 'Set 2': '4', 'Set 3': '2'}},
#    'duration': '1:42'},
#   'match_statistics': {'Aces': ['12', '6'],
#    'Double Faults': ['0', '3'],
#    '1st Serve Percentage': ['81%', '65%'],
#    '1st Serve Points Won': ['74% (43/58)', '73% (35/48)'],
#    '2nd Serve Points Won': ['57% (8/14)', '50% (13/26)'],
#    'Break Points Saved': ['60% (3/5)', '33% (2/6)'],
#    '1st Return Points Won': ['27% (13/48)', '26% (15/58)'],
#    '2nd Return Points Won': ['50% (13/26)', '43% (6/14)'],
#    'Break Points Converted': ['67% (4/6)', '40% (2/5)'],
#    'Winners': ['31', '27'],
#    'Unforced Errors': ['15', '13'],
#    'Net Points Won': ['42% (8/19)', '63% (29/46)'],
#    'Service Points Won': ['71% (51/72)', '65% (48/74)'],
#    'Return Points Won': ['35% (26/74)', '29% (21/72)'],
#    'Total Points Won': ['53% (77/146)', '47% (69/146)'],
#    'Last 10 Balls': ['6', '4'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['86% (12/14)', '71% (10/14)'],
#    'Return Games Won': ['29% (4/14)', '14% (2/14)'],
#    'Total Games Won': ['57% (16/28)', '43% (12/28)']}},
#  'https://www.livesport.com/en/match/IFceqQbK/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BRISBANE',
#     'location': 'AUSTRALIA',
#     'surface': 'HARD',
#     'court': 'outdoor',
#     'round_name': '1/16-FINALS'},
#    'time_and_date': {'date': '01.01.2024', 'time': '04:20'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Shelton B.',
#     'rank': '21',
#     'is_winner': False,
#     'seed': '3'},
#    'player2': {'name': 'Safiullin R.',
#     'rank': '60',
#     'is_winner': True,
#     'seed': ''},
#    'sets_score': {'Wsets': 1, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '7\n7', 'Set 3': '3'},
#     'player2': {'Set 1': '6', 'Set 2': '6\n5', 'Set 3': '6'}},
#    'duration': '2:39'},
#   'match_statistics': {'Aces': ['12', '8'],
#    'Double Faults': ['6', '6'],
#    '1st Serve Percentage': ['67%', '53%'],
#    '1st Serve Points Won': ['77% (53/69)', '88% (44/50)'],
#    '2nd Serve Points Won': ['47% (16/34)', '62% (28/45)'],
#    'Break Points Saved': ['82% (9/11)', '100% (5/5)'],
#    '1st Return Points Won': ['12% (6/50)', '23% (16/69)'],
#    '2nd Return Points Won': ['38% (17/45)', '53% (18/34)'],
#    'Break Points Converted': ['0% (0/5)', '18% (2/11)'],
#    'Winners': ['31', '34'],
#    'Unforced Errors': ['22', '18'],
#    'Net Points Won': ['54% (15/28)', '81% (25/31)'],
#    'Service Points Won': ['67% (69/103)', '76% (72/95)'],
#    'Return Points Won': ['24% (23/95)', '33% (34/103)'],
#    'Total Points Won': ['46% (92/198)', '54% (106/198)'],
#    'Last 10 Balls': ['3', '7'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['86% (12/14)', '100% (16/16)'],
#    'Return Games Won': ['0% (0/16)', '14% (2/14)'],
#    'Total Games Won': ['40% (12/30)', '60% (18/30)']}},
# ...
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['2', '0'],
#    'Service Games Won': ['64% (9/14)', '77% (10/13)'],
#    'Return Games Won': ['23% (3/13)', '36% (5/14)'],
#    'Total Games Won': ['44% (12/27)', '56% (15/27)']}},
#  'https://www.livesport.com/en/match/nLYhH7j4/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': 'QUARTER-FINALS'},
#    'time_and_date': {'date': '19.04.2024', 'time': '17:25'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Diaz Acosta F.',
#     'rank': '79',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Tsitsipas S.',
#     'rank': '11',
#     'is_winner': True,
#     'seed': '5'},
#    'sets_score': {'Wsets': 1, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '3', 'Set 3': '6\n8'},
#     'player2': {'Set 1': '4', 'Set 2': '6', 'Set 3': '7\n10'}},
#    'duration': '2:35'},
#   'match_statistics': {'Aces': ['1', '3'],
#    'Double Faults': ['3', '7'],
#    '1st Serve Percentage': ['61%', '64%'],
#    '1st Serve Points Won': ['79% (41/52)', '73% (49/67)'],
#    '2nd Serve Points Won': ['52% (17/33)', '46% (17/37)'],
#    'Break Points Saved': ['43% (3/7)', '50% (4/8)'],
#    '1st Return Points Won': ['27% (18/67)', '21% (11/52)'],
#    '2nd Return Points Won': ['54% (20/37)', '48% (16/33)'],
#    'Break Points Converted': ['50% (4/8)', '57% (4/7)'],
#    'Service Points Won': ['68% (58/85)', '63% (66/104)'],
#    'Return Points Won': ['37% (38/104)', '32% (27/85)'],
#    'Total Points Won': ['51% (96/189)', '49% (93/189)'],
#    'Last 10 Balls': ['3', '7'],
#    'Match Points Saved': ['2', '2'],
#    'Service Games Won': ['73% (11/15)', '75% (12/16)'],
#    'Return Games Won': ['25% (4/16)', '27% (4/15)'],
#    'Total Games Won': ['48% (15/31)', '52% (16/31)']}},
#  'https://www.livesport.com/en/match/d43Kxor1/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': 'QUARTER-FINALS'},
#    'time_and_date': {'date': '19.04.2024', 'time': '15:35'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Arnaldi M.',
#     'rank': '37',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Ruud C.', 'rank': '6', 'is_winner': True, 'seed': '3'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '3'},
#     'player2': {'Set 1': '6', 'Set 2': '6'}},
#    'duration': '1:34'},
#   'match_statistics': {'Aces': ['1', '2'],
#    'Double Faults': ['1', '0'],
#    '1st Serve Percentage': ['53%', '75%'],
#    '1st Serve Points Won': ['56% (15/27)', '60% (30/50)'],
#    '2nd Serve Points Won': ['46% (11/24)', '71% (12/17)'],
#    'Break Points Saved': ['33% (2/6)', '75% (6/8)'],
#    '1st Return Points Won': ['40% (20/50)', '44% (12/27)'],
#    '2nd Return Points Won': ['29% (5/17)', '54% (13/24)'],
#    'Break Points Converted': ['25% (2/8)', '67% (4/6)'],
#    'Service Points Won': ['51% (26/51)', '63% (42/67)'],
#    'Return Points Won': ['37% (25/67)', '49% (25/51)'],
#    'Total Points Won': ['43% (51/118)', '57% (67/118)'],
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['56% (5/9)', '80% (8/10)'],
#    'Return Games Won': ['20% (2/10)', '44% (4/9)'],
#    'Total Games Won': ['37% (7/19)', '63% (12/19)']}},
#  'https://www.livesport.com/en/match/lzIAMUct/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': 'QUARTER-FINALS'},
#    'time_and_date': {'date': '19.04.2024', 'time': '12:40'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Norrie C.',
#     'rank': '49',
#     'is_winner': False,
#     'seed': '12'},
#    'player2': {'name': 'Etcheverry T. M.',
#     'rank': '39',
#     'is_winner': True,
#     'seed': '13'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '6\n4', 'Set 2': '6\n1'},
#     'player2': {'Set 1': '7\n7', 'Set 2': '7\n7'}},
#    'duration': '2:32'},
#   'match_statistics': {'Aces': ['3', '7'],
#    'Double Faults': ['2', '2'],
#    '1st Serve Percentage': ['67%', '62%'],
#    '1st Serve Points Won': ['73% (43/59)', '77% (44/57)'],
#    '2nd Serve Points Won': ['45% (13/29)', '49% (17/35)'],
#    'Break Points Saved': ['75% (3/4)', '80% (4/5)'],
#    '1st Return Points Won': ['23% (13/57)', '27% (16/59)'],
#    '2nd Return Points Won': ['51% (18/35)', '55% (16/29)'],
#    'Break Points Converted': ['20% (1/5)', '25% (1/4)'],
#    'Service Points Won': ['64% (56/88)', '66% (61/92)'],
#    'Return Points Won': ['34% (31/92)', '36% (32/88)'],
#    'Total Points Won': ['48% (87/180)', '52% (93/180)'],
#    'Last 10 Balls': ['2', '8'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['92% (11/12)', '92% (11/12)'],
#    'Return Games Won': ['8% (1/12)', '8% (1/12)'],
#    'Total Games Won': ['50% (12/24)', '50% (12/24)']}},
#  'https://www.livesport.com/en/match/Ak0HC9tg/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '18.04.2024', 'time': '18:20'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'De Minaur A.',
#     'rank': '9',
#     'is_winner': False,
#     'seed': '4'},
#    'player2': {'name': 'Fils A.',
#     'rank': '20',
#     'is_winner': True,
#     'seed': '16'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '5', 'Set 2': '2'},
#     'player2': {'Set 1': '7', 'Set 2': '6'}},
#    'duration': '1:36'},
#   'match_statistics': {'Aces': ['2', '4'],
#    'Double Faults': ['4', '1'],
#    '1st Serve Percentage': ['59%', '61%'],
#    '1st Serve Points Won': ['61% (25/41)', '71% (24/34)'],
#    '2nd Serve Points Won': ['39% (11/28)', '55% (12/22)'],
#    'Break Points Saved': ['50% (5/10)', '33% (1/3)'],
#    '1st Return Points Won': ['29% (10/34)', '39% (16/41)'],
#    '2nd Return Points Won': ['45% (10/22)', '61% (17/28)'],
#    'Break Points Converted': ['67% (2/3)', '50% (5/10)'],
#    'Service Points Won': ['52% (36/69)', '64% (36/56)'],
#    'Return Points Won': ['36% (20/56)', '48% (33/69)'],
#    'Total Points Won': ['45% (56/125)', '55% (69/125)'],
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['1', '0'],
#    'Service Games Won': ['50% (5/10)', '80% (8/10)'],
#    'Return Games Won': ['20% (2/10)', '50% (5/10)'],
#    'Total Games Won': ['35% (7/20)', '65% (13/20)']}},
#  'https://www.livesport.com/en/match/OI1FQipo/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '18.04.2024', 'time': '17:45'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Carballes Baena R.',
#     'rank': '57',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Tsitsipas S.',
#     'rank': '11',
#     'is_winner': True,
#     'seed': '5'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '5', 'Set 2': '3'},
#     'player2': {'Set 1': '7', 'Set 2': '6'}},
#    'duration': '1:46'},
#   'match_statistics': {'Aces': ['1', '7'],
#    'Double Faults': ['2', '2'],
#    '1st Serve Percentage': ['73%', '60%'],
#    '1st Serve Points Won': ['61% (30/49)', '71% (34/48)'],
#    '2nd Serve Points Won': ['61% (11/18)', '56% (18/32)'],
#    'Break Points Saved': ['73% (8/11)', '83% (5/6)'],
#    '1st Return Points Won': ['29% (14/48)', '39% (19/49)'],
#    '2nd Return Points Won': ['44% (14/32)', '39% (7/18)'],
#    'Break Points Converted': ['17% (1/6)', '27% (3/11)'],
#    'Service Points Won': ['61% (41/67)', '65% (52/80)'],
#    'Return Points Won': ['35% (28/80)', '39% (26/67)'],
#    'Total Points Won': ['47% (69/147)', '53% (78/147)'],
#    'Last 10 Balls': ['5', '5'],
#    'Match Points Saved': ['1', '0'],
#    'Service Games Won': ['70% (7/10)', '91% (10/11)'],
#    'Return Games Won': ['9% (1/11)', '30% (3/10)'],
#    'Total Games Won': ['38% (8/21)', '62% (13/21)']}},
#  'https://www.livesport.com/en/match/GllmMJtn/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '18.04.2024', 'time': '16:15'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Marozsan F.',
#     'rank': '58',
#     'is_winner': False,
#     'seed': '17'},
#    'player2': {'name': 'Diaz Acosta F.',
#     'rank': '79',
#     'is_winner': True,
#     'seed': ''},
#    'sets_score': {'Wsets': 1, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '3', 'Set 3': '1'},
#     'player2': {'Set 1': '3', 'Set 2': '6', 'Set 3': '6'}},
#    'duration': '1:47'},
#   'match_statistics': {'Aces': ['0', '3'],
#    'Double Faults': ['0', '2'],
#    '1st Serve Percentage': ['70%', '70%'],
#    '1st Serve Points Won': ['58% (33/57)', '72% (34/47)'],
#    '2nd Serve Points Won': ['52% (13/25)', '50% (10/20)'],
#    'Break Points Saved': ['50% (4/8)', '0% (0/2)'],
#    '1st Return Points Won': ['28% (13/47)', '42% (24/57)'],
#    '2nd Return Points Won': ['50% (10/20)', '48% (12/25)'],
#    'Break Points Converted': ['100% (2/2)', '50% (4/8)'],
#    'Service Points Won': ['56% (46/82)', '66% (44/67)'],
#    'Return Points Won': ['34% (23/67)', '44% (36/82)'],
#    'Total Points Won': ['46% (69/149)', '54% (80/149)'],
#    'Last 10 Balls': ['3', '7'],
#    'Match Points Saved': ['1', '0'],
#    'Service Games Won': ['67% (8/12)', '85% (11/13)'],
#    'Return Games Won': ['15% (2/13)', '33% (4/12)'],
#    'Total Games Won': ['40% (10/25)', '60% (15/25)']}},
#  'https://www.livesport.com/en/match/27Ph24YF/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '18.04.2024', 'time': '16:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Thompson J.',
#     'rank': '26',
#     'is_winner': False,
#     'seed': '14'},
#    'player2': {'name': 'Ruud C.', 'rank': '6', 'is_winner': True, 'seed': '3'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '1', 'Set 2': '4'},
#     'player2': {'Set 1': '6', 'Set 2': '6'}},
#    'duration': '1:14'},
#   'match_statistics': {'Aces': ['4', '1'],
#    'Double Faults': ['1', '0'],
#    '1st Serve Percentage': ['54%', '71%'],
#    '1st Serve Points Won': ['67% (18/27)', '81% (26/32)'],
#    '2nd Serve Points Won': ['43% (10/23)', '85% (11/13)'],
#    'Break Points Saved': ['50% (3/6)', '100% (2/2)'],
#    '1st Return Points Won': ['19% (6/32)', '33% (9/27)'],
#    '2nd Return Points Won': ['15% (2/13)', '57% (13/23)'],
#    'Break Points Converted': ['0% (0/2)', '50% (3/6)'],
#    'Service Points Won': ['56% (28/50)', '82% (37/45)'],
#    'Return Points Won': ['18% (8/45)', '44% (22/50)'],
#    'Total Points Won': ['38% (36/95)', '62% (59/95)'],
#    'Last 10 Balls': ['4', '6'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['63% (5/8)', '100% (9/9)'],
#    'Return Games Won': ['0% (0/9)', '38% (3/8)'],
#    'Total Games Won': ['29% (5/17)', '71% (12/17)']}},
#  'https://www.livesport.com/en/match/fcvgUhU0/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '18.04.2024', 'time': '14:35'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Arnaldi M.',
#     'rank': '37',
#     'is_winner': True,
#     'seed': ''},
#    'player2': {'name': 'Trungelliti M.',
#     'rank': '141',
#     'is_winner': False,
#     'seed': ''},
#    'sets_score': {'Wsets': 2, 'Lsets': 0},
#    'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'},
#     'player2': {'Set 1': '3', 'Set 2': '0'}},
#    'duration': '1:25'},
#   'match_statistics': {'Aces': ['2', '2'],
#    'Double Faults': ['0', '2'],
#    '1st Serve Percentage': ['55%', '61%'],
#    '1st Serve Points Won': ['85% (22/26)', '55% (21/38)'],
#    '2nd Serve Points Won': ['67% (14/21)', '38% (9/24)'],
#    'Break Points Saved': ['100% (1/1)', '71% (10/14)'],
#    '1st Return Points Won': ['45% (17/38)', '15% (4/26)'],
#    '2nd Return Points Won': ['63% (15/24)', '33% (7/21)'],
#    'Break Points Converted': ['29% (4/14)', '0% (0/1)'],
#    'Service Points Won': ['77% (36/47)', '48% (30/62)'],
#    'Return Points Won': ['52% (32/62)', '23% (11/47)'],
#    'Total Points Won': ['62% (68/109)', '38% (41/109)'],
#    'Last 10 Balls': ['10', '0'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['100% (8/8)', '43% (3/7)'],
#    'Return Games Won': ['57% (4/7)', '0% (0/8)'],
#    'Total Games Won': ['80% (12/15)', '20% (3/15)']}},
#  'https://www.livesport.com/en/match/Mm4Jm5JM/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '18.04.2024', 'time': '12:55'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Davidovich Fokina A.',
#     'rank': '62',
#     'is_winner': False,
#     'seed': '11'},
#    'player2': {'name': 'Lajovic D.',
#     'rank': '81',
#     'is_winner': True,
#     'seed': ''},
#    'sets_score': {'Wsets': 1, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '6\n10', 'Set 2': '6', 'Set 3': '1'},
#     'player2': {'Set 1': '7\n12', 'Set 2': '3', 'Set 3': '6'}},
#    'duration': '2:32'},
#   'match_statistics': {'Aces': ['0', '2'],
#    'Double Faults': ['3', '3'],
#    '1st Serve Percentage': ['67%', '74%'],
#    '1st Serve Points Won': ['56% (35/62)', '65% (56/86)'],
#    '2nd Serve Points Won': ['53% (16/30)', '32% (10/31)'],
#    'Break Points Saved': ['40% (4/10)', '67% (10/15)'],
#    '1st Return Points Won': ['35% (30/86)', '44% (27/62)'],
#    '2nd Return Points Won': ['68% (21/31)', '47% (14/30)'],
#    'Break Points Converted': ['33% (5/15)', '60% (6/10)'],
#    'Service Points Won': ['55% (51/92)', '56% (66/117)'],
#    'Return Points Won': ['44% (51/117)', '45% (41/92)'],
#    'Total Points Won': ['49% (102/209)', '51% (107/209)'],
#    'Last 10 Balls': ['1', '9'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['57% (8/14)', '64% (9/14)'],
#    'Return Games Won': ['36% (5/14)', '43% (6/14)'],
#    'Total Games Won': ['46% (13/28)', '54% (15/28)']}},
#  'https://www.livesport.com/en/match/MRn9fzQF/#/match-summary': {'match_summary': {'tournament_info': {'tournament_name': 'BARCELONA',
#     'location': 'SPAIN',
#     'surface': 'CLAY',
#     'court': 'outdoor',
#     'round_name': '1/8-FINALS'},
#    'time_and_date': {'date': '18.04.2024', 'time': '11:10'},
#    'comment': 'FINISHED',
#    'player1': {'name': 'Bautista-Agut R.',
#     'rank': '51',
#     'is_winner': False,
#     'seed': ''},
#    'player2': {'name': 'Norrie C.',
#     'rank': '49',
#     'is_winner': True,
#     'seed': '12'},
#    'sets_score': {'Wsets': 0, 'Lsets': 2},
#    'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '3'},
#     'player2': {'Set 1': '6', 'Set 2': '6'}},
#    'duration': '1:25'},
#   'match_statistics': {'Aces': ['1', '4'],
#    'Double Faults': ['1', '3'],
#    '1st Serve Percentage': ['67%', '57%'],
#    '1st Serve Points Won': ['61% (22/36)', '73% (19/26)'],
#    '2nd Serve Points Won': ['39% (7/18)', '45% (9/20)'],
#    'Break Points Saved': ['29% (2/7)', '0% (0/2)'],
#    '1st Return Points Won': ['27% (7/26)', '39% (14/36)'],
#    '2nd Return Points Won': ['55% (11/20)', '61% (11/18)'],
#    'Break Points Converted': ['100% (2/2)', '71% (5/7)'],
#    'Service Points Won': ['54% (29/54)', '61% (28/46)'],
#    'Return Points Won': ['39% (18/46)', '46% (25/54)'],
#    'Total Points Won': ['47% (47/100)', '53% (53/100)'],
#    'Last 10 Balls': ['2', '8'],
#    'Match Points Saved': ['0', '0'],
#    'Service Games Won': ['50% (5/10)', '78% (7/9)'],
#    'Return Games Won': ['22% (2/9)', '50% (5/10)'],
#    'Total Games Won': ['37% (7/19)', '63% (12/19)']}},
#  ...}

# %%
def transform_data_to_dataframe(data):
    rows = []
    for url, match_data in data.items():
        summary = match_data['match_summary']
        print(summary)
        if summary["tournament_info"]["tournament_name"] != "OLYMPIC GAMES":
            stats = match_data.get('match_statistics', {})
            
            # Determine winner and loser based on is_winner flag
            if summary['player1']['is_winner']:
                winner, loser = summary['player1'], summary['player2']
            else:
                winner, loser = summary['player2'], summary['player1']
            
            # Base row for all cases
            row = {
                "url": url,
                "tournament_name": summary["tournament_info"]["tournament_name"],
                "location": summary["tournament_info"]["location"],
                "surface": summary["tournament_info"]["surface"],
                "round_name": summary["tournament_info"]["round_name"],
                "date": summary["time_and_date"]["date"],
                "time": summary["time_and_date"]["time"],
                "comment": summary["comment"],
                "winner_name": winner["name"],
                "winner_rank": winner["rank"],
                "winner_seed": winner.get("seed", ""),
                "loser_name": loser["name"],
                "loser_rank": loser["rank"],
                "loser_seed": loser.get("seed", "")
            }
            
            # For WALKOVER, skip additional stats and set others to empty
            if summary["comment"] == "WALKOVER" or summary["tournament_info"]["tournament_name"] == "OLYMPIC GAMES":
                # Set remaining fields to empty
                row.update({
                    "winner_sets": "",
                    "loser_sets": "",
                    "duration": ""
                })
            else:
                # Add regular match-specific fields
                row.update({
                    "winner_sets": summary["sets_score"]["Wsets"],
                    "loser_sets": summary["sets_score"]["Lsets"],
                    "duration": summary["duration"]
                })
                
                # Add set scores
                winner_scores = summary["scores_by_set"].get("player1" if summary['player1']['is_winner'] else "player2", {})
                loser_scores = summary["scores_by_set"].get("player2" if summary['player1']['is_winner'] else "player1", {})
                
                for set_num, score in winner_scores.items():
                    row[f"winner_{set_num}"] = score
                for set_num, score in loser_scores.items():
                    row[f"loser_{set_num}"] = score
                
                # Add match statistics
                if summary['player1']['is_winner']:
                    for stat_name, values in stats.items():
                        row[f"winner_{stat_name}"] = values[0]
                        row[f"loser_{stat_name}"] = values[1]
                else:
                    for stat_name, values in stats.items():
                        row[f"winner_{stat_name}"] = values[1]
                        row[f"loser_{stat_name}"] = values[0]
            
            rows.append(row)
    
    # Create a DataFrame
    return pd.DataFrame(rows)

# Example usage
df = transform_data_to_dataframe(livesport)
df
# Out:
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'FINAL'}, 'time_and_date': {'date': '07.01.2024', 'time': '07:55'}, 'comment': 'FINISHED', 'player1': {'name': 'Rune H.', 'rank': '13', 'is_winner': False, 'seed': '1'}, 'player2': {'name': 'Dimitrov G.', 'rank': '10', 'is_winner': True, 'seed': '2'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '6\n5', 'Set 2': '4'}, 'player2': {'Set 1': '7\n7', 'Set 2': '6'}}, 'duration': '2:19'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'SEMI-FINALS'}, 'time_and_date': {'date': '06.01.2024', 'time': '11:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Thompson J.', 'rank': '26', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Dimitrov G.', 'rank': '10', 'is_winner': True, 'seed': '2'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '5'}, 'player2': {'Set 1': '6', 'Set 2': '7'}}, 'duration': '1:47'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'SEMI-FINALS'}, 'time_and_date': {'date': '06.01.2024', 'time': '06:05'}, 'comment': 'FINISHED', 'player1': {'name': 'Rune H.', 'rank': '13', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Safiullin R.', 'rank': '60', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7\n7'}, 'player2': {'Set 1': '4', 'Set 2': '6\n0'}}, 'duration': '1:39'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '05.01.2024', 'time': '11:35'}, 'comment': 'FINISHED', 'player1': {'name': 'Nadal R.', 'rank': '155', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Thompson J.', 'rank': '26', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '6\n6', 'Set 3': '3'}, 'player2': {'Set 1': '5', 'Set 2': '7\n8', 'Set 3': '6'}}, 'duration': '3:24'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '05.01.2024', 'time': '08:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Hijikata R.', 'rank': '73', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Dimitrov G.', 'rank': '10', 'is_winner': True, 'seed': '2'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '1', 'Set 2': '4'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:19'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '05.01.2024', 'time': '06:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Rune H.', 'rank': '13', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Duckworth J.', 'rank': '82', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7\n8'}, 'player2': {'Set 1': '2', 'Set 2': '6\n6'}}, 'duration': '1:47'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '05.01.2024', 'time': '03:50'}, 'comment': 'FINISHED', 'player1': {'name': 'Safiullin R.', 'rank': '60', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Arnaldi M.', 'rank': '37', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7\n7', 'Set 2': '6'}, 'player2': {'Set 1': '6\n4', 'Set 2': '2'}}, 'duration': '1:48'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '04.01.2024', 'time': '09:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Kubler J.', 'rank': '752', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Nadal R.', 'rank': '155', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '1', 'Set 2': '2'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:21'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '04.01.2024', 'time': '06:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Altmaier D.', 'rank': '88', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Dimitrov G.', 'rank': '10', 'is_winner': True, 'seed': '2'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '1', 'Set 2': '2'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:08'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '04.01.2024', 'time': '03:30'}, 'comment': 'WALKOVER', 'player1': {'name': 'Thompson J.', 'rank': '26', 'is_winner': True}, 'player2': {'name': 'Humbert U.', 'rank': '14', 'is_winner': False}}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '04.01.2024', 'time': '02:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Machac T.', 'rank': '25', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Hijikata R.', 'rank': '73', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '2', 'Set 3': '6\n4'}, 'player2': {'Set 1': '5', 'Set 2': '6', 'Set 3': '7\n7'}}, 'duration': '2:30'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '03.01.2024', 'time': '11:20'}, 'comment': 'FINISHED', 'player1': {'name': 'Rune H.', 'rank': '13', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Shevchenko A.', 'rank': '78', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '5', 'Set 3': '6'}, 'player2': {'Set 1': '4', 'Set 2': '7', 'Set 3': '2'}}, 'duration': '2:29'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '03.01.2024', 'time': '06:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Safiullin R.', 'rank': '60', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Popyrin A.', 'rank': '24', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6\n9', 'Set 2': '6', 'Set 3': '7\n7'}, 'player2': {'Set 1': '7\n11', 'Set 2': '4', 'Set 3': '6\n3'}}, 'duration': '2:56'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '03.01.2024', 'time': '04:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Arnaldi M.', 'rank': '37', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Klein L.', 'rank': '137', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '3', 'Set 3': '7'}, 'player2': {'Set 1': '4', 'Set 2': '6', 'Set 3': '5'}}, 'duration': '2:05'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '03.01.2024', 'time': '04:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Duckworth J.', 'rank': '82', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Hanfmann Y.', 'rank': '96', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '6', 'Set 3': '7\n7'}, 'player2': {'Set 1': '6', 'Set 2': '1', 'Set 3': '6\n2'}}, 'duration': '2:27'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '03.01.2024', 'time': '02:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Michelsen A.', 'rank': '42', 'is_winner': False, 'seed': 'Q/LL'}, 'player2': {'name': 'Humbert U.', 'rank': '14', 'is_winner': True, 'seed': '4'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '4'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:37'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '11:55'}, 'comment': 'FINISHED', 'player1': {'name': 'Kokkinakis T.', 'rank': '77', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Hijikata R.', 'rank': '73', 'is_winner': True, 'seed': 'WC'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '6\n8', 'Set 2': '2'}, 'player2': {'Set 1': '7\n10', 'Set 2': '6'}}, 'duration': '1:39'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '10:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Thiem D.', 'rank': '519', 'is_winner': False, 'seed': 'Q/LL'}, 'player2': {'name': 'Nadal R.', 'rank': '155', 'is_winner': True, 'seed': 'WC'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '5', 'Set 2': '1'}, 'player2': {'Set 1': '7', 'Set 2': '6'}}, 'duration': '1:30'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '09:45'}, 'comment': 'FINISHED', 'player1': {'name': 'Arnaldi M.', 'rank': '37', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Fucsovics M.', 'rank': '103', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6\n5', 'Set 2': '6', 'Set 3': '7\n9'}, 'player2': {'Set 1': '7\n7', 'Set 2': '4', 'Set 3': '6\n7'}}, 'duration': '3:09'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '09:35'}, 'comment': 'FINISHED / RETIRED -\nKARATSEV A.', 'player1': {'name': 'Karatsev A.', 'rank': '291', 'is_winner': False, 'seed': '8'}, 'player2': {'name': 'Kubler J.', 'rank': '752', 'is_winner': True, 'seed': 'WC'}, 'sets_score': {'Wsets': 1, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '7\n7'}, 'player2': {'Set 1': '6', 'Set 2': '6\n4'}}, 'duration': '2:05'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '08:55'}, 'comment': 'FINISHED', 'player1': {'name': 'Thompson J.', 'rank': '26', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Vukic A.', 'rank': '69', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '3', 'Set 2': '2'}}, 'duration': '1:30'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '08:35'}, 'comment': 'FINISHED', 'player1': {'name': 'Etcheverry T. M.', 'rank': '39', 'is_winner': False, 'seed': '7'}, 'player2': {'name': 'Machac T.', 'rank': '25', 'is_winner': True, 'seed': 'Q/LL'}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '7\n7', 'Set 2': '5', 'Set 3': '6\n1'}, 'player2': {'Set 1': '6\n5', 'Set 2': '7', 'Set 3': '7\n7'}}, 'duration': '2:57'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '07:15'}, 'comment': 'FINISHED', 'player1': {'name': 'Tu L.', 'rank': '172', 'is_winner': False, 'seed': 'Q/LL'}, 'player2': {'name': 'Altmaier D.', 'rank': '88', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '6\n5', 'Set 2': '6\n4'}, 'player2': {'Set 1': '7\n7', 'Set 2': '7\n7'}}, 'duration': '2:03'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '07:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Wolf J.J.', 'rank': '262', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Duckworth J.', 'rank': '82', 'is_winner': True, 'seed': 'Q/LL'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '4'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:05'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '06:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Klein L.', 'rank': '137', 'is_winner': True, 'seed': 'Q/LL'}, 'player2': {'name': 'Baez S.', 'rank': '27', 'is_winner': False, 'seed': '6'}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '6', 'Set 3': '6'}, 'player2': {'Set 1': '6', 'Set 2': '3', 'Set 3': '4'}}, 'duration': '2:16'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '02:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Hanfmann Y.', 'rank': '96', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Korda S.', 'rank': '22', 'is_winner': False, 'seed': '5'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '6'}, 'player2': {'Set 1': '5', 'Set 2': '4'}}, 'duration': '1:38'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '01.01.2024', 'time': '09:50'}, 'comment': 'FINISHED', 'player1': {'name': 'Murray A.', 'rank': '', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Dimitrov G.', 'rank': '10', 'is_winner': True, 'seed': '2'}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '5', 'Set 3': '2'}, 'player2': {'Set 1': '4', 'Set 2': '7', 'Set 3': '6'}}, 'duration': '2:27'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '01.01.2024', 'time': '07:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Rune H.', 'rank': '13', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Purcell M.', 'rank': '104', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '6', 'Set 3': '6'}, 'player2': {'Set 1': '6', 'Set 2': '4', 'Set 3': '2'}}, 'duration': '1:42'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '01.01.2024', 'time': '04:20'}, 'comment': 'FINISHED', 'player1': {'name': 'Shelton B.', 'rank': '21', 'is_winner': False, 'seed': '3'}, 'player2': {'name': 'Safiullin R.', 'rank': '60', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '7\n7', 'Set 3': '3'}, 'player2': {'Set 1': '6', 'Set 2': '6\n5', 'Set 3': '6'}}, 'duration': '2:39'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '31.12.2023', 'time': '06:40'}, 'comment': 'FINISHED', 'player1': {'name': 'van Assche L.', 'rank': '128', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Shevchenko A.', 'rank': '78', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '2'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:15'}
# {'tournament_info': {'tournament_name': 'BRISBANE', 'location': 'AUSTRALIA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '31.12.2023', 'time': '06:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Popyrin A.', 'rank': '24', 'is_winner': True, 'seed': ''}, 'player2': {'name': "O'Connell C.", 'rank': '65', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6\n5', 'Set 3': '7\n7'}, 'player2': {'Set 1': '4', 'Set 2': '7\n7', 'Set 3': '6\n4'}}, 'duration': '3:06'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'FINAL'}, 'time_and_date': {'date': '07.01.2024', 'time': '09:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Rublev A.', 'rank': '8', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Ruusuvuori E.', 'rank': '95', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '4', 'Set 2': '4'}}, 'duration': '1:18'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'SEMI-FINALS'}, 'time_and_date': {'date': '06.01.2024', 'time': '10:15'}, 'comment': 'FINISHED', 'player1': {'name': 'Rublev A.', 'rank': '8', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Shang J.', 'rank': '50', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '6', 'Set 3': '6'}, 'player2': {'Set 1': '6', 'Set 2': '2', 'Set 3': '3'}}, 'duration': '2:07'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'SEMI-FINALS'}, 'time_and_date': {'date': '06.01.2024', 'time': '07:45'}, 'comment': 'FINISHED', 'player1': {'name': 'Ofner S.', 'rank': '87', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Ruusuvuori E.', 'rank': '95', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '5', 'Set 3': '3'}, 'player2': {'Set 1': '4', 'Set 2': '7', 'Set 3': '6'}}, 'duration': '2:13'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '05.01.2024', 'time': '11:50'}, 'comment': 'FINISHED', 'player1': {'name': 'Rublev A.', 'rank': '8', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Fils A.', 'rank': '20', 'is_winner': False, 'seed': '8'}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '1', 'Set 3': '6'}, 'player2': {'Set 1': '4', 'Set 2': '6', 'Set 3': '2'}}, 'duration': '1:53'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '05.01.2024', 'time': '10:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Tiafoe F.', 'rank': '18', 'is_winner': False, 'seed': '3'}, 'player2': {'name': 'Shang J.', 'rank': '50', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '4'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:30'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '05.01.2024', 'time': '08:15'}, 'comment': 'FINISHED', 'player1': {'name': 'Ofner S.', 'rank': '87', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Bautista-Agut R.', 'rank': '51', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '4', 'Set 2': '4'}}, 'duration': '1:25'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '05.01.2024', 'time': '06:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Kotov P.', 'rank': '85', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Ruusuvuori E.', 'rank': '95', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '6\n4'}, 'player2': {'Set 1': '6', 'Set 2': '7\n7'}}, 'duration': '1:49'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '04.01.2024', 'time': '11:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Rublev A.', 'rank': '8', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Broady L.', 'rank': '542', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7\n10'}, 'player2': {'Set 1': '4', 'Set 2': '6\n8'}}, 'duration': '1:52'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '04.01.2024', 'time': '09:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Huesler M.', 'rank': '160', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Fils A.', 'rank': '20', 'is_winner': True, 'seed': '8'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '5', 'Set 2': '5'}, 'player2': {'Set 1': '7', 'Set 2': '7'}}, 'duration': '2:01'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '04.01.2024', 'time': '07:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Bautista-Agut R.', 'rank': '51', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Cerundolo F.', 'rank': '30', 'is_winner': False, 'seed': '4'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '6'}, 'player2': {'Set 1': '5', 'Set 2': '3'}}, 'duration': '1:40'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '04.01.2024', 'time': '07:05'}, 'comment': 'FINISHED', 'player1': {'name': 'Struff J-L.', 'rank': '43', 'is_winner': False, 'seed': '5'}, 'player2': {'name': 'Ofner S.', 'rank': '87', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '7\n7', 'Set 2': '6\n5', 'Set 3': '6\n2'}, 'player2': {'Set 1': '6\n4', 'Set 2': '7\n7', 'Set 3': '7\n7'}}, 'duration': '2:51'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '03.01.2024', 'time': '15:35'}, 'comment': 'FINISHED', 'player1': {'name': 'Musetti L.', 'rank': '17', 'is_winner': False, 'seed': '6'}, 'player2': {'name': 'Kotov P.', 'rank': '85', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '3'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:43'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '03.01.2024', 'time': '12:55'}, 'comment': 'FINISHED', 'player1': {'name': 'Ruusuvuori E.', 'rank': '95', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Khachanov K.', 'rank': '19', 'is_winner': False, 'seed': '2'}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '7\n7', 'Set 2': '2', 'Set 3': '6'}, 'player2': {'Set 1': '6\n2', 'Set 2': '6', 'Set 3': '2'}}, 'duration': '2:27'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '03.01.2024', 'time': '11:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Tiafoe F.', 'rank': '18', 'is_winner': True, 'seed': '3'}, 'player2': {'name': 'Kecmanovic M.', 'rank': '54', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7\n7'}, 'player2': {'Set 1': '3', 'Set 2': '6\n4'}}, 'duration': '1:34'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '03.01.2024', 'time': '07:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Van De Zandschulp B.', 'rank': '80', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Shang J.', 'rank': '50', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '7\n7', 'Set 2': '6\n2', 'Set 3': '6\n2'}, 'player2': {'Set 1': '6\n5', 'Set 2': '7\n7', 'Set 3': '7\n7'}}, 'duration': '3:35'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '11:50'}, 'comment': 'FINISHED', 'player1': {'name': 'Musetti L.', 'rank': '17', 'is_winner': True, 'seed': '6'}, 'player2': {'name': 'Wong C.', 'rank': '163', 'is_winner': False, 'seed': 'WC'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7'}, 'player2': {'Set 1': '4', 'Set 2': '5'}}, 'duration': '1:46'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '10:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Gojo B.', 'rank': '445', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Fils A.', 'rank': '20', 'is_winner': True, 'seed': '8'}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '6', 'Set 3': '1'}, 'player2': {'Set 1': '6', 'Set 2': '4', 'Set 3': '6'}}, 'duration': '1:50'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '08:35'}, 'comment': 'FINISHED', 'player1': {'name': 'Huesler M.', 'rank': '160', 'is_winner': True, 'seed': 'Q'}, 'player2': {'name': 'Sachko V.', 'rank': '387', 'is_winner': False, 'seed': 'Q'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '4', 'Set 2': '4'}}, 'duration': '1:27'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '08:35'}, 'comment': 'FINISHED', 'player1': {'name': 'Marozsan F.', 'rank': '58', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Bautista-Agut R.', 'rank': '51', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '2', 'Set 2': '3'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:10'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '08:30'}, 'comment': 'FINISHED', 'player1': {'name': 'Struff J-L.', 'rank': '43', 'is_winner': True, 'seed': '5'}, 'player2': {'name': 'Cilic M.', 'rank': '181', 'is_winner': False, 'seed': 'PR'}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '7\n7', 'Set 3': '7\n9'}, 'player2': {'Set 1': '6', 'Set 2': '6\n4', 'Set 3': '6\n7'}}, 'duration': '3:09'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '07:05'}, 'comment': 'FINISHED', 'player1': {'name': 'Broady L.', 'rank': '542', 'is_winner': True, 'seed': 'Q'}, 'player2': {'name': 'Cachin P.', 'rank': '289', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '4', 'Set 2': '0'}}, 'duration': '1:11'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '07:05'}, 'comment': 'FINISHED', 'player1': {'name': 'Kecmanovic M.', 'rank': '54', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Daniel T.', 'rank': '83', 'is_winner': False, 'seed': 'Q'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '3', 'Set 2': '2'}}, 'duration': '1:11'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '02.01.2024', 'time': '07:05'}, 'comment': 'FINISHED', 'player1': {'name': 'Ofner S.', 'rank': '87', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'McDonald M.', 'rank': '131', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '1', 'Set 2': '2'}}, 'duration': '1:08'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '01.01.2024', 'time': '13:15'}, 'comment': 'FINISHED', 'player1': {'name': 'Mochizuki S.', 'rank': '248', 'is_winner': False, 'seed': 'WC'}, 'player2': {'name': 'Van De Zandschulp B.', 'rank': '80', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '5', 'Set 2': '1'}, 'player2': {'Set 1': '7', 'Set 2': '6'}}, 'duration': '1:39'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '01.01.2024', 'time': '10:20'}, 'comment': 'FINISHED', 'player1': {'name': 'Ruusuvuori E.', 'rank': '95', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Bonzi B.', 'rank': '75', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6\n5', 'Set 2': '6', 'Set 3': '6'}, 'player2': {'Set 1': '7\n7', 'Set 2': '2', 'Set 3': '1'}}, 'duration': '2:40'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '01.01.2024', 'time': '09:35'}, 'comment': 'FINISHED', 'player1': {'name': 'Kotov P.', 'rank': '85', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Borges N.', 'rank': '33', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '2', 'Set 2': '4'}}, 'duration': '1:29'}
# {'tournament_info': {'tournament_name': 'HONG KONG', 'location': 'HONG KONG', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '01.01.2024', 'time': '07:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Shang J.', 'rank': '50', 'is_winner': True, 'seed': 'WC'}, 'player2': {'name': 'Djere L.', 'rank': '115', 'is_winner': False, 'seed': '7'}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6\n5', 'Set 2': '6', 'Set 3': '7\n10'}, 'player2': {'Set 1': '7\n7', 'Set 2': '3', 'Set 3': '6\n8'}}, 'duration': '2:54'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'FINAL'}, 'time_and_date': {'date': '13.01.2024', 'time': '02:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Daniel T.', 'rank': '83', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Tabilo A.', 'rank': '23', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '2', 'Set 2': '5'}, 'player2': {'Set 1': '6', 'Set 2': '7'}}, 'duration': '1:38'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'SEMI-FINALS'}, 'time_and_date': {'date': '12.01.2024', 'time': '03:30'}, 'comment': 'FINISHED', 'player1': {'name': 'Fils A.', 'rank': '20', 'is_winner': False, 'seed': '6'}, 'player2': {'name': 'Tabilo A.', 'rank': '23', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '2', 'Set 2': '5'}, 'player2': {'Set 1': '6', 'Set 2': '7'}}, 'duration': '1:49'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'SEMI-FINALS'}, 'time_and_date': {'date': '12.01.2024', 'time': '01:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Shelton B.', 'rank': '21', 'is_winner': False, 'seed': '1'}, 'player2': {'name': 'Daniel T.', 'rank': '83', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '5', 'Set 2': '6\n9'}, 'player2': {'Set 1': '7', 'Set 2': '7\n11'}}, 'duration': '2:01'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '11.01.2024', 'time': '06:45'}, 'comment': 'FINISHED / RETIRED -\nALTMAIER D.', 'player1': {'name': 'Fils A.', 'rank': '20', 'is_winner': True, 'seed': '6'}, 'player2': {'name': 'Altmaier D.', 'rank': '88', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7\n7'}, 'player2': {'Set 1': '6\n2'}}, 'duration': '1:17'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '11.01.2024', 'time': '04:55'}, 'comment': 'WALKOVER', 'player1': {'name': 'Tabilo A.', 'rank': '23', 'is_winner': True}, 'player2': {'name': 'Norrie C.', 'rank': '49', 'is_winner': False}}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '11.01.2024', 'time': '03:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Shelton B.', 'rank': '21', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Carballes Baena R.', 'rank': '57', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '4', 'Set 2': '3'}}, 'duration': '1:41'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': 'QUARTER-FINALS'}, 'time_and_date': {'date': '11.01.2024', 'time': '00:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Muller A.', 'rank': '68', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Daniel T.', 'rank': '83', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '7\n7', 'Set 3': '3'}, 'player2': {'Set 1': '6', 'Set 2': '6\n3', 'Set 3': '6'}}, 'duration': '2:41'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '10.01.2024', 'time': '06:40'}, 'comment': 'FINISHED', 'player1': {'name': 'van Assche L.', 'rank': '128', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Norrie C.', 'rank': '49', 'is_winner': True, 'seed': '2'}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '7\n8', 'Set 3': '1'}, 'player2': {'Set 1': '6', 'Set 2': '6\n6', 'Set 3': '6'}}, 'duration': '2:30'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '10.01.2024', 'time': '05:05'}, 'comment': 'FINISHED', 'player1': {'name': 'Van De Zandschulp B.', 'rank': '80', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Tabilo A.', 'rank': '23', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '5', 'Set 2': '3'}, 'player2': {'Set 1': '7', 'Set 2': '6'}}, 'duration': '1:17'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '10.01.2024', 'time': '04:30'}, 'comment': 'FINISHED', 'player1': {'name': 'Fils A.', 'rank': '20', 'is_winner': True, 'seed': '6'}, 'player2': {'name': 'Borges N.', 'rank': '33', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '2', 'Set 2': '0'}}, 'duration': '0:53'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '10.01.2024', 'time': '03:05'}, 'comment': 'FINISHED', 'player1': {'name': 'Carballes Baena R.', 'rank': '57', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Ofner S.', 'rank': '87', 'is_winner': False, 'seed': '7'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '6'}, 'player2': {'Set 1': '5', 'Set 2': '3'}}, 'duration': '1:42'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '10.01.2024', 'time': '03:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Shelton B.', 'rank': '21', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Marozsan F.', 'rank': '58', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '3', 'Set 2': '4'}}, 'duration': '1:12'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '10.01.2024', 'time': '01:30'}, 'comment': 'FINISHED', 'player1': {'name': 'Daniel T.', 'rank': '83', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Purcell M.', 'rank': '104', 'is_winner': False, 'seed': '8'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '2', 'Set 2': '4'}}, 'duration': '1:15'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '10.01.2024', 'time': '00:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Altmaier D.', 'rank': '88', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Auger-Aliassime F.', 'rank': '29', 'is_winner': False, 'seed': '4'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7\n11', 'Set 2': '7'}, 'player2': {'Set 1': '6\n9', 'Set 2': '5'}}, 'duration': '2:36'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/8-FINALS'}, 'time_and_date': {'date': '10.01.2024', 'time': '00:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Cerundolo F.', 'rank': '30', 'is_winner': False, 'seed': '3'}, 'player2': {'name': 'Muller A.', 'rank': '68', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '1', 'Set 2': '1'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:08'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '09.01.2024', 'time': '06:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Fils A.', 'rank': '20', 'is_winner': True, 'seed': '6'}, 'player2': {'name': 'Gasquet R.', 'rank': '129', 'is_winner': False, 'seed': 'WC'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '3', 'Set 2': '4'}}, 'duration': '1:10'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '09.01.2024', 'time': '03:35'}, 'comment': 'FINISHED', 'player1': {'name': 'Pannu K.', 'rank': '494', 'is_winner': False, 'seed': 'WC'}, 'player2': {'name': 'Purcell M.', 'rank': '104', 'is_winner': True, 'seed': '8'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '4'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:28'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '09.01.2024', 'time': '02:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Shapovalov D.', 'rank': '56', 'is_winner': False, 'seed': 'WC'}, 'player2': {'name': 'Ofner S.', 'rank': '87', 'is_winner': True, 'seed': '7'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '2'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:09'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '09.01.2024', 'time': '00:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Bautista-Agut R.', 'rank': '51', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Carballes Baena R.', 'rank': '57', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '3'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:44'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '08.01.2024', 'time': '06:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Marozsan F.', 'rank': '58', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Monfils G.', 'rank': '55', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6\n6', 'Set 3': '7\n7'}, 'player2': {'Set 1': '4', 'Set 2': '7\n8', 'Set 3': '6\n4'}}, 'duration': '2:38'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '08.01.2024', 'time': '05:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Michelsen A.', 'rank': '42', 'is_winner': False, 'seed': 'Q'}, 'player2': {'name': 'Borges N.', 'rank': '33', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6\n6', 'Set 3': '3'}, 'player2': {'Set 1': '0', 'Set 2': '7\n8', 'Set 3': '6'}}, 'duration': '2:00'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '08.01.2024', 'time': '03:50'}, 'comment': 'FINISHED', 'player1': {'name': 'Muller A.', 'rank': '68', 'is_winner': True, 'seed': 'Q'}, 'player2': {'name': 'Bonzi B.', 'rank': '75', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7'}, 'player2': {'Set 1': '3', 'Set 2': '5'}}, 'duration': '1:39'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '08.01.2024', 'time': '03:45'}, 'comment': 'FINISHED', 'player1': {'name': 'Eubanks C.', 'rank': '108', 'is_winner': False, 'seed': '5'}, 'player2': {'name': 'Van De Zandschulp B.', 'rank': '80', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '6\n5', 'Set 2': '2'}, 'player2': {'Set 1': '7\n7', 'Set 2': '6'}}, 'duration': '1:36'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '08.01.2024', 'time': '02:05'}, 'comment': 'FINISHED', 'player1': {'name': 'Gojo B.', 'rank': '445', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Tabilo A.', 'rank': '23', 'is_winner': True, 'seed': 'Q'}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '3', 'Set 3': '2'}, 'player2': {'Set 1': '1', 'Set 2': '6', 'Set 3': '6'}}, 'duration': '1:32'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '08.01.2024', 'time': '02:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Wolf J.J.', 'rank': '262', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'van Assche L.', 'rank': '128', 'is_winner': True, 'seed': 'Q'}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '2'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:34'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '08.01.2024', 'time': '00:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Altmaier D.', 'rank': '88', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Giron M.', 'rank': '46', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7\n7', 'Set 2': '6'}, 'player2': {'Set 1': '6\n5', 'Set 2': '2'}}, 'duration': '1:35'}
# {'tournament_info': {'tournament_name': 'AUCKLAND', 'location': 'NEW ZEALAND', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '08.01.2024', 'time': '00:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Vukic A.', 'rank': '69', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Daniel T.', 'rank': '83', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '5', 'Set 2': '5'}, 'player2': {'Set 1': '7', 'Set 2': '7'}}, 'duration': '1:40'}
# ...
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '15.08.2024', 'time': '01:00'}, 'comment': 'FINISHED', 'player1': {'name': 'Musetti L.', 'rank': '17', 'is_winner': False, 'seed': '14'}, 'player2': {'name': 'Tiafoe F.', 'rank': '18', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '2'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:08'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '22:25'}, 'comment': 'FINISHED', 'player1': {'name': 'Etcheverry T. M.', 'rank': '39', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Arnaldi M.', 'rank': '37', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6\n3', 'Set 3': '6'}, 'player2': {'Set 1': '3', 'Set 2': '7\n7', 'Set 3': '2'}}, 'duration': '2:35'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '21:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Carreno-Busta P.', 'rank': '198', 'is_winner': True, 'seed': 'PR'}, 'player2': {'name': 'Korda S.', 'rank': '22', 'is_winner': False, 'seed': '16'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '6'}, 'player2': {'Set 1': '5', 'Set 2': '1'}}, 'duration': '1:18'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '20:55'}, 'comment': 'FINISHED', 'player1': {'name': 'Monfils G.', 'rank': '55', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Popyrin A.', 'rank': '24', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '6'}, 'player2': {'Set 1': '5', 'Set 2': '3'}}, 'duration': '1:22'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '19:35'}, 'comment': 'FINISHED', 'player1': {'name': 'Draper J.', 'rank': '15', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Munar J.', 'rank': '63', 'is_winner': False, 'seed': 'Q'}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '7', 'Set 2': '3', 'Set 3': '7\n7'}, 'player2': {'Set 1': '5', 'Set 2': '6', 'Set 3': '6\n5'}}, 'duration': '2:35'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/16-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '19:30'}, 'comment': 'FINISHED', 'player1': {'name': 'Sinner J.', 'rank': '1', 'is_winner': True, 'seed': '1'}, 'player2': {'name': 'Michelsen A.', 'rank': '42', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7'}, 'player2': {'Set 1': '4', 'Set 2': '5'}}, 'duration': '1:52'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '19:20'}, 'comment': 'FINISHED', 'player1': {'name': 'Purcell M.', 'rank': '104', 'is_winner': True, 'seed': 'WC'}, 'player2': {'name': 'Machac T.', 'rank': '25', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7\n7'}, 'player2': {'Set 1': '4', 'Set 2': '6\n1'}}, 'duration': '1:36'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '18:45'}, 'comment': 'FINISHED', 'player1': {'name': 'Rune H.', 'rank': '13', 'is_winner': True, 'seed': '15'}, 'player2': {'name': 'Berrettini M.', 'rank': '35', 'is_winner': False, 'seed': 'WC'}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '2', 'Set 2': '6', 'Set 3': '6'}, 'player2': {'Set 1': '6', 'Set 2': '1', 'Set 3': '4'}}, 'duration': '1:48'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '17:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Auger-Aliassime F.', 'rank': '29', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Kovacevic A.', 'rank': '97', 'is_winner': False, 'seed': 'Q'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '3', 'Set 2': '1'}}, 'duration': '1:14'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '17:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Marozsan F.', 'rank': '58', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Moutet C.', 'rank': '71', 'is_winner': False, 'seed': 'Q'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7\n7'}, 'player2': {'Set 1': '4', 'Set 2': '6\n2'}}, 'duration': '1:49'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '17:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Struff J-L.', 'rank': '43', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Tsitsipas S.', 'rank': '11', 'is_winner': True, 'seed': '9'}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '4', 'Set 3': '3'}, 'player2': {'Set 1': '4', 'Set 2': '6', 'Set 3': '6'}}, 'duration': '1:59'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '17:05'}, 'comment': 'FINISHED', 'player1': {'name': 'Mannarino A.', 'rank': '67', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Borges N.', 'rank': '33', 'is_winner': True, 'seed': 'Q'}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '6', 'Set 3': '1'}, 'player2': {'Set 1': '6', 'Set 2': '3', 'Set 3': '6'}}, 'duration': '2:05'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '03:40'}, 'comment': 'FINISHED', 'player1': {'name': 'Holt B.', 'rank': '200', 'is_winner': False, 'seed': 'Q'}, 'player2': {'name': 'Fils A.', 'rank': '20', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '1'}, 'player2': {'Set 1': '6', 'Set 2': '6'}}, 'duration': '1:11'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '01:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Fritz T.', 'rank': '4', 'is_winner': False, 'seed': '11'}, 'player2': {'name': 'Nakashima B.', 'rank': '38', 'is_winner': True, 'seed': 'WC'}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '6', 'Set 3': '6\n4'}, 'player2': {'Set 1': '6', 'Set 2': '4', 'Set 3': '7\n7'}}, 'duration': '2:19'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '14.08.2024', 'time': '00:15'}, 'comment': 'FINISHED', 'player1': {'name': 'Nishioka Y.', 'rank': '70', 'is_winner': True, 'seed': 'Q'}, 'player2': {'name': 'Kecmanovic M.', 'rank': '54', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7'}, 'player2': {'Set 1': '4', 'Set 2': '5'}}, 'duration': '1:21'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '22:20'}, 'comment': 'FINISHED', 'player1': {'name': 'Musetti L.', 'rank': '17', 'is_winner': True, 'seed': '14'}, 'player2': {'name': 'Jarry N.', 'rank': '36', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '7\n7', 'Set 3': '7\n7'}, 'player2': {'Set 1': '6', 'Set 2': '6\n5', 'Set 3': '6\n4'}}, 'duration': '2:50'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '21:45'}, 'comment': 'FINISHED', 'player1': {'name': 'Shelton B.', 'rank': '21', 'is_winner': True, 'seed': '12'}, 'player2': {'name': 'Opelka R.', 'rank': '299', 'is_winner': False, 'seed': 'WC'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7\n7', 'Set 2': '7\n7'}, 'player2': {'Set 1': '6\n3', 'Set 2': '6\n3'}}, 'duration': '1:41'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '21:20'}, 'comment': 'FINISHED', 'player1': {'name': 'Thompson J.', 'rank': '26', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Humbert U.', 'rank': '14', 'is_winner': False, 'seed': '13'}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '6', 'Set 3': '7\n7'}, 'player2': {'Set 1': '6', 'Set 2': '3', 'Set 3': '6\n4'}}, 'duration': '2:35'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '20:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Michelsen A.', 'rank': '42', 'is_winner': True, 'seed': 'Q'}, 'player2': {'name': 'Griekspoor T.', 'rank': '40', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '5', 'Set 3': '6'}, 'player2': {'Set 1': '1', 'Set 2': '7', 'Set 3': '2'}}, 'duration': '1:48'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '19:30'}, 'comment': 'FINISHED', 'player1': {'name': 'Lehecka J.', 'rank': '28', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Navone M.', 'rank': '47', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '7\n7', 'Set 2': '6'}, 'player2': {'Set 1': '6\n3', 'Set 2': '3'}}, 'duration': '1:29'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '18:50'}, 'comment': 'FINISHED', 'player1': {'name': 'Davidovich Fokina A.', 'rank': '62', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Tiafoe F.', 'rank': '18', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '6\n6'}, 'player2': {'Set 1': '6', 'Set 2': '7\n8'}}, 'duration': '1:44'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '17:15'}, 'comment': 'FINISHED', 'player1': {'name': 'Giron M.', 'rank': '46', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Baez S.', 'rank': '27', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 1, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '4', 'Set 2': '7', 'Set 3': '6\n6'}, 'player2': {'Set 1': '6', 'Set 2': '5', 'Set 3': '7\n8'}}, 'duration': '2:38'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '17:15'}, 'comment': 'FINISHED', 'player1': {'name': 'Tabilo A.', 'rank': '23', 'is_winner': False, 'seed': ''}, 'player2': {'name': 'Darderi L.', 'rank': '44', 'is_winner': True, 'seed': ''}, 'sets_score': {'Wsets': 0, 'Lsets': 2}, 'scores_by_set': {'player1': {'Set 1': '3', 'Set 2': '6\n5'}, 'player2': {'Set 1': '6', 'Set 2': '7\n7'}}, 'duration': '1:56'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '17:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Zhang Z.', 'rank': '45', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Mpetshi Perricard G.', 'rank': '31', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '7\n7'}, 'player2': {'Set 1': '3', 'Set 2': '6\n4'}}, 'duration': '1:20'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '13.08.2024', 'time': '01:50'}, 'comment': 'FINISHED', 'player1': {'name': 'Khachanov K.', 'rank': '19', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Cerundolo F.', 'rank': '30', 'is_winner': False, 'seed': ''}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '0', 'Set 2': '3'}}, 'duration': '1:05'}
# {'tournament_info': {'tournament_name': 'CINCINNATI', 'location': 'USA', 'surface': 'HARD', 'court': 'outdoor', 'round_name': '1/32-FINALS'}, 'time_and_date': {'date': '12.08.2024', 'time': '21:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Cobolli F.', 'rank': '32', 'is_winner': True, 'seed': ''}, 'player2': {'name': 'Paul T.', 'rank': '12', 'is_winner': False, 'seed': '10'}, 'sets_score': {'Wsets': 2, 'Lsets': 1}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '4', 'Set 3': '7'}, 'player2': {'Set 1': '2', 'Set 2': '6', 'Set 3': '5'}}, 'duration': '2:08'}
# {'tournament_info': {}, 'time_and_date': {'date': '24.08.2024', 'time': '23:10'}, 'comment': 'FINISHED', 'player1': {'name': 'Sonego L.', 'rank': '53', 'is_winner': True, 'seed': '10'}, 'player2': {'name': 'Michelsen A.', 'rank': '42', 'is_winner': False, 'seed': '11'}, 'sets_score': {'Wsets': 2, 'Lsets': 0}, 'scores_by_set': {'player1': {'Set 1': '6', 'Set 2': '6'}, 'player2': {'Set 1': '0', 'Set 2': '3'}}, 'duration': '1:04'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 74
#      71     return pd.DataFrame(rows)
#      73 # Example usage
# ---> 74 df = transform_data_to_dataframe(livesport)
#      75 df
#
# Cell In[9], line 6, in transform_data_to_dataframe(data)
#       4 summary = match_data['match_summary']
#       5 print(summary)
# ----> 6 if summary["tournament_info"]["tournament_name"] != "OLYMPIC GAMES":
#       7     stats = match_data.get('match_statistics', {})
#       9     # Determine winner and loser based on is_winner flag
#
# KeyError: 'tournament_name'

# %%
 # Convert column values to sets
set1 = set(matches["tournament_location"].str.lower())
set2 = set(df["tournament_name"].str.lower())
print(set2)
# Find unique values
unique_to_df1 = set1 - set2
unique_to_df2 = set2 - set1

print(f"Values in only in df1:")
print(unique_to_df1)
print()
print(f"Values in only in df2:")
print(unique_to_df2)

# %%
# Define a mapping for mismatched values
df['tournament_name'] = df['tournament_name'].str.lower()

mapping = {
    'hertogenbosch': "'s-hertogenbosch",
    'paris': 'paris 2',
    'london': 'queens club',
    'australian open': 'melbourne',
    'french open': 'paris',
    'wimbledon': 'london',
    'us open': 'new york',
}
df['tournament_name'] = df['tournament_name'].replace(mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Define a mapping for mismatched values
# ----> 2 df['tournament_name'] = df['tournament_name'].str.lower()
#       4 mapping = {
#       5     'hertogenbosch': "'s-hertogenbosch",
#       6     'paris': 'paris 2',
#    (...)
#      11     'us open': 'new york',
#      12 }
#      13 df['tournament_name'] = df['tournament_name'].replace(mapping)
#
# NameError: name 'df' is not defined

# %%
 # Convert column values to sets
set1 = set(matches["tournament_location"].str.lower())
set2 = set(matches2023["tournament_location"].str.lower())
set3 = set(df["tournament_name"].str.lower())
print(set2)
# Find unique values
unique_to_df1 = set2 - set3
unique_to_df2 = set3 - set1

print(f"Values in only in df1:")
print(unique_to_df1)
print()
print(f"Values in only in df2:")
print(unique_to_df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 set1 = set(matches["tournament_location"].str.lower())
#       3 set2 = set(matches2023["tournament_location"].str.lower())
# ----> 4 set3 = set(df["tournament_name"].str.lower())
#       5 print(set2)
#       6 # Find unique values
#
# NameError: name 'df' is not defined

# %%
df['winner_name'] = df['winner_name'].str.lower()
df['loser_name'] = df['loser_name'].str.lower()

 # Convert column values to sets
set1 = set(bets2024["Winner"].str.lower())
set2 = set(df["winner_name"].str.lower())
set3 = set(bets2024["Loser"].str.lower())
set4 = set(df["loser_name"].str.lower())

set1.update(set3)
set2.update(set4)


# Find unique values
unique_to_df1 = set1 - set2
unique_to_df2 = set2 - set1

print(f"Values in only in df1:")
print(unique_to_df1)
print()
print(f"Values in only in df2:")
print(unique_to_df2)
# Out:
# Values in only in df1:
# {'tseng c.h.', 'kwon s.w.', 'huesler m.a.', 'carreno busta p.', 'bailly g.', 'hong s.', 'mpetshi g.', 'bautista agut r.', 'herbert p.h.', 'burruchaga r.', 'blanch d.', 'schwaerzler j.', 'etcheverry t.', 'rehberg m.', 'galan d.e.', 'barrios m.', 'o connell c.', 'struff j.l.', 'gomez f.', 'tirante t.a.', 'zhang zh.', 'varillas j.p.', 'cerundolo j.m.', 'ramos-vinolas a.'}
#
# Values in only in df2:
# {'cerundolo j. m.', 'barrios vera t.', 'tseng c. h.', 'kwon s.', 'bautista-agut r.', 'ramos a.', 'hong s. c.', 'rehberg m. h.', 'mpetshi perricard g.', 'zhang z.', 'carreno-busta p.', 'huesler m.', 'struff j-l.', 'burruchaga r. a.', 'galan d. e.', 'bailly g. a.', 'etcheverry t. m.', 'schwaerzler j. j.', 'gomez f. a.', 'tirante t. a.', 'blanch dar.', 'varillas j. p.', "o'connell c.", 'herbert p.'}

# %%
from fuzzywuzzy import process
fixed_names = {}
for name in set2:
    closest_match = process.extractOne(name, set1)
    if closest_match[0] != name and closest_match[1] > 90:  # Threshold for similarity
        print(name, closest_match[0])
        fixed_names[name] = closest_match[0]
    else:
        fixed_names[name] = name  # Keep original if no good match is found
# Out:
# E:\Pawel\Studia\Inzynierka_Git\.venv\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# cerundolo j. m. cerundolo j.m.
# tseng c. h. tseng c.h.
# carreno-busta p. carreno busta p.
# galan d. e. galan d.e.
# schwaerzler j. j. schwaerzler j.
# gomez f. a. gomez f.
# rehberg m. h. rehberg m.
# huesler m. huesler m.a.
# struff j-l. struff j.l.
# o'connell c. o connell c.
# burruchaga r. a. burruchaga r.
# tirante t. a. tirante t.a.
# bautista-agut r. bautista agut r.
# zhang z. zhang zh.
# bailly g. a. bailly g.
# etcheverry t. m. etcheverry t.
# herbert p. herbert p.h.
# kwon s. kwon s.w.
# varillas j. p. varillas j.p.

# %%
# Find unique values
unique_to_df1 = set1 - set(fixed_names.values())
unique_to_df2 = set(fixed_names.values()) - set1

print(f"Values in only in df1:")
print(unique_to_df1)
print()
print(f"Values in only in df2:")
print(unique_to_df2)
# Out:
# Values in only in df1:
# {'blanch d.', 'barrios m.', 'hong s.', 'mpetshi g.', 'ramos-vinolas a.'}
#
# Values in only in df2:
# {'mpetshi perricard g.', 'barrios vera t.', 'blanch dar.', 'ramos a.', 'hong s. c.'}

# %%
manual_mapping = {
    'hong s. c.': 'hong s.',
    'ramos a.': 'ramos-vinolas a.',
    'blanch dar.': 'blanch d.',
    'mpetshi perricard g.': 'mpetshi g.',
}
print(sorted(set(df['winner_name'].unique())))
df['winner_name'] = df['winner_name'].replace(fixed_names)
df['loser_name'] = df['loser_name'].replace(fixed_names)

df['winner_name'] = df['winner_name'].replace(manual_mapping)
df['loser_name'] = df['loser_name'].replace(manual_mapping)
manual_mapping = {
    'Barrios M.': 'Barrios Vera T.'
}
bets2024['Winner'] = bets2024['Winner'].replace(manual_mapping)
bets2024['Loser'] = bets2024['Loser'].replace(manual_mapping)
# Out:
# ['ajdukovic d.', 'albot r.', 'alcaraz c.', 'altmaier d.', 'arnaldi m.', 'atmane t.', 'auger-aliassime f.', 'baez s.', 'bagnis f.', 'barrere g.', 'barrios vera t.', 'bautista-agut r.', 'bellucci m.', 'bergs z.', 'berrettini m.', 'blanchet u.', 'bolt a.', 'bonzi b.', 'borges n.', 'broady l.', 'brouwer g.', 'bu y.', 'bublik a.', 'burruchaga r. a.', 'cachin p.', 'carballes baena r.', 'carreno-busta p.', 'cazaux a.', 'cerundolo f.', 'cerundolo j. m.', 'choinski j.', 'cilic m.', 'cobolli f.', 'comesana f.', 'coria f.', 'coric b.', 'cressy m.', 'damm m.', 'daniel t.', 'darderi l.', 'davidovich fokina a.', 'de jong j.', 'de minaur a.', 'dellien h.', 'diallo g.', 'diaz acosta f.', 'dimitrov g.', 'djere l.', 'djokovic n.', 'dodig m.', 'draper j.', 'duckworth j.', 'engel j.', 'etcheverry t. m.', 'eubanks c.', 'evans d.', 'fearnley j.', 'fils a.', 'fognini f.', 'fonseca j.', 'fritz t.', 'fucsovics m.', 'galan d. e.', 'garin c.', 'gasquet r.', 'gaston h.', 'gigante m.', 'giron m.', 'goffin d.', 'gomez f. a.', 'grenier h.', 'griekspoor t.', 'halys q.', 'hanfmann y.', 'hardt n.', 'harris b.', 'harris l.', 'heide g.', 'herbert p.', 'hijikata r.', 'hong s. c.', 'huesler m.', 'humbert u.', 'hurkacz h.', 'hussey g.', 'jarry n.', 'jorda sanchis d.', 'jubb p.', 'kachmazov a.', 'karatsev a.', 'kecmanovic m.', 'khachanov k.', 'klein l.', 'koepfer d.', 'kokkinakis t.', 'korda s.', 'kotov p.', 'kovacevic a.', 'kovalik j.', 'krueger m.', 'kubler j.', 'kudla d.', 'kukushkin m.', 'kwon s.', 'kypson p.', 'lajovic d.', 'landaluce m.', 'lehecka j.', 'lestienne c.', 'llamas ruiz p.', 'machac t.', 'mannarino a.', 'marozsan f.', 'marterer m.', 'martinez p.', 'mayot h.', 'mcdonald m.', 'medjedovic h.', 'medvedev d.', 'meligeni alves f.', 'mensik j.', 'michelsen a.', 'misolic f.', 'mmoh m.', 'molleker r.', 'monfils g.', 'monteiro t.', 'moreno de alboran n.', 'moro canas a.', 'moutet c.', 'mpetshi perricard g.', 'muller a.', 'munar j.', 'murray a.', 'musetti l.', 'nadal r.', 'nagal s.', 'nakashima b.', 'napolitano s.', 'nardi l.', 'nava e.', 'navone m.', 'neumayer l.', 'nishikori k.', 'nishioka y.', 'norrie c.', "o'connell c.", 'ofner s.', 'opelka r.', 'paire b.', 'passaro f.', 'paul t.', 'popyrin a.', 'pouille l.', 'purcell m.', 'quinn e.', 'ramos a.', 'raonic m.', 'riedi l.', 'rinderknech a.', 'rocha h.', 'rodionov j.', 'rublev a.', 'rune h.', 'ruud c.', 'ruusuvuori e.', 'safiullin r.', 'schoolkate t.', 'seyboth wild t.', 'shang j.', 'shapovalov d.', 'shelton b.', 'shevchenko a.', 'sinner j.', 'skatov t.', 'sonego l.', 'spizzirri e.', 'squire h.', 'stricker d.', 'struff j-l.', 'svajda z.', 'tabilo a.', 'thiem d.', 'thompson j.', 'tiafoe f.', 'tien l.', 'tirante t. a.', 'trungelliti m.', 'tseng c. h.', 'tsitsipas s.', 'uchiyama y.', 'ugo carabelli c.', 'van assche l.', 'van de zandschulp b.', 'varillas j. p.', 'vavassori a.', 'virtanen o.', 'vukic a.', 'walton a.', 'watanuki y.', 'wawrinka s.', 'wolf j.j.', 'wong c.', 'wu y.', 'yevseyev d.', 'zapata miralles b.', 'zeppieri g.', 'zhang z.', 'zhou y.', 'zhukayev b.', 'zverev a.']

# %%
 # Convert column values to sets
set1 = set(bets2024["Winner"].str.lower())
set2 = set(df["winner_name"].str.lower())
set3 = set(bets2024["Loser"].str.lower())
set4 = set(df["loser_name"].str.lower())
set1.update(set3)
set2.update(set4)


# Find unique values
unique_to_df1 = set1 - set2
unique_to_df2 = set2 - set1

print(f"Values in only in df1:")
print(unique_to_df1)
print(f"Values in only in df2:")
print(unique_to_df2)
# Out:
# Values in only in df1:
# set()
# Values in only in df2:
# set()

# %%
 # Convert column values to sets
set1 = set(bets2024["Location"].str.lower())
set2 = set(df["tournament_name"].str.lower())
# Find unique values
unique_to_df1 = set1 - set2
unique_to_df2 = set2 - set1

print(f"Values in only in df1:")
print(unique_to_df1)
print(f"Values in only in df2:")
print(unique_to_df2)
# Out:
# Values in only in df1:
# {'turin', 'belgrade', 'dubai '}
# Values in only in df2:
# {'belgrade 2', 'paris 2', 'dubai'}

# %%
bets2024.loc[bets2024['Tournament']== 'BNP Paribas Masters', 'Location'] ='Paris 2'
bets2024.loc[bets2024['Tournament']== 'Belgrade Open', 'Location'] ='Belgrade 2'
bets2024.loc[bets2024['Location']== 'Dubai ', 'Location'] ='Dubai'

# %%
bets2024 = bets2024[~bets2024['Tournament'].isin(['Masters Cup'])]

# %%
 # Convert column values to sets
set1 = set(bets2024["Location"].str.lower())
set2 = set(df["tournament_name"].str.lower())
# Find unique values
unique_to_df1 = set1 - set2
unique_to_df2 = set2 - set1

print(f"Values in only in df1:")
print(unique_to_df1)
print(f"Values in only in df2:")
print(unique_to_df2)
# Out:
# Values in only in df1:
# set()
# Values in only in df2:
# set()

# %%
import random

# Create the initial mapping for losers and winners
map_loser_name_id = github_df.groupby('shortened_loser_name', as_index=False)[['shortened_loser_name', 'loser_id']].first()
map_winner_name_id = github_df.groupby('shortened_winner_name', as_index=False)[['shortened_winner_name', 'winner_id']].first()

# Combine the mappings for both losers and winners
mapping = {**dict(zip(map_loser_name_id['shortened_loser_name'], map_loser_name_id['loser_id'])),
           **dict(zip(map_winner_name_id['shortened_winner_name'], map_winner_name_id['winner_id']))}

# Define a function to generate unique 6-digit IDs
existing_ids = set(mapping.values())  # Track existing IDs to avoid duplicates

def generate_or_get_id(player_name):
    # If the player already has an ID, return it
    if player_name in mapping:
        return mapping[player_name]
    # Otherwise, generate a new unique ID
    new_id = str(random.randint(100000, 999999))
    while new_id in existing_ids:
        new_id = str(random.randint(100000, 999999))
    # Save the new ID in the mapping and mark it as used
    mapping[player_name] = new_id
    existing_ids.add(new_id)
    return new_id

# Map IDs for both loser and winner columns
bets2024['loser_id'] = bets2024['Loser'].apply(generate_or_get_id)
bets2024['winner_id'] = bets2024['Winner'].apply(generate_or_get_id)

# %%
print(bets2024.loc[bets2024['loser_id'].isna(), 'Loser'].unique())
# Out:
# []

# %%
name_mapping = {name.lower(): name for name in bets2024['Loser']}
df['loser_name'] = df['loser_name'].str.lower().map(name_mapping).fillna(df['loser_name'])
name_mapping = {name.lower(): name for name in bets2024['Winner']}
df['winner_name'] = df['winner_name'].str.lower().map(name_mapping).fillna(df['winner_name'])
tournament_mapping = {tournament.lower(): tournament for tournament in bets2024['Location']}
df['tournament_name'] = df['tournament_name'].str.lower().map(tournament_mapping).fillna(df['tournament_name'])

# %%
map_player_name_player_id = bets2024.groupby('Loser', as_index=False)[['Loser', 'loser_id']].first()
mapping = dict(zip(map_player_name_player_id['Loser'], map_player_name_player_id['loser_id']))
df['loser_id'] = df['loser_name'].map(mapping)

# %%
print(df.loc[df['loser_id'].isna(), 'loser_name'].unique())
# Out:
# []

# %%
map_player_name_player_id = bets2024.groupby('Winner', as_index=False)[['Winner', 'winner_id']].first()
mapping = dict(zip(map_player_name_player_id['Winner'], map_player_name_player_id['winner_id']))
df['winner_id'] = df['winner_name'].map(mapping)

# %%
print(df.loc[df['winner_id'].isna(), 'winner_name'].unique())
# Out:
# []

# %%
bets2024['match_id'] = bets2024['Location'].astype(str) + '_' + '2024' + '_' +  bets2024['winner_id'].astype(str) + '_' + bets2024['loser_id'].astype(str)
df['match_id'] = df['tournament_name'].astype(str) + '_' + '2024' + '_' + df['winner_id'].astype(str) + '_' + df['loser_id'].astype(str)

# %%
print(bets2024['match_id'].nunique() == len(bets2024))
print(df['match_id'].nunique() == len(df))
# Out:
# True
# True

# %%
print(bets2024[~bets2024['match_id'].isin(df['match_id'])]['match_id'].unique())
print(df[~df['match_id'].isin(bets2024['match_id'])]['match_id'].unique())
# Out:
# []
# []

# %%
import json
with open(f"../data/raw_data/player_details.json") as f:
        player_details = json.load(f)
print(player_details)
# Out:
# [{'Name': 'Hamza Reguig Samir', 'Country': 'Algeria', 'Date_of_birth': '2002-01-19', 'Plays': 'right'}, {'Name': 'Makhlouf Mohamed Nazim', 'Country': 'Algeria', 'Date_of_birth': '1996-09-12', 'Plays': 'right'}, {'Name': 'Sahtali Toufik', 'Country': 'Algeria', 'Date_of_birth': '1999-01-07', 'Plays': 'right'}, {'Name': 'Domingos Daniel', 'Country': 'Angola', 'Plays': 'right'}, {'Name': 'Maginley Herbert Jody', 'Country': 'Antigua and Barbuda', 'Height': '193 cm', 'Date_of_birth': '1995-06-07', 'Plays': 'right'}, {'Name': 'Baez Sebastian', 'Country': 'Argentina', 'Height': '170 cm', 'Date_of_birth': '2000-12-28', 'Plays': 'right'}, {'Name': 'Cerundolo Francisco', 'Country': 'Argentina', 'Height': '185 cm', 'Date_of_birth': '1998-08-13', 'Plays': 'right'}, {'Name': 'Etcheverry Tomas Martin', 'Country': 'Argentina', 'Height': '196 cm', 'Date_of_birth': '1999-07-18', 'Plays': 'right'}, {'Name': 'Navone Mariano', 'Country': 'Argentina', 'Date_of_birth': '2001-02-27', 'Plays': 'right'}, {'Name': 'Diaz Acosta Facundo', 'Country': 'Argentina', 'Height': '183 cm', 'Date_of_birth': '2000-12-15', 'Plays': 'left'}, {'Name': 'Coria Federico', 'Country': 'Argentina', 'Height': '180 cm', 'Date_of_birth': '1992-03-09', 'Plays': 'right'}, {'Name': 'Comesana Francisco', 'Country': 'Argentina', 'Date_of_birth': '2000-10-06', 'Plays': 'right'}, {'Name': 'Ugo Carabelli Camilo', 'Country': 'Argentina', 'Height': '185 cm', 'Date_of_birth': '1999-06-17', 'Plays': 'right'}, {'Name': 'Tirante Thiago Agustin', 'Country': 'Argentina', 'Height': '185 cm', 'Date_of_birth': '2001-04-10', 'Plays': 'right'}, {'Name': 'Gomez Federico Agustin', 'Country': 'Argentina', 'Date_of_birth': '1996-11-26', 'Plays': 'right'}, {'Name': 'Trungelliti Marco', 'Country': 'Argentina', 'Height': '178 cm', 'Date_of_birth': '1990-01-31', 'Plays': 'right'}, {'Name': 'Burruchaga Roman Andres', 'Country': 'Argentina', 'Date_of_birth': '2002-01-23', 'Plays': 'right'}, {'Name': 'Cerundolo Juan Manuel', 'Country': 'Argentina', 'Height': '183 cm', 'Date_of_birth': '2001-11-15', 'Plays': 'left'}, {'Name': 'Bagnis Facundo', 'Country': 'Argentina', 'Height': '183 cm', 'Date_of_birth': '1990-02-27', 'Plays': 'left'}, {'Name': 'Ficovich Juan Pablo', 'Country': 'Argentina', 'Height': '191 cm', 'Date_of_birth': '1997-01-24', 'Plays': 'right'}, {'Name': 'Mena Facundo', 'Country': 'Argentina', 'Height': '183 cm', 'Date_of_birth': '1992-09-22', 'Plays': 'right'}, {'Name': 'Collarini Andrea', 'Country': 'Argentina', 'Height': '185 cm', 'Date_of_birth': '1992-01-31', 'Plays': 'left'}, {'Name': 'Rodriguez Taverna Santiago', 'Country': 'Argentina', 'Height': '191 cm', 'Date_of_birth': '1999-07-16', 'Plays': 'right'}, {'Name': 'Torres Juan Bautista', 'Country': 'Argentina', 'Date_of_birth': '2002-04-02', 'Plays': 'right'}, {'Name': 'Cachin Pedro', 'Country': 'Argentina', 'Height': '185 cm', 'Date_of_birth': '1995-04-12', 'Plays': 'right'}, {'Name': 'Olivieri Genaro Alberto', 'Country': 'Argentina', 'Height': '175 cm', 'Date_of_birth': '1998-08-04', 'Plays': 'right'}, {'Name': 'Olivo Renzo', 'Country': 'Argentina', 'Height': '180 cm', 'Date_of_birth': '1992-03-15', 'Plays': 'right'}, {'Name': 'Schwartzman Diego', 'Country': 'Argentina', 'Height': '170 cm', 'Date_of_birth': '1992-08-16', 'Plays': 'right'}, {'Name': 'Aboian Valerio', 'Country': 'Argentina', 'Date_of_birth': '2002-06-14', 'Plays': 'left'}, {'Name': 'Lingua Lavallen Alejo Lorenzo', 'Country': 'Argentina', 'Date_of_birth': '2001-03-09', 'Plays': 'left'}, {'Name': 'Villanueva Gonzalo', 'Country': 'Argentina', 'Height': '175 cm', 'Date_of_birth': '1995-01-13', 'Plays': 'right'}, {'Name': 'Midon Lautaro', 'Country': 'Argentina', 'Date_of_birth': '2004-03-29', 'Plays': 'right'}, {'Name': 'Ambrogi Luciano Emanuel', 'Country': 'Argentina', 'Date_of_birth': '2003-11-19', 'Plays': 'right'}, {'Name': 'Casanova Hernan', 'Country': 'Argentina', 'Height': '178 cm', 'Date_of_birth': '1994-02-06', 'Plays': 'right'}, {'Name': 'Farjat Tomas', 'Country': 'Ar ...

# %%
def manual_name_normalization(full_name):
    if full_name == "McCabe James":
        return "Mccabe J."
    if full_name == "Rehberg Max Hans":
        return "Rehberg M."
    if full_name == "Bailly Gilles Arnaud":
        return "Bailly G."
    if full_name == "Barrios Vera Marcelo Tomas":
        return "Barrios Vera T."
    if full_name == "O'Connell Christopher":
        return "O Connell C."
    if full_name == "Etcheverry Tomas Martin": 
        return 'Etcheverry T.'
    if full_name == "Zhang Zhizhen":
        return 'Zhang Zh.'
    if full_name == "Burruchaga Roman Andres":
        return "Burruchaga R."
    if full_name == "Meligeni Rodrigues Alves Felipe":
        return "Meligeni Alves F."
    if full_name == "Damm Martin (2003)":
        return "Damm M."
    if full_name == "Mpetshi Perricard Giovanni":
        return "Mpetshi G."
    if full_name == "McDonald Mackenzie":
        return "Mcdonald M."
    if full_name == "Hong Seong Chan":
        return "Hong S."
    if full_name == "Gomez Federico Agustin":
        return "Gomez F."
    return None

# %%
import re
# Function to normalize and match names
def normalize_name(json_name, df_names):
    """
    Transforms a JSON name to match the format in the DataFrame.
    Returns the transformed name if matched, otherwise None.
    """
    manual_case = manual_name_normalization(json_name)
    if manual_case:
        return manual_case
    # Split the JSON name into parts
    json_parts = re.split(r'[ -]', json_name)  # Split by spaces or dots
    json_parts = [part for part in json_parts if part]     # Normalize against each DataFrame name
    for df_name in df_names:
        df_parts = re.split(r'[ .-]', df_name)  # Split by spaces or dots
        df_parts = [part for part in df_parts if part]         # Check if at least one part matches exactly
    
        exact_match = any(part in json_parts for part in df_parts)
        if not exact_match:
            continue
        # Check remaining parts as initials
        match = True
      
        for json_part in json_parts:
            if json_part not in df_parts:
                # Check if it's an initial of a JSON part
                #print(df_part, f'{json_parts[0][0]}.')
                if not any(df_part == f'{json_part[0]}' for df_part in df_parts):
                    match = False
                    break
        if match:
            return df_name  # Return the matched DataFrame name
    
    
    return json_name

# Extract JSON names
json_names = {d['Name'] for d in player_details}

# Normalize and find missing names
normalized_names = {
    normalize_name(json_name, df['winner_name'].unique()) for json_name in json_names
    if normalize_name(json_name, df['winner_name'].unique()) is not None
}
missing_names = df[~df['loser_name'].isin(normalized_names)]['loser_name'].unique()

# Output the missing names
print("Missing Names:")
print(missing_names)
# Out:
# Missing Names:
# ['Tu L.' 'Gojo B.' 'Sachko V.' 'Mochizuki S.' 'Pannu K.' 'Valkusz M.'
#  'Vesely J.' 'Jasika O.' 'Polmans M.' 'Kopriva V.' 'Prizmic D.'
#  'Sweeny D.' 'Svrcina D.' 'Escoffier A.' 'Schwartzman D.' 'Neff A.'
#  'Johnson S.' 'Sandgren T.' 'Shelbayh A.' 'Pacheco Mendez R.'
#  'Escobedo E.' 'Holt B.' 'Molcan A.' 'Blanch D.' 'Sousa J.' 'Faria J.'
#  'Ritschard A.' 'Dougaz A.' 'Benchetrit E.' 'Vacherot V.' 'Topo M.'
#  'Gakhov I.' 'Taberner C.' 'Rincon D.' 'Hassan B.' 'Fanselow S.'
#  'Barranco Cosano J.' 'Sanchez Izquierdo N.' 'Martineau M.'
#  'Van Rijthoven T.' 'Otte O.' 'Broom C.' 'Searle H.' 'Ymer E.' 'Lajal M.'
#  'Fery A.' 'Janvier M.' 'Pellegrino A.' 'Borg L.' 'Droguet T.'
#  'Schwaerzler J.' 'Collarini A.' 'Couacaud E.' 'Poljicak M.'
#  'Andreozzi G.' 'Mikrut L.' 'Martin A.' 'Pospisil V.' 'Mejia N.'
#  'Kumar O.' 'Kirchheimer S.' 'Forbes M.' 'Jacquet K.' 'Kasnikowski M.'
#  'Dzumhur D.' 'Sun F.' 'Ramanathan R.' 'Gerasimov E.' 'Blockx A.'
#  'Vatutin A.' 'Collignon R.' 'Kym J.' 'Guinard M.' 'Papamalamis T.'
#  'Djuric B.']

# %%
for player in player_details:
    player["normalized_name"] = normalize_name(player["Name"], df['winner_name'].unique())
for player in player_details:
    player["normalized_name"] = normalize_name(player["Name"], df['loser_name'].unique())

# %%
json_normalized_names = {d['normalized_name'] for d in player_details}

missing_names = df[~df['winner_name'].isin(json_normalized_names)]['winner_name'].unique()
print(missing_names)
missing_names = df[~df['loser_name'].isin(json_normalized_names)]['loser_name'].unique()
print(missing_names)
# Out:
# []
# []

# %%
# Convert player details into a lookup dictionary for easier access
details_lookup = {player['normalized_name']: player for player in player_details}

# Iterate over rows of the DataFrame
for index, row in df.iterrows():
    # Check for winner details
    winner_name = row['winner_name']
    if winner_name in details_lookup:
        winner_details = details_lookup[winner_name]
        for key, value in winner_details.items():
            if key != 'normalized_name':  # Skip normalized_name
                col_name = f"winner_{key}"
                if col_name not in df.columns:
                    df[col_name] = None  # Initialize column if it doesn't exist
                df.at[index, col_name] = value

    # Check for loser details
    loser_name = row['loser_name']
    if loser_name in details_lookup:
        loser_details = details_lookup[loser_name]
        for key, value in loser_details.items():
            if key != 'normalized_name':  # Skip normalized_name
                col_name = f"loser_{key}"
                if col_name not in df.columns:
                    df[col_name] = None  # Initialize column if it doesn't exist
                df.at[index, col_name] = value
df
# Out:
#                                                     url tournament_name  \
# 0     https://www.livesport.com/en/match/hrB0HLYB/#/...        Brisbane
# 1     https://www.livesport.com/en/match/rulXp2l4/#/...        Brisbane
# 2     https://www.livesport.com/en/match/nBebMPXT/#/...        Brisbane
# 3     https://www.livesport.com/en/match/8tKKk33i/#/...        Brisbane
# 4     https://www.livesport.com/en/match/vaNo5gB0/#/...        Brisbane
# ...                                                 ...             ...
# 2683  https://www.livesport.com/en/match/CYzZmNcR/#/...      Belgrade 2
# 2684  https://www.livesport.com/en/match/I14clWiA/#/...      Belgrade 2
# 2685  https://www.livesport.com/en/match/MNU3BtAU/#/...      Belgrade 2
# 2686  https://www.livesport.com/en/match/84M4r1Ll/#/...      Belgrade 2
# 2687  https://www.livesport.com/en/match/MmbNVNyq/#/...      Belgrade 2
#
#        location surface      round_name        date   time   comment  \
# 0     AUSTRALIA    HARD           FINAL  07.01.2024  07:55  FINISHED
# 1     AUSTRALIA    HARD     SEMI-FINALS  06.01.2024  11:40  FINISHED
# 2     AUSTRALIA    HARD     SEMI-FINALS  06.01.2024  06:05  FINISHED
# 3     AUSTRALIA    HARD  QUARTER-FINALS  05.01.2024  11:35  FINISHED
# 4     AUSTRALIA    HARD  QUARTER-FINALS  05.01.2024  08:10  FINISHED
# ...         ...     ...             ...         ...    ...       ...
# 2683     SERBIA    HARD     1/16-FINALS  04.11.2024  12:45  FINISHED
# 2684     SERBIA    HARD     1/16-FINALS  04.11.2024  11:10  FINISHED
# 2685     SERBIA    HARD     1/16-FINALS  04.11.2024  11:05  FINISHED
# 2686     SERBIA    HARD     1/16-FINALS  03.11.2024  18:30  FINISHED
# 2687     SERBIA    HARD     1/16-FINALS  03.11.2024  16:05  FINISHED
#
#         winner_name winner_rank  ...              winner_Name winner_Country  \
# 0       Dimitrov G.          10  ...          Dimitrov Grigor       Bulgaria
# 1       Dimitrov G.          10  ...          Dimitrov Grigor       Bulgaria
# 2           Rune H.          13  ...              Rune Holger        Denmark
# 3       Thompson J.          26  ...          Thompson Jordan      Australia
# 4       Dimitrov G.          10  ...          Dimitrov Grigor       Bulgaria
# ...             ...         ...  ...                      ...            ...
# 2683  Etcheverry T.          39  ...  Etcheverry Tomas Martin      Argentina
# 2684       Cilic M.         181  ...              Cilic Marin        Croatia
# 2685    Altmaier D.          88  ...          Altmaier Daniel        Germany
# 2686  Medjedovic H.         113  ...         Medjedovic Hamad         Serbia
# 2687    Marozsan F.          58  ...          Marozsan Fabian        Hungary
#
#      winner_Height winner_Date_of_birth winner_Plays  \
# 0           191 cm           1991-05-16        right
# 1           191 cm           1991-05-16        right
# 2           185 cm           2003-04-29        right
# 3           183 cm           1994-04-20        right
# 4           191 cm           1991-05-16        right
# ...            ...                  ...          ...
# 2683        196 cm           1999-07-18        right
# 2684        198 cm           1988-09-28        right
# 2685        191 cm           1998-09-12        right
# 2686          None           2003-07-18        right
# 2687          None           1999-10-08        right
#
#                      loser_Name loser_Country loser_Height  \
# 0                   Rune Holger       Denmark       185 cm
# 1               Thompson Jordan     Australia       183 cm
# 2               Safiullin Roman        Russia       185 cm
# 3                  Nadal Rafael         Spain       185 cm
# 4                Hijikata Rinky     Australia       178 cm
# ...                         ...           ...          ...
# 2683                Kotov Pavel        Russia       191 cm
# 2684           Muller Alexandre        France       183 cm
# 2685            Darderi Luciano         Italy         None
# 2686  Nakashima Bryce Nakashima           USA         None
# 2687             Shang Juncheng         China         None
#
#      loser_Date_of_birth loser_Plays
# 0             2003-04-29       right
# 1             1994-04-20       right
# 2             1997-08-07       right
# 3             1986-06-03        left
# 4             2001-02-23       right
# ...                  ...         ...
# 2683          1998-11-18       right
# 2684          1997-02-01       right
# 2685          2002-02-14       right
# 2686          2004-02-20       right
# 2687          2005-02-02        left
#
# [2688 rows x 86 columns]

# %%
df.columns
# Out:
# Index(['url', 'tournament_name', 'location', 'surface', 'round_name', 'date',
#        'time', 'comment', 'winner_name', 'winner_rank', 'winner_seed',
#        'loser_name', 'loser_rank', 'loser_seed', 'winner_sets', 'loser_sets',
#        'duration', 'winner_Set 1', 'winner_Set 2', 'loser_Set 1',
#        'loser_Set 2', 'winner_Aces', 'loser_Aces', 'winner_Double Faults',
#        'loser_Double Faults', 'winner_1st Serve Percentage',
#        'loser_1st Serve Percentage', 'winner_1st Serve Points Won',
#        'loser_1st Serve Points Won', 'winner_2nd Serve Points Won',
#        'loser_2nd Serve Points Won', 'winner_Break Points Saved',
#        'loser_Break Points Saved', 'winner_1st Return Points Won',
#        'loser_1st Return Points Won', 'winner_2nd Return Points Won',
#        'loser_2nd Return Points Won', 'winner_Break Points Converted',
#        'loser_Break Points Converted', 'winner_Winners', 'loser_Winners',
#        'winner_Unforced Errors', 'loser_Unforced Errors',
#        'winner_Net Points Won', 'loser_Net Points Won',
#        'winner_Service Points Won', 'loser_Service Points Won',
#        'winner_Return Points Won', 'loser_Return Points Won',
#        'winner_Total Points Won', 'loser_Total Points Won',
#        'winner_Last 10 Balls', 'loser_Last 10 Balls',
#        'winner_Match Points Saved', 'loser_Match Points Saved',
#        'winner_Service Games Won', 'loser_Service Games Won',
#        'winner_Return Games Won', 'loser_Return Games Won',
#        'winner_Total Games Won', 'loser_Total Games Won', 'winner_Set 3',
#        'loser_Set 3', 'winner_Set 4', 'winner_Set 5', 'loser_Set 4',
#        'loser_Set 5', 'winner_Distance Covered (metres)',
#        'loser_Distance Covered (metres)', 'winner_Average 1st Serve Speed',
#        'loser_Average 1st Serve Speed', 'winner_Average 2nd Serve Speed',
#        'loser_Average 2nd Serve Speed', 'loser_id', 'winner_id', 'match_id',
#        'winner_Name', 'winner_Country', 'winner_Height',
#        'winner_Date_of_birth', 'winner_Plays', 'loser_Name', 'loser_Country',
#        'loser_Height', 'loser_Date_of_birth', 'loser_Plays'],
#       dtype='object')

# %%
df['loser_seed'].unique()
# Out:
# array(['1', '', '8', '7', '6', '5', '3', '4', '2', '9', '12', '19', '10',
#        '15', '20', '27', '13', '11', '28', '21', '14', '29', '30', '16',
#        '26', '23', '24', '32', '17', '22', '25', '31', '18', '33'],
#       dtype=object)
